# %% [markdown]
# ## map2loop: From Topology fom Local file or Loop WFS Server to outputs to 3D mdoelling program
#
# This notebook reads in three layers from  local or remote sources:  geology polygons, orientation data and fault polylines; and calculates the topological relationships between the different features. Requires compiled cpp code from Vitaliy Ogarko
#
# This all gets fed into successive tolopogical and geometric transfroms that end up feeding into gempy to make a 3D model

# %%
import subprocess
import geopandas as gpd
import os
import sys
import stat
import functools 
import operator  
import matplotlib
import networkx as nx
from shapely.geometry import Polygon
from map2loop import m2l_utils
from map2loop import m2l_topology
# %matplotlib inline

newwd="C:\\Users\\00073294\Dropbox\\loop_minex\\map2model\\"
#os.chdir(newwd)
print("Current Working Directory " )

gdal_data = os.environ['GDAL_DATA']
print("***",gdal_data)
print('is dir: ' + str(os.path.isdir(gdal_data)))
gcs_csv = os.path.join(gdal_data, 'gcs.csv')
print('is file: ' + str(os.path.isfile(gcs_csv)))
st = os.stat(gcs_csv)
print('is readable: ' + str(bool(st.st_mode & stat.S_IRGRP)))
os.environ['PROJ_LIB']=r"C:\\Users\\00073294\\AppData\\Local\\Continuum\\anaconda3\\Lib\\site-packages\\pyproj\\proj_dir\\share\\proj"
print(os.getenv('PROJ_LIB'))
print(os.getcwd())
# Out:
# Current Working Directory
# *** C:\Program Files\PostgreSQL\11\gdal-data
# is dir: True
# is file: True
# is readable: True
# C:\\Users\\00073294\\AppData\\Local\\Continuum\\anaconda3\\Lib\\site-packages\\pyproj\\proj_dir\\share\\proj
# C:\Users\00073294\Dropbox\1_Jupyter_notebooks\map2loop\notebooks

# %% [markdown]
# ## Create bounding box based on inputs

# %%
test_data_path='../test_data3/'


# %run -i "../test_data3/m2l_config.py"

bbox2=str(minx)+","+str(miny)+","+str(maxx)+","+str(maxy)
lat_point_list = [miny, miny, maxy, maxy, maxy]
lon_point_list = [minx, maxx, maxx, minx, minx]
bbox_geom = Polygon(zip(lon_point_list, lat_point_list))
polygon = gpd.GeoDataFrame(index=[0], crs=dst_crs, geometry=[bbox_geom]) 
bbox=(minx,miny,maxx,maxy)
# Out:
# Default parameters loaded from m2l_config.py:
# #ROI
# minlong=117 # should back calc from metre system\n",
# maxlong=118
# minlat=-23
# maxlat=-22
#
# step_out=0
# inset=0
#
# minx=500057
# maxx=603028
# miny=7455348
# maxy=7567953
#
# #CRS
# src_crs = {'init': 'EPSG:4326'}
# dst_crs = {'init': 'EPSG:28350'}
#
# #PATH
# mname='hams3'
# geology_file='hams2_geol.shp'
# fault_file='GEOS_GEOLOGY_LINEARSTRUCTURE_500K_GSD.shp'
# structure_file='hams2_structure.shp'
#
#
#
# #CODES
# gcode='GROUP_'
# dcode='DIP'
# ddcode='DIP_DIR'
# ccode='CODE'
# ncode='NAME'
# ocode='OBJECTID'
# gicode='GEOPNT_ID'
# r1code='ROCKTYPE1'
# r2code='ROCKTYPE2'
# tcode='TYPE'
# fcode='FEATURE'
# dscode='DESCRIPTN'
# ucode='UNITNAME'
# mincode='MIN_AGE_MA'
# maxcode='MAX_AGE_MA'
# sill_label='sill'
# intrusive_label='intrusive'
# fold_label='Fold axial trace'
# fault_label='Fault'
# bedding_label='Bed'
#
# #MODEL_EXTENTS
# model_base=-8200
#
#
# #DECIMATION
# orientation_decimate=0
# contact_decimate=10
# fault_decimate=5
# fold_decimate=5
#
#
# #INTERPOLATION
# gridx=50
# gridy=50
# scheme='scipy_rbf'
# dist_buffer=5
# intrusion_mode=0 # 1 all instrusions exluded from basal contacts, 0 only sills
#
# #ASSUMPTIONS
# pluton_dip=45
# pluton_form='saucers' #pluton_form='dontknow'  #saucers \_____/  pancakes /_____\   domes /â€¾â€¾â€¾â€¾â€¾\  dontknow ???
# fault_dip=90
#
# #PATHS
#
# local_paths=False
# test_data_path='../test_data3/'
# graph_path=test_data_path+'graph/'
# tmp_path=test_data_path+'tmp/'
# data_path=test_data_path+'data/'
# dtm_path=test_data_path+'dtm/'
# output_path=test_data_path+'output/'
# vtk_path=test_data_path+'vtk/'
# m2m_cpp_path='../m2m_cpp/'
#
# fault_file=data_path+'GEOS_GEOLOGY_LINEARSTRUCTURE_500K_GSD.shp'
# structure_file=data_path+'hams2_structure.shp'
# geology_file=data_path+'hams2_geol.shp'
#
# fault_file_csv=fault_file.replace(".shp",".csv").replace("/data/","/tmp/")
# structure_file_csv=structure_file.replace(".shp",".csv").replace("/data/","/tmp/")
# geology_file_csv=geology_file.replace(".shp",".csv").replace("/data/","/tmp/")
#
# strat_graph_file=test_data_path+'graph/graph_strat.gml'
#
# dtm_file=dtm_path+mname+'_dtm.tif'
# dtm_reproj_file=dtm_path+mname+'_dtm_rp.tif'
#
# if(not os.path.isdir(tmp_path)):
#    os.mkdir(tmp_path)
# if(not os.path.isdir(output_path)):
#    os.mkdir(output_path)
# if(not os.path.isdir(dtm_path)):
#    os.mkdir(dtm_path)
# if(not os.path.isdir(dtm_path)):
#    os.mkdir(dtm_path)
# if(not os.path.isdir(vtk_path)):
#    os.mkdir(vtk_path)
#
# print('Default parameters loaded from m2l_config.py:')
# with open('../test_data3/m2l_config.py', 'r') as myfile:
#   data = myfile.read()
#   print(data)
#   myfile.close()
# print('\nModify these parameters in the cell below')
#
# Modify these parameters in the cell below

# %% [markdown]
# ## First we test to see if we have access to the online data we need

# %%
net=m2l_utils.have_access("geo.loop-gis.org")
# Out:
# available: geo.loop-gis.org

# %% [markdown]
# ## Optional WFS source
#
# WFS brings in field names as lower case, so need to redefine codes too

# %%
#local_paths=True



if(not local_paths and net):
    structure_file='http://geo.loop-gis.org/geoserver/loop/wfs?service=WFS&version=1.1.0&request=GetFeature&typeName=warox_points_f5011&bbox='+bbox2+'&srs=EPSG:28350'
    fault_file='http://geo.loop-gis.org/geoserver/loop/wfs?service=WFS&version=1.1.0&request=GetFeature&typeName=linear_500k&bbox='+bbox2+'&srs=EPSG:28350'
    geology_file='http://geo.loop-gis.org/geoserver/loop/wfs?service=WFS&version=1.0.0&request=GetFeature&typeName=loop:geol_500k&bbox='+bbox2+'&srs=EPSG:28350'

    gcode='group_'
    dcode='dip'
    ddcode='dip_dir'
    ccode='code'
    ncode='fname'
    ocode='objectid'
    gicode='geopnt_id'
    r1code='rocktype1'
    r2code='rocktype2'
    tcode='type'
    fcode='feature'
    dscode='descriptn'
    ucode='unitname'
    mincode='min_age_ma'
    maxcode='max_age_ma'

# %% [markdown]
# ## Plot geology polygons and bounding box

# %%
geology_ll = gpd.read_file(geology_file,bbox=bbox)

base=geology_ll.plot(column=ccode,figsize=(10,10),edgecolor='#000000',linewidth=0.2)
polygon.plot(ax=base, color='none',edgecolor='black')

# %% [markdown]
# ## Save to file as WKT

# %%
sub_geol = geology_ll[['geometry', ocode,ccode,gcode,ucode,mincode,maxcode,dscode,r1code,r2code]]
m2l_topology.save_geol_wkt(sub_geol,geology_file_csv,ocode,gcode,mincode,maxcode,ccode,r1code,r2code,dscode,ucode)
# Out:
# 186  polygons

# %% [markdown]
# ## Read and save WAROX point data as WKT

# %%
warox = gpd.read_file(structure_file,bbox=bbox)

sub_pts = warox[['geometry', gicode,dcode,ddcode]]

m2l_topology.save_structure_wkt(sub_pts,structure_file_csv,gcode,dcode,ddcode,gicode)

base=sub_pts.plot()
polygon.plot(ax=base, color='none',edgecolor='black')
# Out:
# 297  points

# %% [markdown]
# ## Plot faults and bounding box

# %%
#bbox='-23,117,-22,118'
#lines=gpd.read_file("https://services.slip.wa.gov.au/public/services/SLIP_Public_Services/Geology_and_Soils_Map_WFS/MapServer/WFSServer/?service=WFS&version=1.0.0&request=GetFeature&typename=SLIP_Public_Services_Geology_and_Soils_Map_WFS:__2_500_000_State_interpreted_bedrock_geology_structural_lines__DMIRS-013_&BBOX="+bbox+"&srs=EPSG:3857")
#print(lines)
#lines.plot(column='feature',figsize=(10,10),linewidth=0.2)
lines_ll=gpd.read_file(fault_file,bbox=bbox)
#lines_ll = lines.to_crs('epsg:4326')
#print(geology.crs)
base2=lines_ll.plot(cmap='rainbow',column=fcode,figsize=(10,10),linewidth=0.4)
polygon.plot(ax=base2, color='none',edgecolor='black')

# %% [markdown]
# ## Save faults to file as WKT

# %%
sub_lines = lines_ll[['geometry', ocode,fcode]]
m2l_topology.save_faults_wkt(sub_lines,fault_file_csv,ocode,fcode)
# Out:
# 134  polylines

# %% [markdown]
# ## Create map2model input file

# %%
m2l_topology.save_Parfile(m2m_cpp_path,ocode,fcode,gicode,dcode,ddcode,ucode,gcode,mincode,maxcode,ccode,dscode,r1code,r2code,fold_label,sill_label,graph_path,geology_file_csv,fault_file_csv,structure_file_csv,minx,maxx,miny,maxy)

# %% [markdown]
# ## Calculate topology

# %%
os.chdir(m2m_cpp_path)
print(os.getcwd())
# %system map2model.exe Parfile
# Out:
# C:\Users\00073294\Dropbox\1_Jupyter_notebooks\map2loop\m2m_cpp
# ['Reading data from the file: Parfile',
#  '--- COLUMN NAMES IN CSV DATA FILES: -------------------------------------------------------------',
#  'OBJECT COORDINATES              =WKT',
#  'FAULT: ID                       =objectid',
#  'FAULT: FEATURE                  =feature',
#  'POINT: ID                       =geopnt_id',
#  'POINT: DIP                      =dip',
#  'POINT: DIP DIR                  =dip_dir',
#  'POLYGON: ID                     =objectid',
#  'POLYGON: LEVEL1 NAME            =unitname',
#  'POLYGON: LEVEL2 NAME            =group_',
#  'POLYGON: MIN AGE                =min_age_ma',
#  'POLYGON: MAX AGE                =max_age_ma',
#  'POLYGON: CODE                   =code',
#  'POLYGON: DESCRIPTION            =descriptn',
#  'POLYGON: ROCKTYPE1              =rocktype1',
#  'POLYGON: ROCKTYPE2              =rocktype2',
#  '--- SOME CONSTANTS: ----------------------------------------------------------------------------',
#  'FAULT AXIAL FEATURE NAME        =Fold axial trace',
#  'SILL UNIT DESCRIPTION CONTAINS  =sill',
#  'IGNEOUS ROCKTYPE CONTAINS                           =igneous',
#  'VOLCANIC ROCKTYPE CONTAINS                          =volcanic',
#  'Intersect Contact With Fault: angle epsilon (deg)   =1',
#  'Intersect Contact With Fault: distance epsilon (m)  =15',
#  '------------------------------------------------------------------------------------------------',
#  'Path to the output data folder                      =../test_data3/graph/',
#  'Path to geology data file                           =../test_data3/tmp/hams2_geol.csv',
#  'Path to faults data file                            =../test_data3/tmp/GEOS_GEOLOGY_LINEARSTRUCTURE_500K_GSD.csv',
#  'Path to points data file                            =../test_data3/tmp/hams2_structure.csv',
#  '------------------------------------------------------------------------------------------------',
#  'Clipping window X1 Y1 X2 Y2 (zeros for infinite)    =500057 7.45535e+06 603028 7.56795e+06',
#  'Min length fraction for strat/fault graphs          =0',
#  'Graph edge width categories (three doubles)         =2000 20000 200000',
#  'Graph edge direction (0-min age, 1-max age, 2-avg)  =2',
#  'Partial graph polygon ID                            =32',
#  'Partial graph depth                                 =4',
#  'Map subregion size dx, dy [m] (zeros for full map)  =0 0',
#  '------------------------------------------------------------------------------------------------',
#  'Reading data from the file ../test_data3/tmp/GEOS_GEOLOGY_LINEARSTRUCTURE_500K_GSD.csv',
#  'Objects read: 104',
#  'Reading data from the file ../test_data3/tmp/hams2_structure.csv',
#  'Objects read: 297',
#  'Reading data from the file ../test_data3/tmp/hams2_geol.csv',
#  'Objects read: 186',
#  'Multipolygons left (after clipping): 186',
#  'Faults left (after clipping): 104',
#  'Window perimeter = 431152',
#  'Building lists of units and groups...',
#  'Number of units: 29',
#  'Total unit length = 11506810.30721',
#  '1 Fortescue Group',
#  '2 Hamersley Group',
#  '3 A-b-PRK',
#  '4 A-mgn-PMI',
#  '5 A-mgn-PRK',
#  '6 A-s-PMI',
#  '7 A-s-PRK',
#  '8 Shingle Creek Group',
#  '9 Turee Creek Group',
#  '10 Wyloo Group',
#  'Intersecting faults with polygons...',
#  'Wrote 26 items to unit-fault intersection list: ../test_data3/graph//unit-fault-intersection.txt',
#  'Intersecting faults with faults...',
#  'Wrote 49 items to fault-fault intersection list: ../test_data3/graph//fault-fault-intersection.txt',
#  'Finding contacts...',
#  'numCommonEdges = 13296',
#  'Total contact length = 5537829.1536051',
#  'Identifying contact types...',
#  'Total number of intersections: 680',
#  'Number of all contacts: 402',
#  'Number of fault-contacts: 108',
#  'Number of mixed-contacts: 128',
#  'Splitting mixed contacts...',
#  'Number of contacts after splitting: 748',
#  'PERIMETER LENGTHS: 11506810.30721 11506810.30721 -1.4901161193848e-08',
#  'Finding unit-contacts...',
#  'Number of unit-contacts: 75',
#  'Number of unit-contacts = 75',
#  'Number of stratigraphic unit-contacts = 17',
#  'Number of fault unit-contacts = 26',
#  'Number of mixed unit-contacts = 32',
#  'Identifying igneous contacts...',
#  'Number of intrusive igneous unit contacts: 23',
#  'Number of igneous unit contacts: 5',
#  'Writing topology graph to a file: ../test_data3/graph//graph_all.gml',
#  'Number of units in the graph: 29',
#  'Number of groups in the graph: 10',
#  'Writing topology graph to a file: ../test_data3/graph//graph_strat.gml',
#  'Number of units in the graph: 29',
#  'Number of groups in the graph: 10',
#  'Writing topology graph to a file: ../test_data3/graph//graph_fault.gml',
#  'Number of units in the graph: 26',
#  'Number of groups in the graph: 9',
#  'Writing topology graph to a file: ../test_data3/graph//graph_ingeous.gml',
#  'Number of units in the graph: 29',
#  'Number of groups in the graph: 10',
#  'Finding unit-contacts...',
#  'Number of unit-contacts: 0',
#  'Number of unit-contacts = 0',
#  'Number of stratigraphic unit-contacts = 0',
#  'Number of fault unit-contacts = 0',
#  'Number of mixed unit-contacts = 0',
#  'Writing topology graph to a file: ../test_data3/graph//graph_partial.gml',
#  'Number of units in the graph: 0',
#  'Number of groups in the graph: 0',
#  'End.']

# %% [markdown]
# ## Simple network graph of the geology with legend

# %%
G=nx.read_gml(strat_graph_file,label='id')
selected_nodes = [n for n,v in G.nodes(data=True) if n >=0]
nx.draw_networkx(G, pos=nx.kamada_kawai_layout(G), arrows=True, nodelist=selected_nodes)

nlist=list(G.nodes.data('LabelGraphics'))
nlist.sort()
for no in nlist:
    if(no[0]>=0):
        elem=str(no[1]).replace("{'text':","").replace(", 'fontSize': 14}","")
        #second=elem.split(":").replace("'","")
        print(no[0]," ",elem)
# Out:
# C:\Users\00073294\AppData\Local\Continuum\anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\00073294\AppData\Local\Continuum\anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# 0    'A-HAm-cib'
# 1    'A-FO-od'
# 2    'A-HAu-xsl-ci'
# 3    'P_-HAw-fr'
# 4    'A-FOj-xs-b'
# 5    'P_-SKq-stq'
# 6    'A-b-PRK'
# 7    'A-HAd-kd'
# 8    'A-FOo-bbo'
# 9    'A-s-PMI'
# 10    'A-FO-xo-a'
# 11    'A-FOh-xs-f'
# 12    'A-FOp-bs'
# 13    'P_-WYm-sp'
# 14    'A-FOu-bbo'
# 15    'P_-HAb-cib'
# 16    'P_-TK-s'
# 17    'P_-HAj-xci-od'
# 18    'P_-TKk-sf'
# 19    'P_-TKa-xs-k'
# 20    'P_-SKb-bb'
# 21    'P_-WYa-s'
# 22    'A-s-PRK'
# 23    'A-FOr-b'
# 24    'P_-HAo-ci'
# 25    'P_-WYd-kd'
# 26    'A-mgn-PMI'
# 27    'P_-TKo-stq'
# 28    'A-mgn-PRK'

# %% [markdown]
# ## Detailed Topology via dot or gml format files
# For a more detailed look we can open up the online version of <b>yEd</b> <a href="https://www.yworks.com/yed-live/" >https://www.yworks.com/yed-live/</a>  and load in the *.dot file that we will now create or dowload the <a href="https://www.yworks.com/products/yed/download">yEd program</a> and look at the *.gml files in the <b>output</b> directory

# %% [markdown]
# from networkx.drawing.nx_pydot import write_dot
#
# import filer,gfiler
#
# filepath=filer.gui_fname().decode('UTF-8')
# write_dot(G,filepath)

# %% [markdown]
# http://localhost:8888/notebooks/Dropbox/1_Jupyter_notebooks/map2loop/notebooks/2.%20map2loop_after_topology.ipynb

# %% [markdown]
# ## Process topography, stratigraphy, fold axial traces and faults
#
# ### Takes GML file produced by topology code, combines with geology polygons, structure points and dtm to create 3D model in gempy.<br><br>
#
# Limitations:  no dykes, no sills. Sills require us to assign a unique surface to each instance of a sill (sill between units A and B needs to be different from sill of same age and strat codes as one found between E and F). Dykes via cokriging are really hard without just cookie cutting them in (but that is not our problem!). We are not checking for onlap relationships, which can perhaps been seen by having lots of units from one series adjacent to the youngest surface of the older series. Could also think about interpreting these as faults to introduce conceptual uncertainty. All mistakes belong to Mark Jessell, topology code that feeds this system by Vitaliy Ogarko.<br><br>
#
# Geology layer needs to have some unique strat code or text, some group code or text to function<br>
# Structure layer needs dip/dip direction<br>
#
# <font color='red'>Currently mostly hardwired to GSWA 500K map so needs work...</font>

# %%
import os
#print(os.getcwd())
os.chdir('../map2loop')

print(os.getcwd())
# Out:
# C:\Users\00073294\Dropbox\1_Jupyter_notebooks\map2loop\map2loop

# %%
from map2loop import m2l_utils
from map2loop import m2l_topology
from map2loop import m2l_geometry

m2l_utils.v()
# Out:
# 0.0.46

# %%
#from IPython.core.display import display, HTML
#display(HTML("<style>.container { width:80% !important; }</style>"))
import matplotlib
import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from urllib.request import urlopen
import numpy as np
from matplotlib.pyplot import imshow
from matplotlib import pyplot as plt
import os
import rasterio
from rasterio.transform import from_origin
from rasterio import features
# %matplotlib inline
import sys, os
import geopandas as gpd
import os
from shapely.geometry import Polygon, Point, LineString
sys.path.insert(0,"../..")
print(os.getcwd())
#rootdir=r'C:\Users\00073294\Dropbox\1_Jupyter_notebooks\map2loop\\'
#os.chdir('../')
print(os.getcwd())
os.environ["PROJ_LIB"] = r"C:\Users\00073294\AppData\Local\Continuum\anaconda3\Lib\site-packages\pyproj\proj_dir\share\proj"
# Out:
# C:\Users\00073294\Dropbox\1_Jupyter_notebooks\map2loop\map2loop
# C:\Users\00073294\Dropbox\1_Jupyter_notebooks\map2loop\map2loop

# %% [markdown]
# ## First we test to see if we have access to the online data we need

# %%
net=m2l_utils.have_access("geo.loop-gis.org")
m2l_utils.have_access("oos.soest.hawaii.edu")
# Out:
# available: geo.loop-gis.org
# available: oos.soest.hawaii.edu
# True

# %% [markdown]
# ## Next we define an area of interest and some other basic stuff

# %%
print(os.getcwd())
test_data_path='../test_data3/'


#%run -i "../test_data3/m2l_config.py"

bbox2=str(minx)+","+str(miny)+","+str(maxx)+","+str(maxy)
lat_point_list = [miny, miny, maxy, maxy, maxy]
lon_point_list = [minx, maxx, maxx, minx, minx]
bbox_geom = Polygon(zip(lon_point_list, lat_point_list))
polygon = gpd.GeoDataFrame(index=[0], crs=dst_crs, geometry=[bbox_geom]) 
bbox=(minx,miny,maxx,maxy)

step_out=0.045 #add (in degrees) so edge pixel from dtm reprojection are not found


contact_decimate=5
# Out:
# C:\Users\00073294\Dropbox\1_Jupyter_notebooks\map2loop\map2loop

# %% [markdown]
# ## Optional WFS source
#
# WFS brings in field names as lower case, so need to redefine codes too

# %%
if(not local_paths and net):
    structure_file='http://geo.loop-gis.org/geoserver/loop/wfs?service=WFS&version=1.1.0&request=GetFeature&typeName=warox_points_f5011&bbox='+bbox2+'&srs=EPSG:28350'
    fault_file='http://geo.loop-gis.org/geoserver/loop/wfs?service=WFS&version=1.1.0&request=GetFeature&typeName=linear_500k&bbox='+bbox2+'&srs=EPSG:28350'
    geology_file='http://geo.loop-gis.org/geoserver/loop/wfs?service=WFS&version=1.0.0&request=GetFeature&typeName=loop:geol_500k&bbox='+bbox2+'&srs=EPSG:28350'

    gcode='group_'
    dcode='dip'
    ddcode='dip_dir'
    ccode='code'
    ncode='fname'
    ocode='objectid'
    gicode='geopnt_id'
    r1code='rocktype1'
    r2code='rocktype2'
    tcode='type'
    fcode='feature'
    dscode='descriptn'
    ucode='unitname'
    mincode='min_age_ma'
    maxcode='max_age_ma'

# %% [markdown]
# ## Download and reproject the appropriate SRTM data
# mj: Getting this from Hawaii, but could also get from Geoscience Australia (expect when I tried via WCS it blew up for more than 0.25 degree square areas, but I am pretty sure this is a OWS python plugin problem not GA since I can load the whole data with QGIS)

# %%
if(not local_paths and net):
    m2l_utils.get_dtm(dtm_file, minlong,maxlong,minlat,maxlat,step_out)
    geom_rp=m2l_utils.reproject_dtm(dtm_file,dtm_reproj_file,src_crs,dst_crs)
# Out:
# dtm geotif saved as ../test_data3/dtm/hams3_dtm.tif
# reprojected dtm geotif saved as ../test_data3/dtm/hams3_dtm_rp.tif

# %% [markdown]
# ## Load stratigraphy graph and create list of series (aka groups)
# mj: The choice of what constitutes basic unit and what a group of units is hard-wired at the moment, but could be altered to any pair. Not even sure we need two levels but it seemed like a good idea at the time. Note that this needs the arcgis plugin version of the topology code (for now) as it seperates the different sub graphs. Text outputs list alternate topologies for series and surfaces, which if confirmed by comapring max-min ages will be a nice source of uncertainty.

# %%
groups,glabels,G = m2l_topology.get_series(strat_graph_file,'id')
m2l_topology.save_units(G,tmp_path,glabels)
# Out:
# -12 A_b_PRK ----------------------
# choices: 1
# 6 A_b_PRK
#
# -13 A_mgn_PMI ----------------------
# choices: 1
# 26 A_mgn_PMI
#
# -14 A_mgn_PRK ----------------------
# choices: 1
# 28 A_mgn_PRK
#
# -15 A_s_PMI ----------------------
# choices: 1
# 9 A_s_PMI
#
# -16 A_s_PRK ----------------------
# choices: 1
# 22 A_s_PRK
#
# -1 Fortescue_Group ----------------------
# choices: 2
# 4 A_FOj_xs_b
# 10 A_FO_xo_a
# 1 A_FO_od
# 14 A_FOu_bbo
# 12 A_FOp_bs
# 8 A_FOo_bbo
# 11 A_FOh_xs_f
# 23 A_FOr_b
# ....
# 10 A_FO_xo_a
# 4 A_FOj_xs_b
# 1 A_FO_od
# 14 A_FOu_bbo
# 12 A_FOp_bs
# 8 A_FOo_bbo
# 11 A_FOh_xs_f
# 23 A_FOr_b
#
# -9 Hamersley_Group ----------------------
# choices: 1
# 24 P__HAo_ci
# 3 P__HAw_fr
# 17 P__HAj_xci_od
# 15 P__HAb_cib
# 2 A_HAu_xsl_ci
# 7 A_HAd_kd
# 0 A_HAm_cib
#
# -21 Shingle_Creek_Group ----------------------
# choices:
# C:\Users\00073294\AppData\Local\Continuum\anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\00073294\AppData\Local\Continuum\anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
#  1
# 20 P__SKb_bb
# 5 P__SKq_stq
#
# -23 Turee_Creek_Group ----------------------
# choices: 4
# 19 P__TKa_xs_k
# 27 P__TKo_stq
# 18 P__TKk_sf
# 16 P__TK_s
# ....
# 19 P__TKa_xs_k
# 27 P__TKo_stq
# 16 P__TK_s
# 18 P__TKk_sf
# ....
# 19 P__TKa_xs_k
# 16 P__TK_s
# 27 P__TKo_stq
# 18 P__TKk_sf
# ....
# 16 P__TK_s
# 19 P__TKa_xs_k
# 27 P__TKo_stq
# 18 P__TKk_sf
#
# -27 Wyloo_Group ----------------------
# choices: 2
# 13 P__WYm_sp
# 21 P__WYa_s
# 25 P__WYd_kd
# ....
# 21 P__WYa_s
# 13 P__WYm_sp
# 25 P__WYd_kd

# %% [markdown]
# ## Load geology & structure data
# Currently loading from local files, but could load geology from WFS server at GSWA EXCEPT that the WFS online map has less fields that the zipped shapefiles. Go figure. We don't use fault layer at the moment (except for Vitaliy's topology code) but same logic applies in terms of where to get it from. Already have fault/strat relationships and once we have fault/fault relationships will start to include faults in models.

# %%
# Extract point data from structure & geology layers for modelling
##First we readin the structure and map from shapefiles, or wherever...

bbox=(minx,miny,maxx,maxy)
geology = gpd.read_file(geology_file,bbox=bbox)


structure = gpd.read_file(structure_file,bbox=bbox)
structure.crs=dst_crs
print(fault_file)
faults = gpd.read_file(fault_file,bbox=bbox)
faults.crs=dst_crs
display(faults)
sub_pts = structure[['geometry',dcode,ddcode,fcode]]

base=geology.plot(column=ccode,figsize=(10,10),edgecolor='#000000',linewidth=0.2)
sub_pts.plot(ax=base, column=fcode,edgecolor='black')
faults.plot(ax=base, column=fcode,edgecolor='black')
# Out:
# http://geo.loop-gis.org/geoserver/loop/wfs?service=WFS&version=1.1.0&request=GetFeature&typeName=linear_500k&bbox=500057,7455348,603028,7567953&srs=EPSG:28350
#                 gml_id  objectid                     feature  \
# 0     linear_500k.6825      6825  Fault or shear zone, major
# 1     linear_500k.7344      7344  Fault or shear zone, major
# 2     linear_500k.7436      7436  Fault or shear zone, major
# 3     linear_500k.7439      7439  Fault or shear zone, major
# 4     linear_500k.7966      7966  Fault or shear zone, major
# 5     linear_500k.7967      7967  Fault or shear zone, major
# 6     linear_500k.8551      8551  Fault or shear zone, major
# 7    linear_500k.11127     11127            Fold axial trace
# 8    linear_500k.11170     11170            Fold axial trace
# 9    linear_500k.11182     11182            Fold axial trace
# 10   linear_500k.11183     11183            Fold axial trace
# 11   linear_500k.11202     11202            Fold axial trace
# 12   linear_500k.12795     12795            Fold axial trace
# 13   linear_500k.13532     13532            Fold axial trace
# 14   linear_500k.13533     13533            Fold axial trace
# 15   linear_500k.13563     13563            Fold axial trace
# 16   linear_500k.13564     13564            Fold axial trace
# 17   linear_500k.13565     13565            Fold axial trace
# 18   linear_500k.13631     13631            Fold axial trace
# 19   linear_500k.13632     13632            Fold axial trace
# 20   linear_500k.13655     13655            Fold axial trace
# 21   linear_500k.13665     13665            Fold axial trace
# 22   linear_500k.13670     13670            Fold axial trace
# 23   linear_500k.14303     14303         Fault or shear zone
# 24   linear_500k.15527     15527         Fault or shear zone
# 25   linear_500k.16245     16245         Fault or shear zone
# 26   linear_500k.16740     16740         Fault or shear zone
# 27   linear_500k.17127     17127  Fault or shear zone, major
# 28     linear_500k.313       313         Fault or shear zone
# 29    linear_500k.5471      5471         Fault or shear zone
# ..                 ...       ...                         ...
# 104  linear_500k.12647     12647         Fault or shear zone
# 105  linear_500k.12658     12658         Fault or shear zone
# 106  linear_500k.12660     12660         Fault or shear zone
# 107  linear_500k.12754     12754            Fold axial trace
# 108  linear_500k.12890     12890            Fold axial trace
# 109  linear_500k.12955     12955            Fold axial trace
# 110  linear_500k.14251     14251         Fault or shear zone
# 111  linear_500k.14378     14378         Fault or shear zone
# 112  linear_500k.15530     15530         Fault or shear zone
# 113  linear_500k.15531     15531         Fault or shear zone
# 114  linear_500k.15540     15540         Fault or shear zone
# 115  linear_500k.15546     15546         Fault or shear zone
# 116  linear_500k.15552     15552         Fault or shear zone
# 117  linear_500k.16397     16397         Fault or shear zone
# 118  linear_500k.16399     16399         Fault or shear zone
# 119  linear_500k.16455     16455         Fault or shear zone
# 120  linear_500k.16502     16502         Fault or shear zone
# 121  linear_500k.16503     16503         Fault or shear zone
# 122  linear_500k.16739     16739         Fault or shear zone
# 123  linear_500k.16742     16742         Fault or shear zone
# 124  linear_500k.16744     16744         Fault or shear zone
# 125  linear_500k.16754     16754         Fault or shear zone
# 126  linear_500k.16767     16767         Fault or shear zone
# 127  linear_500k.16769     16769         Fault or shear zone
# 128  linear_500k.16816     16816         Fault or shear zone
# 129  linear_500k.16825     16825         Fault or shear zone
# 130  linear_500k.16878     16878         Fault or shear zone
# 131  linear_500k.16896     16896         Fault or shear zone
# 132  linear_500k.17182     17182         Fault or shear zone
# 133  linear_500k.17031     17031  Fault or shear zone, major
#
#                                                   type  \
# 0                                              exposed
# 1                                              exposed
# 2                                              exposed
# 3                                              exposed
# 4                                              exposed
# 5                                              exposed
# 6             normal, exposed, tick on downthrown side
# 7                                   anticline, exposed
# 8                                   anticline, exposed
# 9                                   anticline, exposed
# 10                                  anticline, exposed
# 11                                  anticline, exposed
# 12                                   syncline, exposed
# 13                                   syncline, exposed
# 14                                   syncline, exposed
# 15                                   syncline, exposed
# 16                                   syncline, exposed
# 17                                   syncline, exposed
# 18                                   syncline, exposed
# 19                                   syncline, exposed
# 20                                   syncline, exposed
# 21                                   syncline, exposed
# 22                                   syncline, exposed
# 23                                             exposed
# 24                                             exposed
# 25                                             exposed
# 26                                             exposed
# 27   strike-slip, exposed, showing relative dextral...
# 28                                             exposed
# 29                                             exposed
# ..                                                 ...
# 104                                            exposed
# 105                                            exposed
# 106                                            exposed
# 107                                  syncline, exposed
# 108                                  syncline, exposed
# 109                                  syncline, exposed
# 110                                            exposed
# 111                                            exposed
# 112                                            exposed
# 113                                            exposed
# 114                                            exposed
# 115                                            exposed
# 116                                            exposed
# 117                                            exposed
# 118                                            exposed
# 119                                            exposed
# 120                                            exposed
# 121                                            exposed
# 122                                            exposed
# 123                                            exposed
# 124                                            exposed
# 125                                            exposed
# 126                                            exposed
# 127                                            exposed
# 128                                            exposed
# 129                                            exposed
# 130                                            exposed
# 131                                            exposed
# 132                                            exposed
# 133                                            exposed
#
#                         fname  code  dip dip_est dip_dir  plunge plunge_est  \
# 0                Coppin Fault  None    0    None    None       0       None
# 1            Karra Well Fault  None    0    None    None       0       None
# 2       Mithgoondy Shear Zone  None    0    None    None       0       None
# 3                 Moona Fault  None    0    None    None       0       None
# 4             Soda Well Fault  None    0    None    None       0       None
# 5             Soda Well Fault  None    0    None    None       0       None
# 6       Southern Batter Fault  None    0    None    None       0       None
# 7                Bellary Dome  None    0    None    None       0       None
# 8          Jeerinah Anticline  None    0    None    None       0       None
# 9    Meteorite Bore Anticline  None    0    None    None       0       None
# 10           Milli Milli Dome  None    0    None    None       0       None
# 11               Rocklea Dome  None    0    None    None       0       None
# 12                       None  None    0    None    None       0       None
# 13         Boolgeeda Syncline  None    0    None    None       0       None
# 14         Boolgeeda Syncline  None    0    None    None       0       None
# 15            Hardey Syncline  None    0    None    None       0       None
# 16            Hardey Syncline  None    0    None    None       0       None
# 17            Hardey Syncline  None    0    None    None       0       None
# 18         Panhandle Syncline  None    0    None    None       0       None
# 19         Panhandle Syncline  None    0    None    None       0       None
# 20       Silvergrass Syncline  None    0    None    None       0       None
# 21            Turner Syncline  None    0    None    None       0       None
# 22      Yandicoogina Syncline  None    0    None    None       0       None
# 23                       None  None    0    None    None       0       None
# 24                       None  None    0    None    None       0       None
# 25                       None  None    0    None    None       0       None
# 26                       None  None    0    None    None       0       None
# 27          Nanjilgardy Fault  None    0    None    None       0       None
# 28                       None  None    0    None    None       0       None
# 29                       None  None    0    None    None       0       None
# ..                        ...   ...  ...     ...     ...     ...        ...
# 104                      None  None    0    None    None       0       None
# 105                      None  None    0    None    None       0       None
# 106                      None  None    0    None    None       0       None
# 107                      None  None    0    None    None       0       None
# 108                      None  None    0    None    None       0       None
# 109                      None  None    0    None    None       0       None
# 110                      None  None    0    None    None       0       None
# 111                      None  None    0    None    None       0       None
# 112                      None  None    0    None    None       0       None
# 113                      None  None    0    None    None       0       None
# 114                      None  None    0    None    None       0       None
# 115                      None  None    0    None    None       0       None
# 116                      None  None    0    None    None       0       None
# 117                      None  None    0    None    None       0       None
# 118                      None  None    0    None    None       0       None
# 119                      None  None    0    None    None       0       None
# 120                      None  None    0    None    None       0       None
# 121                      None  None    0    None    None       0       None
# 122                      None  None    0    None    None       0       None
# 123                      None  None    0    None    None       0       None
# 124                      None  None    0    None    None       0       None
# 125                      None  None    0    None    None       0       None
# 126                      None  None    0    None    None       0       None
# 127                      None  None    0    None    None       0       None
# 128                      None  None    0    None    None       0       None
# 129                      None  None    0    None    None       0       None
# 130                      None  None    0    None    None       0       None
# 131                      None  None    0    None    None       0       None
# 132                      None  None    0    None    None       0       None
# 133                      None  None    0    None    None       0       None
#
#     plunge_dir max_age_ev min_age_ev  \
# 0         None       None       None
# 1         None       None       None
# 2         None       None       None
# 3         None       None       None
# 4         None       None       None
# 5         None       None       None
# 6         None       None       None
# 7         None       None       None
# 8         None       None       None
# 9         None       None       None
# 10        None       None       None
# 11        None       None       None
# 12        None       None       None
# 13        None       None       None
# 14        None       None       None
# 15        None       None       None
# 16        None       None       None
# 17        None       None       None
# 18        None       None       None
# 19        None       None       None
# 20        None       None       None
# 21        None       None       None
# 22        None       None       None
# 23        None       None       None
# 24        None       None       None
# 25        None       None       None
# 26        None       None       None
# 27        None       None       None
# 28        None       None       None
# 29        None       None       None
# ..         ...        ...        ...
# 104       None       None       None
# 105       None       None       None
# 106       None       None       None
# 107       None       None       None
# 108       None       None       None
# 109       None       None       None
# 110       None       None       None
# 111       None       None       None
# 112       None       None       None
# 113       None       None       None
# 114       None       None       None
# 115       None       None       None
# 116       None       None       None
# 117       None       None       None
# 118       None       None       None
# 119       None       None       None
# 120       None       None       None
# 121       None       None       None
# 122       None       None       None
# 123       None       None       None
# 124       None       None       None
# 125       None       None       None
# 126       None       None       None
# 127       None       None       None
# 128       None       None       None
# 129       None       None       None
# 130       None       None       None
# 131       None       None       None
# 132       None       None       None
# 133       None       None       None
#
#                                                 symbol   extract_da  \
# 0                  Fault or shear zone, major; exposed  2016-06-29Z
# 1                  Fault or shear zone, major; exposed  2016-06-29Z
# 2                  Fault or shear zone, major; exposed  2016-06-29Z
# 3                  Fault or shear zone, major; exposed  2016-06-29Z
# 4                  Fault or shear zone, major; exposed  2016-06-29Z
# 5                  Fault or shear zone, major; exposed  2016-06-29Z
# 6    Fault or shear zone, major; normal, exposed, t...  2016-06-29Z
# 7                 Fold axial trace; anticline, exposed  2016-06-29Z
# 8                 Fold axial trace; anticline, exposed  2016-06-29Z
# 9                 Fold axial trace; anticline, exposed  2016-06-29Z
# 10                Fold axial trace; anticline, exposed  2016-06-29Z
# 11                Fold axial trace; anticline, exposed  2016-06-29Z
# 12                 Fold axial trace; syncline, exposed  2016-06-29Z
# 13                 Fold axial trace; syncline, exposed  2016-06-29Z
# 14                 Fold axial trace; syncline, exposed  2016-06-29Z
# 15                 Fold axial trace; syncline, exposed  2016-06-29Z
# 16                 Fold axial trace; syncline, exposed  2016-06-29Z
# 17                 Fold axial trace; syncline, exposed  2016-06-29Z
# 18                 Fold axial trace; syncline, exposed  2016-06-29Z
# 19                 Fold axial trace; syncline, exposed  2016-06-29Z
# 20                 Fold axial trace; syncline, exposed  2016-06-29Z
# 21                 Fold axial trace; syncline, exposed  2016-06-29Z
# 22                 Fold axial trace; syncline, exposed  2016-06-29Z
# 23                        Fault or shear zone; exposed  2016-06-29Z
# 24                        Fault or shear zone; exposed  2016-06-29Z
# 25                        Fault or shear zone; exposed  2016-06-29Z
# 26                        Fault or shear zone; exposed  2016-06-29Z
# 27   Fault or shear zone, major; strike-slip, expos...  2016-06-29Z
# 28                        Fault or shear zone; exposed  2016-06-29Z
# 29                        Fault or shear zone; exposed  2016-06-29Z
# ..                                                 ...          ...
# 104                       Fault or shear zone; exposed  2016-06-29Z
# 105                       Fault or shear zone; exposed  2016-06-29Z
# 106                       Fault or shear zone; exposed  2016-06-29Z
# 107                Fold axial trace; syncline, exposed  2016-06-29Z
# 108                Fold axial trace; syncline, exposed  2016-06-29Z
# 109                Fold axial trace; syncline, exposed  2016-06-29Z
# 110                       Fault or shear zone; exposed  2016-06-29Z
# 111                       Fault or shear zone; exposed  2016-06-29Z
# 112                       Fault or shear zone; exposed  2016-06-29Z
# 113                       Fault or shear zone; exposed  2016-06-29Z
# 114                       Fault or shear zone; exposed  2016-06-29Z
# 115                       Fault or shear zone; exposed  2016-06-29Z
# 116                       Fault or shear zone; exposed  2016-06-29Z
# 117                       Fault or shear zone; exposed  2016-06-29Z
# 118                       Fault or shear zone; exposed  2016-06-29Z
# 119                       Fault or shear zone; exposed  2016-06-29Z
# 120                       Fault or shear zone; exposed  2016-06-29Z
# 121                       Fault or shear zone; exposed  2016-06-29Z
# 122                       Fault or shear zone; exposed  2016-06-29Z
# 123                       Fault or shear zone; exposed  2016-06-29Z
# 124                       Fault or shear zone; exposed  2016-06-29Z
# 125                       Fault or shear zone; exposed  2016-06-29Z
# 126                       Fault or shear zone; exposed  2016-06-29Z
# 127                       Fault or shear zone; exposed  2016-06-29Z
# 128                       Fault or shear zone; exposed  2016-06-29Z
# 129                       Fault or shear zone; exposed  2016-06-29Z
# 130                       Fault or shear zone; exposed  2016-06-29Z
# 131                       Fault or shear zone; exposed  2016-06-29Z
# 132                       Fault or shear zone; exposed  2016-06-29Z
# 133                Fault or shear zone, major; exposed  2016-06-29Z
#
#      shape_leng                                           geometry
# 0      1.147117  (LINESTRING (568748.86295698 7497204.91630132,...
# 1      0.696075  (LINESTRING (548218.22807501 7450974.94948044,...
# 2      0.215472  (LINESTRING (524662.73130987 7480154.44913802,...
# 3      0.344530  (LINESTRING (560124.94518343 7479717.8142949, ...
# 4      0.198193  (LINESTRING (523139.74494814 7465417.97509713,...
# 5      0.093382  (LINESTRING (508005.39376107 7478924.91334002,...
# 6      0.146770  (LINESTRING (581077.90917815 7480837.91895163,...
# 7      0.459385  (LINESTRING (585975.08114379 7433903.92577123,...
# 8      1.036114  (LINESTRING (557792.88912399 7526666.65256088,...
# 9      0.177212  (LINESTRING (513684.24943192 7462267.62915548,...
# 10     0.640846  (LINESTRING (632734.23064221 7467131.3688331, ...
# 11     0.643849  (LINESTRING (491235.35649548 7481249.65408026,...
# 12     0.487919  (LINESTRING (512228.58473766 7544025.14332257,...
# 13     0.449403  (LINESTRING (557303.57008435 7518646.23233708,...
# 14     0.428456  (LINESTRING (515738.88476599 7504353.4403226, ...
# 15     0.091381  (LINESTRING (538447.28899123 7462700.43897321,...
# 16     0.195950  (LINESTRING (510425.71485485 7467747.48946443,...
# 17     0.174071  (LINESTRING (529100.64007716 7462146.2026508, ...
# 18     0.252398  (LINESTRING (580783.05634832 7450101.05303508,...
# 19     0.090797  (LINESTRING (566344.85032215 7472880.09901163,...
# 20     0.514111  (LINESTRING (534123.7679221201 7566232.5027284...
# 21     0.487136  (LINESTRING (537771.61272498 7490461.123314, 5...
# 22     2.228898  (LINESTRING (554815.4335207 7551658.06563118, ...
# 23     0.023867  (LINESTRING (500126.3660744 7468790.72562249, ...
# 24     0.053997  (LINESTRING (512855.51947114 7465188.04146992,...
# 25     0.116558  (LINESTRING (544229.29847218 7451684.49182652,...
# 26     0.014250  (LINESTRING (505540.77669087 7467554.00325005,...
# 27     1.244480  (LINESTRING (405283.77423593 7511537.06802014,...
# 28     0.170901  (LINESTRING (521647.7793439 7467241.05086821, ...
# 29     0.022973  (LINESTRING (521224.2899599 7489118.45021574, ...
# ..          ...                                                ...
# 104    0.178653  (LINESTRING (520343.17884566 7501712.97896174,...
# 105    0.154477  (LINESTRING (546639.32683299 7512670.78252025,...
# 106    0.127692  (LINESTRING (509566.75673552 7514303.3448132, ...
# 107    0.122748  (LINESTRING (490604.67594707 7560184.10569923,...
# 108    0.211599  (LINESTRING (622787.02916309 7503075.39649346,...
# 109    0.202724  (LINESTRING (483136.66158302 7549077.72512207,...
# 110    0.071136  (LINESTRING (496014.68342019 7470546.57629222,...
# 111    0.236425  (LINESTRING (504095.73363437 7512570.3030599, ...
# 112    0.046464  (LINESTRING (595861.47994603 7473711.84675533,...
# 113    0.212933  (LINESTRING (595340.77997391 7475216.88087953,...
# 114    0.025759  (LINESTRING (586547.8474747 7485021.97982307, ...
# 115    0.019756  (LINESTRING (524248.58790062 7500447.0197916, ...
# 116    0.092350  (LINESTRING (515424.93267759 7509837.91858182,...
# 117    0.129957  (LINESTRING (520903.52083879 7460937.09038972,...
# 118    0.102555  (LINESTRING (556931.35087387 7494207.77888696,...
# 119    0.106503  (LINESTRING (556810.03934078 7496760.77135565,...
# 120    0.257608  (LINESTRING (498700.00943997 7474614.73994781,...
# 121    0.094357  (LINESTRING (502280.78031662 7478738.78911675,...
# 122    0.030933  (LINESTRING (503243.75836533 7467170.45419572,...
# 123    0.016659  (LINESTRING (504908.35120611 7468352.9612461, ...
# 124    0.401802  (LINESTRING (602600.12363018 7469187.86603131,...
# 125    0.076670  (LINESTRING (567074.71630619 7478240.92666188,...
# 126    0.043049  (LINESTRING (509082.58885467 7500793.86104241,...
# 127    0.061467  (LINESTRING (522459.5291779 7512088.52096737, ...
# 128    0.190173  (LINESTRING (515470.58119806 7469457.53161369,...
# 129    0.278089  (LINESTRING (531009.8393847001 7462104.4206943...
# 130    0.028579  (LINESTRING (529930.1291255601 7461072.9488118...
# 131    0.481484  (LINESTRING (554706.6693824501 7439143.8098673...
# 132    0.132747  (LINESTRING (509926.37931228 7471053.45986649,...
# 133    0.060543  (LINESTRING (518756.03529311 7451167.80519259,...
#
# [134 rows x 18 columns]

# %% [markdown]
# ## Clip geology, faults, structures and map geology to structures

# %%
geology = m2l_utils.explode(geology)
geology.crs = dst_crs
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows',None)
structure_code = gpd.sjoin(sub_pts, geology, how="left", op="within")

y_point_list = [miny, miny, maxy, maxy, miny]
x_point_list = [minx, maxx, maxx, minx, minx]

bbox_geom = Polygon(zip(x_point_list, y_point_list))

polygo = gpd.GeoDataFrame(index=[0], crs=dst_crs, geometry=[bbox_geom]) 

if(local_paths):
     is_bed=structure_code.FEATURE.str.contains(bedding_label, regex=False) #hardwires, needs if of local
else:
     is_bed=structure_code.feature.str.contains(bedding_label, regex=False) #hardwires, needs if of local
    
all_beds = structure_code[is_bed]

geol_clip=m2l_utils.clip_shp(geology, polygo)
faults_clip=m2l_utils.clip_shp(faults,polygo)
structure_clip = m2l_utils.clip_shp(all_beds, polygo)

base = geol_clip.plot(column=ccode,figsize=(7,7),edgecolor='#000000',linewidth=0.2)
faults_clip.plot(ax=base, column=tcode,edgecolor='black')
structure_clip.plot(ax=base, column=ccode,edgecolor='black')

geol_clip.to_file(tmp_path+'geol_clip.shp')
faults_clip.to_file(tmp_path+'faults_clip.shp')
structure_clip.to_file(tmp_path+'structure_clip.shp')

# %% [markdown]
# ## Create possible stratigraphy sets per group
# mj: <font color='red'>Uses first of each possible set of toplogies per unit and per group, which is arbitrary. </font>On the other hand we are not checking relative ages again to see if this helps reduce ambiguity, which I think it would.

# %%
m2l_topology.save_group(G,mname,tmp_path,glabels,geol_clip,ccode,gcode,mincode,maxcode)
# Out:
#    index               group_     min     max     ave
# 0      0          Wyloo_Group  1796.0  2008.0  1902.0
# 1      1  Shingle_Creek_Group  2031.0  2208.0  2119.5
# 2      2    Turee_Creek_Group  2208.0  2445.0  2326.5
# 3      3      Hamersley_Group  2445.0  2629.0  2537.0
# 4      4      Fortescue_Group  2629.0  2775.0  2702.0
# 5      5            A_mgn_PMI  2890.0  3225.0  3057.5
# 6      6            A_mgn_PRK  3221.0  3225.0  3223.0
# 7      7              A_s_PMI  3225.0  3530.0  3377.5
# 8      8              A_b_PRK  3225.0  3530.0  3377.5
# 9      9              A_s_PRK  3225.0  3530.0  3377.5
#                      index     min     max     ave
# group_
# Wyloo_Group              0  1796.0  2008.0  1902.0
# Shingle_Creek_Group      1  2031.0  2208.0  2119.5
# Turee_Creek_Group        2  2208.0  2445.0  2326.5
# Hamersley_Group          3  2445.0  2629.0  2537.0
# Fortescue_Group          4  2629.0  2775.0  2702.0
# A_mgn_PMI                5  2890.0  3225.0  3057.5
# A_mgn_PRK                6  3221.0  3225.0  3223.0
# A_s_PMI                  7  3225.0  3530.0  3377.5
# A_b_PRK                  8  3225.0  3530.0  3377.5
# A_s_PRK                  9  3225.0  3530.0  3377.5
# []
# P__WYm_sp
# P__WYa_s
# P__WYd_kd
# P__SKb_bb
# P__SKq_stq
# P__TKa_xs_k
# P__TKo_stq
# P__TKk_sf
# P__TK_s
# P__HAo_ci
# P__HAw_fr
# P__HAj_xci_od
# P__HAb_cib
# A_HAu_xsl_ci
# A_HAd_kd
# A_HAm_cib
# A_FOj_xs_b
# A_FO_xo_a
# A_FO_od
# A_FOu_bbo
# A_FOp_bs
# A_FOo_bbo
# A_FOh_xs_f
# A_FOr_b
# A_s_PMI
# A_mgn_PRK
# A_b_PRK
# A_s_PRK
# A_mgn_PMI

# %% [markdown]
# ## Export orientation data in csv  format
# mj: Orientation data needs calculated height as file does not provide it, taken from SRTM data already downloaded. To calculate polarity <font color='red'>(WHICH WE DON'T DO YET)</font> we can calculate the dot product of the dip direction of a bedding plane and the vector to that points nearest basal contact node, if  abs(acos(dot product))>90  then right way up :
#
# <img src='../graphics/polarity.png'>
#
# Added code to not save intrusion orientation data as they won't have associated surfaces if sill...

# %%
dtm = rasterio.open(dtm_reproj_file)
m2l_geometry.save_orientations(structure_code,mname,output_path,ddcode,dcode,ccode,r1code,intrusive_label,orientation_decimate,dtm)
# Out:
# 169 orientations saved to ../test_data3/output//hams3_orientations.csv

# %% [markdown]
# ## Find those series that don't have any orientation or contact point data  then create arbitrary point for series with no orientation data
# Not sure if gempy needs this but geomodeller does. Currently just gives a point dipping 45 degrees to North, but could use dip direction normal to basal surface)

# %%
m2l_geometry.create_orientations(mname, tmp_path, output_path, dtm,geol_clip,structure_clip,ccode,gcode,r1code,intrusive_label)
# Out:
# Orientations----------
#  10 [('Wyloo_Group', 1), ('Shingle_Creek_Group', 1), ('Turee_Creek_Group', 1), ('Hamersley_Group', 1), ('Fortescue_Group', 1), ('A_s_PMI', 1), ('A_mgn_PRK', 0), ('A_b_PRK', 1), ('A_s_PRK', 0), ('A_mgn_PMI', 1)]
# Contacts----------
#  29 {'A-FOh-xs-f', 'A-s-PRK', 'A-FOo-bbo', 'P_-TK-s', 'P_-WYa-s', 'P_-SKq-stq', 'A-HAm-cib', 'A-mgn-PRK', 'A-FOr-b', 'P_-HAw-fr', 'P_-TKa-xs-k', 'A-FOp-bs', 'P_-WYd-kd', 'A-FOu-bbo', 'A-FOj-xs-b', 'A-s-PMI', 'P_-TKo-stq', 'P_-SKb-bb', 'P_-HAj-xci-od', 'A-b-PRK', 'A-FO-xo-a', 'A-HAd-kd', 'P_-HAb-cib', 'P_-HAo-ci', 'P_-TKk-sf', 'A-HAu-xsl-ci', 'A-FO-od', 'A-mgn-PMI', 'P_-WYm-sp'}
# extra orientations saved as ../test_data3/output//hams3_empty_series_orientations.csv

# %% [markdown]
# ## Export contact information subset of each polygon to gempy format
# mj: Orientation data needs calculated height as file does not provide it, taken from SRTM data already downloaded. Need to reduce number of points whilst retaining useful info (Ranee's job!)'
# To calculate which are the basal units contact for a polygon find the polygons which are older than the selected polygon, in the example below the central polygon has relative age 23 so its basal contact is with the polygons whose ages are 26 & 28. If there are no older units for a polygon it has no basal content. We keep every nth node based on the decimate term (simple count along polyline). gempy seems to need at least two points per surface, so we always take the first two points.
#
# <font color='red'>Needs also to account for case when missing surface in stratigraphy means that locally basal polyline can ALSO be anothe rthan youngest surface.</font>
# <img src='../graphics/base.png'>

# %%
ls_dict,ls_dict_decimate=m2l_geometry.save_basal_contacts(mname,tmp_path,dtm,geol_clip,contact_decimate,ccode,gcode,ocode,dscode,r1code,intrusion_mode)
# Out:
# decimation: 1 / 5
# surfaces: 30
# polygons: 206
# [[1, 'P__WYm_sp'], [2, 'P__WYa_s'], [3, 'P__WYd_kd'], [4, 'P__SKb_bb'], [5, 'P__SKq_stq'], [6, 'P__TKa_xs_k'], [7, 'P__TKo_stq'], [8, 'P__TKk_sf'], [9, 'P__TK_s'], [10, 'P__HAo_ci'], [11, 'P__HAw_fr'], [12, 'P__HAj_xci_od'], [13, 'P__HAb_cib'], [14, 'A_HAu_xsl_ci'], [15, 'A_HAd_kd'], [16, 'A_HAm_cib'], [17, 'A_FOj_xs_b'], [18, 'A_FO_xo_a'], [19, 'A_FO_od'], [20, 'A_FOu_bbo'], [21, 'A_FOp_bs'], [22, 'A_FOo_bbo'], [23, 'A_FOh_xs_f'], [24, 'A_FOr_b'], [25, 'A_s_PMI'], [26, 'A_mgn_PRK'], [27, 'A_b_PRK'], [28, 'A_s_PRK'], [29, 'A_mgn_PMI']]
# BoundingBox(left=500000.0000000026, bottom=7454093.693147668, right=605065.852135498, top=7567173.042479938)
# basal contacts saved allpts= 9339 deci_pts= 2283
# saved as ../test_data3/tmp/hams3_all_contacts.csv and ../test_data3/tmp/hams3_contacts.csv

# %% [markdown]
# ## Remove all basal contacts that are defined by faults and save to shapefile (no decimation)

# %%
m2l_geometry.save_basal_no_faults(mname,tmp_path+'basal_contacts2.shp',tmp_path+'faults_clip.shp',ls_dict,10,ccode,gcode,dst_crs)
# Out:
# (207,)
# basal contacts without faults saved as ../test_data3/tmp/basal_contacts2.shp

# %% [markdown]
# ## Remove faults from decimated basal contacts as save as csv file

# %%
m2l_geometry.save_contacts_with_faults_removed(mname,tmp_path+'faults_clip.shp',output_path,10,ls_dict,ls_dict_decimate,ccode,dst_crs,dtm)
# Out:
# undecimated points: 2283
# 1974 decimated contact points saved as ../test_data3/output//hams3_contacts4.csv

# %% [markdown]
# ## Save fault as contact info and and orientation info make vertical (for the moment)

# %%
m2l_geometry.save_faults(mname,tmp_path+'faults_clip.shp',output_path,dtm,ncode,ocode,fcode,fault_decimate)
m2l_topology.parse_fault_relationships(graph_path,tmp_path,output_path)
# Out:
# fault orientations saved as ../test_data3/output/hams3_fault_orientations.csv
# fault positions saved as ../test_data3/output/hams3_faults.csv
# fault dimensions saved as ../test_data3/output/hams3_fault_dimensions.csv
# fault-fault, fault-group and fault-unit relationship tables saved as:
# ../test_data3/output/fault-fault-relationships.csv
# ../test_data3/output/group-fault-relationships.csv
# ../test_data3/output/unit-fault-relationships.csv

# %% [markdown]
# ## Create basal contact points with orientation from orientations and basal points

# %%
contacts = gpd.read_file(tmp_path+'basal_contacts2.shp') #load orientation data as geopandas dataframe 
structures = gpd.read_file(tmp_path+'structure_clip.shp') #load orientation data as geopandas dataframe 

m2l_geometry.create_basal_contact_orientations(mname,contacts,structures,output_path,dtm,2500,ccode,gcode,dcode,ddcode)
# Out:
# basal contact orientations saved as ../test_data3/output/hams3_projected_dip_contacts2.csv

# %% [markdown]
# ## Creates fold axial trace points

# %%
m2l_geometry.save_fold_axial_traces(mname,tmp_path+'faults_clip.shp',output_path,dtm,ocode,tcode,fcode,fold_decimate)
# Out:
# fold axial traces saved as ../test_data3/output/hams3_fold_axial_traces.csv

# %% [markdown]
# ## Process plutons
#
# For each instruve but not sill polygon, find older neighbours and store decimated contact points. Also store dipping contact orientations (user defined, just because) with three possible sub-surface configurations:
#
# <b>saucers: \\_____/ <br>
# pancakes: /_____\\
# domes: /‾\\</b>
#
# Saves out orientations and contact points, as well as updated group level stratigraphic column.<br>
# Doesn't account for faults yet...

# %%
import matplotlib
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
from urllib.request import urlopen
import numpy as np
from matplotlib.pyplot import imshow
import rasterio
from rasterio.transform import from_origin
from rasterio import features
# %matplotlib inline
import sys, os
from map2loop import m2l_utils
import geopandas as gpd
import pandas as pd
from math import acos, sqrt, cos, sin, degrees, radians, fabs, atan2
from shapely.geometry import shape, Polygon, LineString, Point
## import geopandas as gpd
#os.chdir('..')

print(os.getcwd())
# Out:
# C:\Users\00073294\Dropbox\1_Jupyter_notebooks\map2loop\map2loop

# %%
#%run -i "../test_data3/m2l_config.py"
bbox=(minx,miny,maxx,maxy)

pluton_dip=str(pluton_dip)

dist_buffer=10

# %%
test_data_path='../test_data3/'


#%run -i "../test_data3/m2l_config.py"


#geology = gpd.read_file(data_path+'hams2_geol.shp',bbox=bbox)
#print(geology.crs)

#geol_explode=m2l_utils.explode(geology)
#print(geology.shape, geol_explode.shape)
#roi = gpd.read_file(data_path+'hamms_roi.shp')

#geol_clip=m2l_utils.clip_shp(geol_explode,roi)


dtm_reproj_file=dtm_path+'hams3_dtm_rp.tif'

dtm = rasterio.open(dtm_reproj_file)

# %%
m2l_geometry.process_plutons(tmp_path,output_path,geol_clip,local_paths,dtm,sill_label,pluton_form,pluton_dip,intrusive_label,contact_decimate,mincode,maxcode,ccode,gcode,ocode,r1code,dscode)
# Out:
# 0 Wyloo_Group
# 1 Shingle_Creek_Group
# 2 Turee_Creek_Group
# 3 Hamersley_Group
# 4 Fortescue_Group
# 5 A_s_PMI
# 6 A_mgn_PRK
# 7 A_b_PRK
# 8 A_s_PRK
# 9 A_mgn_PMI
# False
# ../test_data3/output/ign_orientations_saucers.csv
# 10 A_mgn_PMI_7366
# 11 A_mgn_PRK_16193
# 0 Wyloo_Group
# 1 Shingle_Creek_Group
# 2 Turee_Creek_Group
# 3 Hamersley_Group
# 4 Fortescue_Group
# 5 A_s_PMI
# 6 A_mgn_PRK
# 7 A_b_PRK
# 8 A_s_PRK
# 9 A_mgn_PMI
# 10 A_mgn_PMI_7366
# 11 A_mgn_PRK_16193
# pluton contacts and orientations saved as:
# ../test_data3/output/ign_contacts.csv
# ../test_data3/output/ign_orientations_saucers.csv

# %% [markdown]
# ## Interpolates a regular grid of orientations from an  shapefile of arbitrarily-located points and saves out four csv files of l,m & n direction cosines and dip dip direction data
#
# Can choose between various RBF and IDW options
#
# The purpose of Notebooks 4,5,6 and associated code is to help in three cases:
# - Providing estimated dips and contacts in fault-bounded domains where no structural data are available
# - Needed to estimate true thickness of formations
# - Possibly useful for poulating parts of maps where little structural data is available

# %%
from map2loop import m2l_interpolation
from map2loop import m2l_utils

this_gcode=('Hamersley Group','Fortescue Group','Turee Group','Shingle Creek Group','Wyloo Group')
structure_file=tmp_path+'structure_clip.shp'
bbox=(minx+inset,miny+inset,maxx-inset,maxy-inset)

# %%
print(gcode)
# Out:
# group_

# %%
m2l_interpolation.interpolate_orientations(structure_file,tmp_path,bbox,dcode,ddcode,gcode,this_gcode,scheme,gridx,gridy)
# Out:
# ../test_data3/tmp/structure_clip.shp ../test_data3/tmp/ (500057, 7455348, 603028, 7567953) dip dip_dir group_ ('Hamersley Group', 'Fortescue Group', 'Turee Group', 'Shingle Creek Group', 'Wyloo Group') scipy_rbf 50 50
# orientations interpolated as dip dip direction ../test_data3/tmp/interpolation_scipy_rbf.csv
# orientations interpolated as l,m,n dir cos ../test_data3/tmp/interpolation_l.csv etc.

# %% [markdown]
# ## Interpolates a regular grid from a shapefile of from contacts and saves out three csv files of l & m direction cosines and strike data
#
# Can choose between various RBF and IDW options
#
# <font face color='red'>Best with basal contacts only, using Notebook #1 as this avoids intrusive  and fault contacts being considered</font>

# %%
geology_file=tmp_path+'basal_contacts2.shp'

dtm = rasterio.open(dtm_reproj_file)

# %%
m2l_interpolation.interpolate_contacts(geology_file,tmp_path,dtm,bbox,dcode,ddcode,gcode,ccode,scheme,gridx,gridy)
# Out:
# ../test_data3/tmp/basal_contacts2.shp ../test_data3/tmp/ (500057, 7455348, 603028, 7567953) dip dip_dir group_ scipy_rbf 50 50
# 176
# 6856 1328.7966407308122 525.2523567890748
# 8758 682.2054117958178 500.3340552216396
# contacts interpolated as strike ../test_data3/tmp/interpolation_contacts_scipy_rbf.csv
# contacts interpolated as l,m dir cos ../test_data3/tmp/interpolation_contacts_l.csv etc.

# %% [markdown]
# ## Combines rbf of contact orientations with rbf of dip/dipdir measurements
#
# Uses normalised direction cosines **(l,m,n)**:
# - **l,m** from RBF of basal contact orientations
# - **signs of l & m** from misorientation with RBF of orientation data and
# - **n** from RBF of orientation data
#
# May be useful for adding data where no orientations are available (e.g. in fault bounded domains) and for calculating true thickness of layers. Assumes a 2D plane of data, but if 3D RBF was calulated and projected contact info was used it should apply with topography too.

# %%
geology_file=tmp_path+'geol_clip.shp'
combo_file=tmp_path+'combo.csv'

lc=np.loadtxt(tmp_path+'interpolation_contacts_l.csv',skiprows =1,delimiter =',',dtype=float)
mc=np.loadtxt(tmp_path+'interpolation_contacts_m.csv',skiprows =1,delimiter =',',dtype=float)
lo=np.loadtxt(tmp_path+'interpolation_l.csv',skiprows =1,delimiter =',',dtype=float)
mo=np.loadtxt(tmp_path+'interpolation_m.csv',skiprows =1,delimiter =',',dtype=float)
no=np.loadtxt(tmp_path+'interpolation_n.csv',skiprows =1,delimiter =',',dtype=float)
xy=np.loadtxt(tmp_path+'interpolation_'+scheme+'.csv',skiprows =1,delimiter =',',dtype=float)

# %%
m2l_interpolation.join_contacts_and_orientations(combo_file,geology_file,tmp_path,dtm_reproj_file,ccode,lo,mo,no,lc,mc,xy,dst_crs,bbox)
# Out:
# {'init': 'EPSG:28350'} None
# C:\Users\00073294\AppData\Local\Continuum\anaconda3\lib\site-packages\geopandas\tools\sjoin.py:44: UserWarning: CRS of frames being joined does not match!
#   warn('CRS of frames being joined does not match!')
# contacts and orientations interpolated as dip dip direction ../test_data3/tmp/combo_full.csv

# %% [markdown]
# # gempy test
#
#
# ## Convert stratigraphy GML to time-sorted groups and units
#
#
# Takes GML file produced by topology code, geology polygons, structure points and dtm to create 3D model.<br><br>
# Limitations: no faults yet, no plutons yet, no dykes, no sills. Faults and plutons will come soon, sills require us to assign a unique surface to each instance of a sill (sill between units A and B needs to be different from sill of same age and strat codes as one found between E and F). Dykes via cokriging are really hard without just cookie cutting them in (but that is not our problem!). We are not checking for onlap relationships, which can perhaps been seen by having lots of units from one series adjacent to the youngest surface of the older series. Could also think about interpreting these as faults to introduce conceptual uncertainty.
#
# <font face color='red'>The way this loads data to gempy is not right, so all the units end up in one series... but it gives the basic idea </font>

# %%
import matplotlib
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
from urllib.request import urlopen
import numpy as np
import pandas as pd
from matplotlib.pyplot import imshow
from matplotlib import pyplot as plt
import os
import rasterio
from rasterio.transform import from_origin
from rasterio import features
# %matplotlib inline
import sys, os
print(os.getcwd())

os.chdir('../map2loop')
import m2l_utils
print(os.getcwd())
#os.chdir('../')
# Out:
# C:\Users\00073294\Dropbox\1_Jupyter_notebooks\map2loop\map2loop
# C:\Users\00073294\Dropbox\1_Jupyter_notebooks\map2loop\map2loop

# %% [markdown]
# ## Preprocess data to ensure it meets gempy's requirements

# %%
m2l_geometry.tidy_data(mname)
# Out:
#                  index  group number  index in group  number in group  \
# code
# A_mgn_PMI_7366      29            11               1                1
# A_mgn_PRK_16193     30            12               1                1
# P__WYm_sp            0             1               1                3
# P__WYa_s             1             1               2                3
# P__WYd_kd            2             1               3                3
# P__SKb_bb            3             2               1                2
# P__SKq_stq           4             2               2                2
# P__TKa_xs_k          5             3               1                4
# P__TKo_stq           6             3               2                4
# P__TKk_sf            7             3               3                4
# P__TK_s              8             3               4                4
# P__HAo_ci            9             4               1                7
# P__HAw_fr           10             4               2                7
# P__HAj_xci_od       11             4               3                7
# P__HAb_cib          12             4               4                7
# A_HAu_xsl_ci        13             4               5                7
# A_HAd_kd            14             4               6                7
# A_HAm_cib           15             4               7                7
# A_FOj_xs_b          16             5               1                8
# A_FO_xo_a           17             5               2                8
# A_FO_od             18             5               3                8
# A_FOu_bbo           19             5               4                8
# A_FOp_bs            20             5               5                8
# A_FOo_bbo           21             5               6                8
# A_FOh_xs_f          22             5               7                8
# A_FOr_b             23             5               8                8
# A_s_PMI             24             6               1                1
# A_mgn_PRK           25             7               1                1
# A_b_PRK             26             8               1                1
# A_s_PRK             27             9               1                1
# A_mgn_PMI           28            10               1                1
#
#                                group
# code
# A_mgn_PMI_7366        A_mgn_PMI_7366
# A_mgn_PRK_16193      A_mgn_PRK_16193
# P__WYm_sp                Wyloo_Group
# P__WYa_s                 Wyloo_Group
# P__WYd_kd                Wyloo_Group
# P__SKb_bb        Shingle_Creek_Group
# P__SKq_stq       Shingle_Creek_Group
# P__TKa_xs_k        Turee_Creek_Group
# P__TKo_stq         Turee_Creek_Group
# P__TKk_sf          Turee_Creek_Group
# P__TK_s            Turee_Creek_Group
# P__HAo_ci            Hamersley_Group
# P__HAw_fr            Hamersley_Group
# P__HAj_xci_od        Hamersley_Group
# P__HAb_cib           Hamersley_Group
# A_HAu_xsl_ci         Hamersley_Group
# A_HAd_kd             Hamersley_Group
# A_HAm_cib            Hamersley_Group
# A_FOj_xs_b           Fortescue_Group
# A_FO_xo_a            Fortescue_Group
# A_FO_od              Fortescue_Group
# A_FOu_bbo            Fortescue_Group
# A_FOp_bs             Fortescue_Group
# A_FOo_bbo            Fortescue_Group
# A_FOh_xs_f           Fortescue_Group
# A_FOr_b              Fortescue_Group
# A_s_PMI                      A_s_PMI
# A_mgn_PRK                  A_mgn_PRK
# A_b_PRK                      A_b_PRK
# A_s_PRK                      A_s_PRK
# A_mgn_PMI                  A_mgn_PMI
# {'A_b_PRK', 'A_s_PRK', 'A_mgn_PRK_16193', 'Turee_Creek_Group', 'Wyloo_Group', 'Hamersley_Group', 'Fortescue_Group', 'A_s_PMI', 'A_mgn_PMI_7366', 'Shingle_Creek_Group', 'A_mgn_PMI', 'A_mgn_PRK'}
# no contacts for the group: A_b_PRK
# no contacts for the group: A_s_PRK
# no contacts for the group: A_s_PMI
# no contacts for the group: A_mgn_PMI
# no contacts for the group: A_mgn_PRK
# no contacts for the group: A_s_PMI
# no contacts for the group: A_mgn_PRK
# no contacts for the group: A_b_PRK
# no contacts for the group: A_s_PRK
# no contacts for the group: A_mgn_PMI
# ['A_s_PMI', 'A_mgn_PRK', 'A_b_PRK', 'A_s_PRK', 'A_mgn_PMI']
# dud orientation: P__WYd_kd
# dud orientation: P__WYd_kd
# dud orientation: A_s_PRK
# dud orientation: A_s_PRK
# dud orientation: A_s_PRK
# dud orientation: A_s_PRK
# dud orientation: A_s_PRK
# dud orientation: A_b_PRK
# dud orientation: A_s_PMI
# dud orientation: A_s_PMI
# dud orientation: A_s_PMI
# dud orientation: A_s_PMI
# dud orientation: A_s_PRK
# dud orientation: A_s_PRK
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: P__WYd_kd
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: P__WYd_kd
# dud orientation: A_FO_od
# dud orientation: P__WYd_kd
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_mgn_PRK
# dud orientation: A_mgn_PRK
# dud orientation: A_mgn_PRK
# dud orientation: A_mgn_PRK
# dud orientation: A_FO_od
# dud orientation: A_s_PRK
# dud orientation: A_mgn_PRK
# dud orientation: A_mgn_PRK
# dud orientation: A_FO_od
# dud orientation: A_mgn_PRK
# dud orientation: A_mgn_PRK
# dud orientation: A_mgn_PRK
# dud orientation: A_FO_od
# dud orientation: A_s_PRK
# dud orientation: A_mgn_PRK
# dud orientation: A_mgn_PRK
# dud orientation: A_mgn_PRK
# dud orientation: A_mgn_PRK
# dud orientation: A_b_PRK
# dud orientation: A_mgn_PRK
# dud orientation: A_s_PRK
# dud orientation: A_mgn_PRK
# dud orientation: A_mgn_PRK
# dud orientation: A_mgn_PRK
# dud orientation: A_mgn_PRK
# dud orientation: A_mgn_PRK
# dud orientation: A_mgn_PRK
# dud orientation: A_mgn_PRK
# dud orientation: A_mgn_PRK
# dud orientation: A_s_PRK
# dud orientation: A_b_PRK
# dud orientation: A_FO_xo_a
# dud orientation: A_FO_xo_a
# dud orientation: A_FO_xo_a
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_xo_a
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_xo_a
# dud orientation: A_FO_xo_a
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_xo_a
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_xo_a
# dud orientation: A_FO_xo_a
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_xo_a
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_FO_xo_a
# dud orientation: A_s_PMI
# dud orientation: A_FO_od
# dud orientation: A_s_PMI
# dud orientation: A_FO_od
# dud orientation: A_FO_od
# dud orientation: A_s_PMI
# dud orientation: A_mgn_PMI
# dud orientation: A_s_PMI

# %% [markdown]
# ## Now we define the basic model and load the orientation and lithological information
# mj: We inset the model dimensions as once reprojects the edge pixels of the topography are undefined. Probably doesn't need to be that extreme (unit is metres). Could use parameter <b>maxtopo</b> to

# %%
import gempy as gp
import numpy as np
import matplotlib.pyplot as plt
import os
geo_model = gp.create_model('gp_test')

gp.init_data(geo_model, extent=[502536, 600652, 7.458e6, 7.56e6, -8800, 1200],
    resolution = (50,50,50), 
      #path_o = './test_data/output/hams2_orientations.txt',
      path_o = '../test_data3/output/hams3_orientations_clean.csv',
      path_i = '../test_data3/output/hams3_contacts_clean.csv', default_values=True); #%%      
      #path_o = './test_data3/output/ign_orientations_saucers.csv',
      #path_i = './test_data3/output/ign_contacts.csv', default_values=True); #%%
# Out:
# Active grids: ['regular']

# %% [markdown]
# ## Show example lithological points

# %%
gp.get_data(geo_model, 'surface_points').head()
# Out:
#                X             Y    Z       X_r       Y_r       Z_r  \
# 0  595340.779974  7.475217e+06  671  0.695983  0.338961  0.500035
# 1  598761.529573  7.475077e+06  689  0.711282  0.338337  0.500116
# 2  599690.780193  7.475238e+06  674  0.715437  0.339055  0.500049
# 3  601532.969011  7.474814e+06  638  0.723676  0.337159  0.499888
# 4  602892.489648  7.474514e+06  629  0.729757  0.335817  0.499847
#
#           surface          series  id  order_series        smooth
# 0  A_mgn_PMI_7366  Default series   1             1  1.000000e-08
# 1  A_mgn_PMI_7366  Default series   1             1  1.000000e-08
# 2  A_mgn_PMI_7366  Default series   1             1  1.000000e-08
# 3  A_mgn_PMI_7366  Default series   1             1  1.000000e-08
# 4  A_mgn_PMI_7366  Default series   1             1  1.000000e-08

# %% [markdown]
# ## Show example orientations

# %%
gp.get_data(geo_model, 'orientations').head()
# Out:
#                  X             Y    Z       X_r       Y_r       Z_r       G_x  \
# 156  595340.779974  7.475217e+06  671  0.695983  0.338961  0.500035  0.043481
# 157  598761.529573  7.475077e+06  689  0.711282  0.338337  0.500116  0.120356
# 158  599690.780193  7.475238e+06  674  0.715437  0.339055  0.500049 -0.047065
# 159  601532.969011  7.474814e+06  638  0.723676  0.337159  0.499888 -0.135025
# 160  602892.489648  7.474514e+06  629  0.729757  0.335817  0.499847 -0.234711
#
#           G_y       G_z   dip     azimuth  polarity         surface  \
# 156 -0.705769  0.707107  45.0  176.474571       1.0  A_mgn_PMI_7366
# 157 -0.696789  0.707107  45.0  170.199991       1.0  A_mgn_PMI_7366
# 158 -0.705539  0.707107  45.0  183.816438       1.0  A_mgn_PMI_7366
# 159 -0.694095  0.707107  45.0  191.008468       1.0  A_mgn_PMI_7366
# 160 -0.667016  0.707107  45.0  199.386032       1.0  A_mgn_PMI_7366
#
#              series  id  order_series  smooth
# 156  Default series   1             1    0.01
# 157  Default series   1             1    0.01
# 158  Default series   1             1    0.01
# 159  Default series   1             1    0.01
# 160  Default series   1             1    0.01

# %% [markdown]
# ## Plot some of this data

# %%
# %matplotlib inline
gp.plot.plot_data(geo_model, direction='z');

# %% [markdown]
# ## Load reprojected topgraphy to model

# %%
fp = '../test_data3/dtm/hams3_dtm_rp.tif'
geo_model.set_topography(source='gdal',filepath=fp)

## Load stratigraphic Series

f=open('../test_data3/tmp/hams3_groups_clean.csv',"r")
contents =f.readlines()
f.close


faults = gp.Faults()
series = gp.Series(faults)
series.df

ngroups=contents[0].split(" ")
ngroups=int(ngroups[1])
groups=[]

for i in range (1,int(ngroups)+1):
    groups.append(contents[i].replace("\n",""))
    series.add_series(contents[i].replace("\n",""))
    print(contents[i].replace("\n",""))

series.delete_series('Default series')

series
# Out:
# Cropped raster to geo_model.grid.extent.
# [ 502536  600652 7458000 7560000] [115 110]
# storing converted file...
# Active grids: ['regular' 'topography']
# A_mgn_PMI_7366
# A_mgn_PRK_16193
# Wyloo_Group
# Shingle_Creek_Group
# Turee_Creek_Group
# Hamersley_Group
# Fortescue_Group
#                      order_series BottomRelation
# A_mgn_PMI_7366                  1        Erosion
# A_mgn_PRK_16193                 2        Erosion
# Wyloo_Group                     3        Erosion
# Shingle_Creek_Group             4        Erosion
# Turee_Creek_Group               5        Erosion
# Hamersley_Group                 6        Erosion
# Fortescue_Group                 7        Erosion

# %% [markdown]
# ## Load surfaces and assign to series

# %%
surfaces = gp.Surfaces(series)

#ngroups=5
for i in range(0,ngroups):
    f=open('../test_data3/tmp/'+groups[i]+'.csv',"r")
    contents =f.readlines()
    nformations=str(contents[0])
    nformations=nformations.split(" ")
    nformations=int(nformations[1].replace("\n",""))

    for j in range (1,int(nformations)+1):
        surfaces.add_surface(contents[j].replace("\n",""))
        d={groups[i]:contents[j].replace("\n","")}
        surfaces.map_series({groups[i]:(contents[j].replace("\n",""))}) #working but no gps
        #gp.map_series_to_surfaces(geo_model, {groups[0]:(contents[j].replace("\n",""))},#XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX<<<<
              #  set_series=True, remove_unused_series=True)
    f.close

surfaces
# Out:
#             surface               series  order_surfaces  isBasement    color vertices edges  id
# 0    A_mgn_PMI_7366       A_mgn_PMI_7366               1       False  #015482      NaN   NaN   1
# 1   A_mgn_PRK_16193      A_mgn_PRK_16193               1       False  #9f0052      NaN   NaN   2
# 2         P__WYm_sp          Wyloo_Group               1       False  #ffbe00      NaN   NaN   3
# 3          P__WYa_s          Wyloo_Group               2       False  #728f02      NaN   NaN   4
# 4         P__WYd_kd          Wyloo_Group               3       False  #443988      NaN   NaN   5
# 5         P__SKb_bb  Shingle_Creek_Group               1       False  #ff3f20      NaN   NaN   6
# 6        P__SKq_stq  Shingle_Creek_Group               2       False  #325916      NaN   NaN   7
# 7       P__TKa_xs_k    Turee_Creek_Group               1       False  #5DA629      NaN   NaN   8
# 8        P__TKo_stq    Turee_Creek_Group               2       False  #acc2d9      NaN   NaN   9
# 9         P__TKk_sf    Turee_Creek_Group               3       False  #56ae57      NaN   NaN  10
# 10          P__TK_s    Turee_Creek_Group               4       False  #b2996e      NaN   NaN  11
# 11        P__HAo_ci      Hamersley_Group               1       False  #a8ff04      NaN   NaN  12
# 12        P__HAw_fr      Hamersley_Group               2       False  #69d84f      NaN   NaN  13
# 13    P__HAj_xci_od      Hamersley_Group               3       False  #894585      NaN   NaN  14
# 14       P__HAb_cib      Hamersley_Group               4       False  #70b23f      NaN   NaN  15
# 15     A_HAu_xsl_ci      Hamersley_Group               5       False  #d4ffff      NaN   NaN  16
# 16         A_HAd_kd      Hamersley_Group               6       False  #65ab7c      NaN   NaN  17
# 17        A_HAm_cib      Hamersley_Group               7       False  #952e8f      NaN   NaN  18
# 18       A_FOj_xs_b      Fortescue_Group               1       False  #fcfc81      NaN   NaN  19
# 19        A_FO_xo_a      Fortescue_Group               2       False  #a5a391      NaN   NaN  20
# 20          A_FO_od      Fortescue_Group               3       False  #388004      NaN   NaN  21
# 21        A_FOu_bbo      Fortescue_Group               4       False  #4c9085      NaN   NaN  22
# 22         A_FOp_bs      Fortescue_Group               5       False  #5e9b8a      NaN   NaN  23
# 23        A_FOo_bbo      Fortescue_Group               6       False  #efb435      NaN   NaN  24
# 24       A_FOh_xs_f      Fortescue_Group               7       False  #d99b82      NaN   NaN  25
# 25          A_FOr_b      Fortescue_Group               8        True  #0a5f38      NaN   NaN  26

# %% [markdown]
# ## Set Interpolation Data

# %%
id_only_one_bool = geo_model.surface_points.df['id'].value_counts() == 1
id_only_one = id_only_one_bool.index[id_only_one_bool]
single_vals = geo_model.surface_points.df[geo_model.surface_points.df['id'].isin(id_only_one)]
for idx, vals in single_vals.iterrows():
    geo_model.add_surface_points(vals['X'], vals['Y'], vals['Z'], vals['surface'])
    
geo_model.update_structure()
# Out:
#                                                                         values
# isLith                                                                    True
# isFault                                                                  False
# number faults                                                                0
# number surfaces                                                             23
# number series                                                                1
# number surfaces per series                                                [23]
# len surfaces surface_points  [13, 79, 46, 48, 64, 209, 169, 262, 92, 359, 2...
# len series surface_points                                               [2066]
# len series orientations                                                 [1328]

# %%
gp.set_interpolation_data(geo_model,
                          compile_theano=True,
                          theano_optimizer='fast_compile',
                          verbose=[])
# Out:
# Compiling theano function...
# Compilation Done!

# %% [markdown]
# ## Provide summary data on model

# %%
geo_model.additional_data.structure_data
# Out:
#                                                                         values
# isLith                                                                    True
# isFault                                                                  False
# number faults                                                                0
# number surfaces                                                             23
# number series                                                                1
# number surfaces per series                                                [23]
# len surfaces surface_points  [13, 79, 46, 48, 64, 209, 169, 262, 92, 359, 2...
# len series surface_points                                               [2066]
# len series orientations                                                 [1328]

# %% [markdown]
# ## Calculate Model

# %%
gp.compute_model(geo_model)
# Out:
# C:\Users\00073294\AppData\Local\Continuum\anaconda3\lib\site-packages\gempy\core\solution.py:253: UserWarning: Attribute error. Using non masked marching cubesmarching_cubes_lewiner() got an unexpected keyword argument 'mask'
#   warnings.warn('Attribute error. Using non masked marching cubes' + str(e))
# Lithology ids
#   [24.         24.         24.         ...  5.00013222  1.00001658
#   1.        ]

# %% [markdown]
# ## Extract surfaces to visualize in 3D renderers

# %%
gp.plot.plot_section(geo_model, 49, direction='z', show_data=False)

# %%
ver , sim = gp.get_surfaces(geo_model)

import winsound
duration = 300  # milliseconds
freq = 500  # Hz
winsound.Beep(freq, duration)

# %% [markdown]
# ## Visualise model

# %%
gp.plot.plot_3D(geo_model, render_data=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\gempy\plot\visualization_3d.py in key_callbacks(self, obj, event)
#     226
#     227         if key is 't':
# --> 228             if self.topo_visualization is True:
#     229                 self.topography_surface.VisibilityOff()
#     230                 self.topo_visualization = False
#
# AttributeError: 'GemPyvtkInteract' object has no attribute 'topo_visualization'
# closing vtk

# %%
from gempy import plot
#gp.plot.export_to_vtk(geo_model, path='./test_data3/vtk/', name='hams3.vtk', voxels=False, block=None, surfaces=True)
