# %% [markdown]
# ## map2loop: From geology layers to outputs to various 3D modelling programs- Hamersley example (Geomodeller)
#
# This notebook reads in three layers from  local or remote sources:  geology polygons, orientation data and fault polylines; and calculates the topological relationships between the different features. Requires compiled cpp code from Vitaliy Ogarko
#
# This all gets fed into successive tolopogical and geometric transfroms that end up feeding into geomodeller to make a 3D model

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import os
import sys
import stat
import functools 
import operator  
import matplotlib
import networkx as nx
import rasterio
from shapely.geometry import Polygon
from map2loop import m2l_utils
from map2loop import m2l_topology
from map2loop import m2l_geometry
from map2loop import m2l_interpolation
from map2loop import m2l_export
# %matplotlib inline

#newwd="C:\\Users\\00073294\Dropbox\\loop_minex\\map2model\\"
#os.chdir(newwd)
print("Current Working Directory " )

gdal_data = os.environ['GDAL_DATA']
print("***",gdal_data)
print('is dir: ' + str(os.path.isdir(gdal_data)))
gcs_csv = os.path.join(gdal_data, 'gcs.csv')
print('is file: ' + str(os.path.isfile(gcs_csv)))
st = os.stat(gcs_csv)
print('is readable: ' + str(bool(st.st_mode & stat.S_IRGRP)))
os.environ['PROJ_LIB']=r"C:\\Users\\00073294\\AppData\\Local\\Continuum\\anaconda3\\Lib\\site-packages\\pyproj\\proj_dir\\share\\proj"
print(os.getenv('PROJ_LIB'))
print(os.getcwd())
# Out:
# Current Working Directory
# *** C:\Program Files\PostgreSQL\11\gdal-data
# is dir: True
# is file: True
# is readable: True
# C:\\Users\\00073294\\AppData\\Local\\Continuum\\anaconda3\\Lib\\site-packages\\pyproj\\proj_dir\\share\\proj
# C:\Users\00073294\Dropbox\1_Jupyter_notebooks\map2loop\notebooks

# %% [markdown]
# ## Create bounding box based on inputs

# %%
test_data_name='test_data3'

test_data_path='../'+test_data_name+'/'

os.chdir(test_data_path)
# %run -i "m2l_config.py"
#%run -i "../test_data3/m2l_config.py"
print(os.getcwd())

bbox2=str(minx)+","+str(miny)+","+str(maxx)+","+str(maxy)
lat_point_list = [miny, miny, maxy, maxy, maxy]
lon_point_list = [minx, maxx, maxx, minx, minx]
bbox_geom = Polygon(zip(lon_point_list, lat_point_list))
polygon = gpd.GeoDataFrame(index=[0], crs=dst_crs, geometry=[bbox_geom]) 
bbox=(minx,miny,maxx,maxy)
# Out:
# Default parameters loaded from ../test_data3/m2l_config.py:
# #ROI
#
# step_out=0.1   #padding arounf dtm to ensure reprojected dtm covers target area (in degrees)
# inset=0      #unused??
#
# minx=500057  #region of interest coordinates in metre-based system (or non-degree system)
# maxx=603028
# miny=7455348
# maxy=7567953
# model_top=1200
# model_base=-8200
#
# #PATHS
#
# test_data_path='../test_data3/'
# geology_file='hams2_geol.shp'   #input geology file (if local)
# fault_file='GEOS_GEOLOGY_LINEARSTRUCTURE_500K_GSD.shp' #input fault file (if local)
# structure_file='hams2_structure.shp' #input bedding orientation file (if local)
# m2m_cpp_path='../m2m_cpp/'
#
#
# #CRS
#
# src_crs = {'init': 'EPSG:4326'}  # coordinate reference system for imported dtms (geodetic lat/long WGS84)
# dst_crs = {'init': 'EPSG:28350'} # coordinate system for data
#
# #codes and labels these refer to specific fields (codes) in GIS layer or database that contain the info needed for these calcs and text substrings (labels) in the contents of these fields
# c_l= {
# #Orientations
#   "d": "DIP",                  #field that contains dip information
#   "dd": "DIP_DIR",             #field that contains dip direction information
#   "sf": 'FEATURE',             #field that contains information on type of structure
#   "bedding": 'Bed',            #text to search for in field defined by sf code to show that this is a bedding measurement
# #Stratigraphy
#   "g": 'GROUP_',               #field that contains coarser stratigraphic coding
#   "c": 'CODE',                 #field that contains finer stratigraphic coding
#   "ds": 'DESCRIPTN',           #field that contains information about lithology
#   "u": 'UNITNAME',             #field that contains alternate stratigraphic coding (not used??)
#   "r1": 'ROCKTYPE1',           #field that contains  extra lithology information
#   "r2": 'ROCKTYPE2',           #field that contains even more lithology information
#   "sill": 'sill',              #text to search for in field defined by ds code to show that this is a sill
#   "intrusive": 'intrusive',    #text to search for in field defined by ds code to show that this is an intrusion
#   "volcanic": 'volcanic',      #text to search for in field defined by ds code to show that this is an intrusion
# #Timing
#   "min": 'MIN_AGE_MA',         #field that contains minimum age of unit defined by ccode
#   "max": 'MAX_AGE_MA',         #field that contains maximum age of unit defined by ccode
# #faults and folds
#   "f": 'FEATURE',              #field that contains information on type of structure
#   "fault": 'Fault',            #text to search for in field defined by f code to show that this is a fault
#   "fold": 'Fold axial trace',  #text to search for in field defined by f code to show that this is a fold axial trace
#   "n": 'NAME',                 #field that contains information on name of fault (not used??)
#   "t": 'TYPE',                 #field that contains information on type of fold
#   "syn": 'syncline',           #text to search for in field defined by t to show that this is a syncline
# #ids
#   "o": 'OBJECTID',             #field that contains unique id of geometry object
#   "gi": 'GEOPNT_ID'            #field that contains unique id of structure point
# }
#
# #DECIMATION
#
# orientation_decimate=0  #store every nth orientation (in object order) 0 = save all
# contact_decimate=10     #store every nth contact point (in object order) 0 = save all
# fault_decimate=5        #store every nth fault point (in object order) 0 = save all
# fold_decimate=5         #store every nth fold axial trace point (in object order) 0 = save all
#
#
# #INTERPOLATION
#
# gridx=50                #x grid dimensions (no of points, not distance) for interpolations
# gridy=50                #x grid dimensions (no of points, not distance) for interpolations
# scheme='scipy_rbf'      #interpolation scheme
# dist_buffer=5           #buffer distance for clipping points by faults (in metres or same units as dst_crs)
# intrusion_mode=0        # 1 all intrusions exluded from basal contacts, 0 only sills
# use_interpolations=False    # flag to sue interpolated orientations or not.
#
# #ASSUMPTIONS
#
# pluton_dip=45           #surface dip of pluton contacts
# pluton_form='domes'     #saucers: \__+_+__/  batholith: +/       \+   domes: /  +  + \  pendant: +\_____/+
# fault_dip=90            #surface dip of faults
#
# #DERIVED PATHS
#
# local_paths=False       #flag to use local or WFS source for data inputs (True = local)
#
# graph_path=test_data_path+'graph/'
# tmp_path=test_data_path+'tmp/'
# data_path=test_data_path+'data/'
# dtm_path=test_data_path+'dtm/'
# output_path=test_data_path+'output/'
# vtk_path=test_data_path+'vtk/'
#
# fault_file=data_path+fault_file
# structure_file=data_path+structure_file
# geology_file=data_path+geology_file
#
# fault_file_csv=fault_file.replace(".shp",".csv").replace("/data/","/tmp/")
# structure_file_csv=structure_file.replace(".shp",".csv").replace("/data/","/tmp/")
# geology_file_csv=geology_file.replace(".shp",".csv").replace("/data/","/tmp/")
#
# strat_graph_file=test_data_path+'graph/graph_strat.gml'
#
# dtm_file=dtm_path+'dtm.tif'
# dtm_reproj_file=dtm_path+'dtm_rp.tif'
#
# if(not os.path.isdir(test_data_path)):
#    os.mkdir(test_data_path)
# if(not os.path.isdir(tmp_path)):
#    os.mkdir(tmp_path)
# if(not os.path.isdir(output_path)):
#    os.mkdir(output_path)
# if(not os.path.isdir(dtm_path)):
#    os.mkdir(dtm_path)
# if(not os.path.isdir(vtk_path)):
#    os.mkdir(vtk_path)
# if(not os.path.isdir(graph_path)):
#    os.mkdir(graph_path)
#
# print('Default parameters loaded from '+test_data_path+'m2l_config.py:')
# with open(test_data_path+'m2l_config.py', 'r') as myfile:
#   data = myfile.read()
#   print(data)
#   myfile.close()
#
# print('\nModify these parameters in the cell below')
#
# Modify these parameters in the cell below
# C:\Users\00073294\Dropbox\1_Jupyter_notebooks\map2loop\test_data3

# %%
fold_decimate=2         

contact_decimate=5

use_interpolations=True       #use interpolated dips/contacts as additional constraints

use_fat=True                   #use fold axial trace orientation hints

    
local_paths=True              #use local copies of data

pluton_form='domes'

min_fault_length=20

compute_etc=False

# %% [markdown]
# ## First we test to see if we have access to the online data we need

# %%
loopwfs=m2l_utils.have_access("geo.loop-gis.org")
hawaii=m2l_utils.have_access("pae-paha.pacioos.hawaii.edu")

if(not (loopwfs & hawaii)):
    local_paths=True
    net=False
    print('using local paths')
else:
    net=True
# Out:
# available: geo.loop-gis.org
# available: pae-paha.pacioos.hawaii.edu

# %% [markdown]
# ## Optional WFS source
#
# WFS brings in field names as lower case, so need to redefine codes too

# %%
if((not local_paths) and net):
    structure_file='http://geo.loop-gis.org/geoserver/loop/wfs?service=WFS&version=1.1.0&request=GetFeature&typeName=warox_points_f5011&bbox='+bbox2+'&srs=EPSG:28350'
    fault_file='http://geo.loop-gis.org/geoserver/loop/wfs?service=WFS&version=1.1.0&request=GetFeature&typeName=linear_500k&bbox='+bbox2+'&srs=EPSG:28350'
    geology_file='http://geo.loop-gis.org/geoserver/loop/wfs?service=WFS&version=1.0.0&request=GetFeature&typeName=loop:geol_500k&bbox='+bbox2+'&srs=EPSG:28350'

    c_l= {
    #Orientations
      "d": "dip",                  #field that contains dip information
      "dd": "dip_dir",             #field that contains dip direction information
      "sf": 'feature',             #field that contains information on type of structure
      "bedding": 'Bed',            #text to search for in field defined by sfcode to show that this is a bedding measurement
    #Stratigraphy
      "g": 'group_',               #field that contains coarser stratigraphic coding
      "c": 'code',                 #field that contains finer stratigraphic coding
      "ds": 'descriptn',           #field that contains information about lithology
      "u": 'unitname',             #field that contains alternate stratigraphic coding (not used??)
      "r1": 'rocktype1',           #field that contains  extra lithology information
      "r2": 'rocktype2',           #field that contains even more lithology information
      "sill": 'sill',              #text to search for in field defined by dscode to show that this is a sill
      "intrusive": 'intrusive',    #text to search for in field defined by dscode to show that this is an intrusion
      "volcanic": 'volcanic',      #text to search for in field defined by dscode to show that this is an intrusion
    #Timing
      "min": 'min_age_ma',         #field that contains minimum age of unit defined by ccode
      "max": 'max_age_ma',         #field that contains maximum age of unit defined by ccode
    #faults and folds
      "f": 'feature',              #field that contains information on type of structure
      "fault": 'Fault',            #text to search for in field defined by fcode to show that this is a fault
      "fold": 'Fold axial trace',  #text to search for in field defined by fcode to show that this is a fold axial trace
      "n": 'name',                 #field that contains information on name of fault (not used??)
      "t": 'type',                 #field that contains information on type of fold
    #ids
      "o": 'objectid',             #field that contains unique id of geometry object
      "gi": 'geopnt_id'            #field that contains unique id of structure point
    }

# %% [markdown]
# ## Plot geology polygons and bounding box

# %%
print(geology_file)
geology_ll = gpd.read_file(geology_file,bbox=bbox)

base=geology_ll.plot(column=c_l['c'],figsize=(10,10),edgecolor='#000000',linewidth=0.2)
polygon.plot(ax=base, color='none',edgecolor='black')
# Out:
# ../test_data3/data/hams2_geol.shp

# %% [markdown]
# ## Save to file as WKT

# %%
sub_geol = geology_ll[['geometry', c_l['o'],c_l['c'],c_l['g'],c_l['u'],c_l['min'],c_l['max'],c_l['ds'],c_l['r1'],c_l['r2']]]
m2l_topology.save_geol_wkt(sub_geol,geology_file_csv, c_l)
# Out:
# 186  polygons

# %% [markdown]
# ## Read and save WAROX point data as WKT

# %%
warox = gpd.read_file(structure_file,bbox=bbox)

sub_pts = warox[['geometry', c_l['gi'],c_l['d'],c_l['dd']]]

m2l_topology.save_structure_wkt(sub_pts,structure_file_csv,c_l)

base=sub_pts.plot()
polygon.plot(ax=base, color='none',edgecolor='black')
# Out:
# 121  points

# %% [markdown]
# ## Plot faults and bounding box

# %%
lines_ll=gpd.read_file(fault_file,bbox=bbox)

base2=lines_ll.plot(cmap='rainbow',column=c_l['f'],figsize=(10,10),linewidth=0.4)
polygon.plot(ax=base2, color='none',edgecolor='black')

# %% [markdown]
# ## Save faults to file as WKT

# %%
sub_lines = lines_ll[['geometry', c_l['o'],c_l['f']]]
m2l_topology.save_faults_wkt(sub_lines,fault_file_csv,c_l)
# Out:
# 134  polylines

# %% [markdown]
# ## Create map2model input file

# %%
m2l_topology.save_Parfile(m2m_cpp_path,c_l,graph_path,geology_file_csv,fault_file_csv,structure_file_csv,minx,maxx,miny,maxy)

# %% [markdown]
# ## Calculate topology

# %%
os.chdir(m2m_cpp_path)
print(os.getcwd())
# %system map2model.exe Parfile
# Out:
# C:\Users\00073294\Dropbox\1_Jupyter_notebooks\map2loop\m2m_cpp
# ['Reading data from the file: Parfile',
#  '--- COLUMN NAMES IN CSV DATA FILES: -------------------------------------------------------------',
#  'OBJECT COORDINATES              =WKT',
#  'FAULT: ID                       =OBJECTID',
#  'FAULT: FEATURE                  =FEATURE',
#  'POINT: ID                       =GEOPNT_ID',
#  'POINT: DIP                      =DIP',
#  'POINT: DIP DIR                  =DIP_DIR',
#  'POLYGON: ID                     =OBJECTID',
#  'POLYGON: LEVEL1 NAME            =UNITNAME',
#  'POLYGON: LEVEL2 NAME            =GROUP_',
#  'POLYGON: MIN AGE                =MIN_AGE_MA',
#  'POLYGON: MAX AGE                =MAX_AGE_MA',
#  'POLYGON: CODE                   =CODE',
#  'POLYGON: DESCRIPTION            =DESCRIPTN',
#  'POLYGON: ROCKTYPE1              =ROCKTYPE1',
#  'POLYGON: ROCKTYPE2              =ROCKTYPE2',
#  '--- SOME CONSTANTS: ----------------------------------------------------------------------------',
#  'FAULT AXIAL FEATURE NAME        =Fold axial trace',
#  'SILL UNIT DESCRIPTION CONTAINS  =sill',
#  'IGNEOUS ROCKTYPE CONTAINS                           =intrusive',
#  'VOLCANIC ROCKTYPE CONTAINS                          =volcanic',
#  'Intersect Contact With Fault: angle epsilon (deg)   =1',
#  'Intersect Contact With Fault: distance epsilon (m)  =15',
#  '------------------------------------------------------------------------------------------------',
#  'Path to the output data folder                      =../test_data3/graph/',
#  'Path to geology data file                           =../test_data3/tmp/hams2_geol.csv',
#  'Path to faults data file                            =../test_data3/tmp/GEOS_GEOLOGY_LINEARSTRUCTURE_500K_GSD.csv',
#  'Path to points data file                            =../test_data3/tmp/hams2_structure.csv',
#  '------------------------------------------------------------------------------------------------',
#  'Clipping window X1 Y1 X2 Y2 (zeros for infinite)    =500057 7.45535e+06 603028 7.56795e+06',
#  'Min length fraction for strat/fault graphs          =0',
#  'Graph edge width categories (three doubles)         =2000 20000 200000',
#  'Graph edge direction (0-min age, 1-max age, 2-avg)  =2',
#  'Partial graph polygon ID                            =32',
#  'Partial graph depth                                 =4',
#  'Map subregion size dx, dy [m] (zeros for full map)  =0 0',
#  '------------------------------------------------------------------------------------------------',
#  'Reading data from the file ../test_data3/tmp/GEOS_GEOLOGY_LINEARSTRUCTURE_500K_GSD.csv',
#  'Objects read: 104',
#  'Reading data from the file ../test_data3/tmp/hams2_structure.csv',
#  'Objects read: 121',
#  'Reading data from the file ../test_data3/tmp/hams2_geol.csv',
#  'Objects read: 186',
#  'Multipolygons left (after clipping): 186',
#  'Faults left (after clipping): 104',
#  'Window perimeter = 431152',
#  'Building lists of units and groups...',
#  'Number of units: 29',
#  'Total unit length = 11506904.249082',
#  '1 Fortescue Group',
#  '2 Hamersley Group',
#  '3 A-b-PRK',
#  '4 A-mgn-PMI',
#  '5 A-mgn-PRK',
#  '6 A-s-PMI',
#  '7 A-s-PRK',
#  '8 Shingle Creek Group',
#  '9 Turee Creek Group',
#  '10 Wyloo Group',
#  'Intersecting faults with polygons...',
#  'Wrote 26 items to unit-fault intersection list: ../test_data3/graph//unit-fault-intersection.txt',
#  'Intersecting faults with faults...',
#  'Wrote 48 items to fault-fault intersection list: ../test_data3/graph//fault-fault-intersection.txt',
#  'Finding contacts...',
#  'numCommonEdges = 15268',
#  'Total contact length = 5537876.124541',
#  'Identifying contact types...',
#  'Total number of intersections: 681',
#  'Number of all contacts: 400',
#  'Number of fault-contacts: 96',
#  'Number of mixed-contacts: 141',
#  'Splitting mixed contacts...',
#  'Number of contacts after splitting: 764',
#  'PERIMETER LENGTHS: 11506904.249082 11506904.249082 0',
#  'Finding unit-contacts...',
#  'Number of unit-contacts: 75',
#  'Number of unit-contacts = 75',
#  'Number of stratigraphic unit-contacts = 17',
#  'Number of fault unit-contacts = 21',
#  'Number of mixed unit-contacts = 37',
#  'Identifying igneous contacts...',
#  'Number of intrusive igneous unit contacts: 23',
#  'Number of igneous unit contacts: 5',
#  'Writing topology graph to a file: ../test_data3/graph//graph_all.gml',
#  'Number of units in the graph: 29',
#  'Number of groups in the graph: 10',
#  'Writing topology graph to a file: ../test_data3/graph//graph_strat.gml',
#  'Number of units in the graph: 29',
#  'Number of groups in the graph: 10',
#  'Writing topology graph to a file: ../test_data3/graph//graph_fault.gml',
#  'Number of units in the graph: 26',
#  'Number of groups in the graph: 9',
#  'Writing topology graph to a file: ../test_data3/graph//graph_ingeous.gml',
#  'Number of units in the graph: 29',
#  'Number of groups in the graph: 10',
#  'Number of filtered contacts: 8068',
#  'Number of unique filtered contacts: 60',
#  'Finding unit-contacts...',
#  'Number of unit-contacts: 14',
#  'Number of unit-contacts = 14',
#  'Number of stratigraphic unit-contacts = 10',
#  'Number of fault unit-contacts = 0',
#  'Number of mixed unit-contacts = 4',
#  'Writing topology graph to a file: ../test_data3/graph//graph_partial.gml',
#  'Number of units in the graph: 10',
#  'Number of groups in the graph: 4',
#  'End.']

# %% [markdown]
# ## Simple network graph of the geology with legend

# %%
G=nx.read_gml(strat_graph_file,label='id')
selected_nodes = [n for n,v in G.nodes(data=True) if n >=0]
nx.draw_networkx(G, pos=nx.kamada_kawai_layout(G), arrows=True, nodelist=selected_nodes)

nlist=list(G.nodes.data('LabelGraphics'))
nlist.sort()
for no in nlist:
    if(no[0]>=0):
        elem=str(no[1]).replace("{'text':","").replace(", 'fontSize': 14}","")
        #second=elem.split(":").replace("'","")
        print(no[0]," ",elem)
# Out:
# C:\Users\00073294\AppData\Local\Continuum\anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\00073294\AppData\Local\Continuum\anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# 0    'A-HAm-cib'
# 1    'A-FOp-bs'
# 2    'A-HAS-xsl-ci'
# 3    'P_-HAb-cib'
# 4    'P_-HAj-xci-od'
# 5    'A-mgn-PRK'
# 6    'A-FOh-xs-f'
# 7    'A-FOo-bbo'
# 8    'A-FO-od'
# 9    'A-HAd-kd'
# 10    'A-FOj-xs-b'
# 11    'P_-TKa-xs-k'
# 12    'P_-HAo-ci'
# 13    'P_-HAw-fr'
# 14    'A-FO-xo-a'
# 15    'A-b-PRK'
# 16    'A-FOr-b'
# 17    'A-FOu-bbo'
# 18    'P_-TK-s'
# 19    'A-mgn-PMI'
# 20    'A-s-PMI'
# 21    'A-s-PRK'
# 22    'P_-SKq-stq'
# 23    'P_-WYm-sp'
# 24    'P_-WYa-st'
# 25    'P_-WYd-kd'
# 26    'P_-TKo-stq'
# 27    'P_-TKk-sf'
# 28    'P_-SKb-bb'

# %% [markdown]
# ## Detailed Topology via dot or gml format files
# For a more detailed look we can open up the online version of <b>yEd</b> <a href="https://www.yworks.com/yed-live/" >https://www.yworks.com/yed-live/</a>  and load in the *.dot file that we will now create or dowload the <a href="https://www.yworks.com/products/yed/download">yEd program</a> and look at the *.gml files in the <b>output</b> directory

# %% [markdown]
# from networkx.drawing.nx_pydot import write_dot
#
# import filer,gfiler
#
# filepath=filer.gui_fname().decode('UTF-8')
# write_dot(G,filepath)

# %% [markdown]
# http://localhost:8888/notebooks/Dropbox/1_Jupyter_notebooks/map2loop/notebooks/2.%20map2loop_after_topology.ipynb

# %% [markdown]
# ## Process topography, stratigraphy, fold axial traces and faults
#
# ### Takes GML file produced by topology code, combines with geology polygons, structure points and dtm to create 3D model in gempy.<br><br>
#
# Limitations:  no dykes, no sills. Sills require us to assign a unique surface to each instance of a sill (sill between units A and B needs to be different from sill of same age and strat codes as one found between E and F). Dykes via cokriging are really hard without just cookie cutting them in (but that is not our problem!). We are not checking for onlap relationships, which can perhaps been seen by having lots of units from one series adjacent to the youngest surface of the older series. Could also think about interpreting these as faults to introduce conceptual uncertainty. All mistakes belong to Mark Jessell, topology code that feeds this system by Vitaliy Ogarko.<br><br>
#
# Geology layer needs to have some unique strat code or text, some group code or text to function<br>
# Structure layer needs dip/dip direction<br>
#
# <font color='red'>Currently mostly hardwired to GSWA 500K map so needs work...</font>

# %%
os.chdir('../map2loop')

print(os.getcwd())
# Out:
# C:\Users\00073294\Dropbox\1_Jupyter_notebooks\map2loop\map2loop

# %%
#from IPython.core.display import display, HTML
#display(HTML("<style>.container { width:80% !important; }</style>"))

sys.path.insert(0,"../..")
print(os.getcwd())


#print(os.getcwd())
#os.environ["PROJ_LIB"] = r"C:\Users\00073294\AppData\Local\Continuum\anaconda3\Lib\site-packages\pyproj\proj_dir\share\proj"
# Out:
# C:\Users\00073294\Dropbox\1_Jupyter_notebooks\map2loop\map2loop

# %% [markdown]
# ## Next we define an area of interest and some other basic stuff

# %%
print(os.getcwd())
#test_data_path='../test_data3/'


#%run -i "../test_data3/m2l_config.py"

bbox2=str(minx)+","+str(miny)+","+str(maxx)+","+str(maxy)
lat_point_list = [miny, miny, maxy, maxy, maxy]
lon_point_list = [minx, maxx, maxx, minx, minx]
bbox_geom = Polygon(zip(lon_point_list, lat_point_list))
polygon = gpd.GeoDataFrame(index=[0], crs=dst_crs, geometry=[bbox_geom]) 
bbox=(minx,miny,maxx,maxy)

step_out=0.045 #add (in degrees) so edge pixel from dtm reprojection are not found


#contact_decimate=5
# Out:
# C:\Users\00073294\Dropbox\1_Jupyter_notebooks\map2loop\map2loop

# %% [markdown]
# ## Download and reproject the appropriate SRTM data
# mj: Getting this from GA, but could also get from Hawaii

# %%
polygon_ll=polygon.to_crs(src_crs)

minlong=polygon_ll.total_bounds[0]-step_out
maxlong=polygon_ll.total_bounds[2]+step_out
minlat=polygon_ll.total_bounds[1]-step_out
maxlat=polygon_ll.total_bounds[3]+step_out

print(minlong,maxlong,minlat,maxlat)
if((not local_paths) and net):     
    m2l_utils.get_dtm(dtm_file, minlong,maxlong,minlat,maxlat)
    geom_rp=m2l_utils.reproject_dtm(dtm_file,dtm_reproj_file,src_crs,dst_crs)
# Out:
# 116.9555521867685 118.0503484485386 -23.055227990891293 -21.94491765252865

# %% [markdown]
# ## Load stratigraphy graph and create list of series (aka groups)
# mj: The choice of what constitutes basic unit and what a group of units is hard-wired at the moment, but could be altered to any pair. Not even sure we need two levels but it seemed like a good idea at the time. Note that this needs the arcgis plugin version of the topology code (for now) as it seperates the different sub graphs. Text outputs list alternate topologies for series and surfaces, which if confirmed by comapring max-min ages will be a nice source of uncertainty.

# %%
groups,glabels,G = m2l_topology.get_series(strat_graph_file,'id')
m2l_topology.save_units(G,tmp_path,glabels)

# %% [markdown]
# ## Load geology & structure data
# Currently loading from local files, but could load geology from WFS server at GSWA EXCEPT that the WFS online map has less fields that the zipped shapefiles. Go figure. We don't use fault layer at the moment (except for Vitaliy's topology code) but same logic applies in terms of where to get it from. Already have fault/strat relationships and once we have fault/fault relationships will start to include faults in models.

# %%
# Extract point data from structure & geology layers for modelling
##First we readin the structure and map from shapefiles, or wherever...

bbox=(minx,miny,maxx,maxy)
geology = gpd.read_file(geology_file,bbox=bbox)


structure = gpd.read_file(structure_file,bbox=bbox)
structure.crs=dst_crs
print(fault_file)
faults = gpd.read_file(fault_file,bbox=bbox)
faults.crs=dst_crs
#display(faults)
sub_pts = structure[['geometry',c_l['d'],c_l['dd'],c_l['sf']]] 

base=geology.plot(column=c_l['c'],figsize=(10,10),edgecolor='#000000',linewidth=0.2)
sub_pts.plot(ax=base,edgecolor='black')
faults.plot(ax=base, column=c_l['f'],edgecolor='black')
# Out:
# ../test_data3/data/GEOS_GEOLOGY_LINEARSTRUCTURE_500K_GSD.shp

# %% [markdown]
# ## Clip geology, faults, structures and map geology to structures

# %%
geology = m2l_utils.explode(geology)
geology.crs = dst_crs
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows',None)
structure_code = gpd.sjoin(sub_pts, geology, how="left", op="within")

y_point_list = [miny, miny, maxy, maxy, miny]
x_point_list = [minx, maxx, maxx, minx, minx]

bbox_geom = Polygon(zip(x_point_list, y_point_list))

polygo = gpd.GeoDataFrame(index=[0], crs=dst_crs, geometry=[bbox_geom]) 
#display(polygo.geometry)
is_bed=structure_code[c_l['sf']].str.contains(c_l['bedding'], regex=False) 
    
all_beds = structure_code[is_bed]
#display(sfcode)
all_folds=faults[faults[c_l['f']].str.contains(c_l['fold'])]
folds_clip=m2l_utils.clip_shp(all_folds,polygo)
folds_clip.to_file(tmp_path+'folds_clip.shp')


all_faults=faults[faults[c_l['f']].str.contains(c_l['fault'])]



#display(structure_code)
geol_clip=m2l_utils.clip_shp(geology, polygo)
faults_clip=m2l_utils.clip_shp(all_faults,polygo)
#display(faults_clip)
structure_clip = m2l_utils.clip_shp(all_beds, polygo)

base = geol_clip.plot(column=c_l['c'],figsize=(7,7),edgecolor='#000000',linewidth=0.2)
faults_clip.plot(ax=base, column=c_l['t'],edgecolor='black')
structure_clip.plot(ax=base, column=c_l['c'],edgecolor='black')

geol_clip.to_file(tmp_path+'geol_clip.shp')
faults_clip.to_file(tmp_path+'faults_clip.shp')
structure_clip.to_file(tmp_path+'structure_clip.shp')

# %% [markdown]
# ## Create possible stratigraphy sets per group
# mj: <font color='red'>Uses first of each possible set of toplogies per unit and per group, which is arbitrary. </font>On the other hand we are not checking relative ages again to see if this helps reduce ambiguity, which I think it would.

# %%
m2l_topology.save_group(G,tmp_path,glabels,geol_clip,c_l)
# Out:
#                      index     min     max     ave
# group_
# Wyloo_Group              0  1799.0  2010.0  1904.5
# Shingle_Creek_Group      1  2208.0  2208.0  2208.0
# Turee_Creek_Group        2  2208.0  2449.0  2328.5
# Hamersley_Group          3  2208.0  2629.0  2418.5
# Fortescue_Group          4  2629.0  2780.0  2704.5
# A_mgn_PMI                5  2830.0  3500.0  3165.0
# A_mgn_PRK                6  2830.0  3500.0  3165.0
# A_s_PMI                  7  2930.0  3520.0  3225.0
# A_b_PRK                  8  2930.0  3520.0  3225.0
# A_s_PRK                  9  2930.0  3520.0  3225.0
# []
# group choices: 40

# %% [markdown]
# ## Export orientation data in csv  format
# mj: Orientation data needs calculated height as file does not provide it, taken from SRTM data already downloaded. To calculate polarity <font color='red'>(WHICH WE DON'T DO YET)</font> we can calculate the dot product of the dip direction of a bedding plane and the vector to that points nearest basal contact node, if  abs(acos(dot product))>90  then right way up :
#
# <img src='../graphics/polarity.png'>
#
# Added code to not save intrusion orientation data as they won't have associated surfaces if sill...

# %%
dtm = rasterio.open(dtm_reproj_file)
m2l_geometry.save_orientations(structure_code,output_path,c_l,orientation_decimate,dtm)
# Out:
# 115 orientations saved to ../test_data3/output//orientations.csv

# %% [markdown]
# ## Find those series that don't have any orientation or contact point data  then create arbitrary point for series with no orientation data
# Not sure if gempy needs this but geomodeller does. Currently just gives a point dipping 45 degrees to North, but could use dip direction normal to basal surface)

# %%
m2l_geometry.create_orientations( tmp_path, output_path, dtm,geol_clip,structure_clip,c_l)
# Out:
# extra orientations saved as ../test_data3/output//empty_series_orientations.csv

# %% [markdown]
# ## Export contact information subset of each polygon to gempy format
# mj: Orientation data needs calculated height as file does not provide it, taken from SRTM data already downloaded. Need to reduce number of points whilst retaining useful info (Ranee's job!)'
# To calculate which are the basal units contact for a polygon find the polygons which are older than the selected polygon, in the example below the central polygon has relative age 23 so its basal contact is with the polygons whose ages are 26 & 28. If there are no older units for a polygon it has no basal content. We keep every nth node based on the decimate term (simple count along polyline). gempy seems to need at least two points per surface, so we always take the first two points.
#
#
# <img src='../graphics/base.png'>

# %%
ls_dict,ls_dict_decimate=m2l_geometry.save_basal_contacts(tmp_path,dtm,geol_clip,contact_decimate,c_l,intrusion_mode)
# Out:
# basal contacts saved allpts= 10902 deci_pts= 2603
# saved as ../test_data3/tmp/all_contacts.csv and ../test_data3/tmp/contacts.csv

# %% [markdown]
# ## Remove all basal contacts that are defined by faults and save to shapefile (no decimation)

# %%
display(ls_dict)
# Out:
# {0: {'id': 0,
#   'CODE': 'A_FOp_bs',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c187ce198>},
#  1: {'id': 1,
#   'CODE': 'A_FOo_bbo',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c18793128>},
#  2: {'id': 2,
#   'CODE': 'A_FOh_xs_f',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c18561860>},
#  3: {'id': 3,
#   'CODE': 'A_FOh_xs_f',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c18781240>},
#  4: {'id': 4,
#   'CODE': 'A_FOh_xs_f',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c13ee90b8>},
#  5: {'id': 5,
#   'CODE': 'A_s_PMI',
#   'GROUP_': 'A_s_PMI',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c185616d8>},
#  6: {'id': 6,
#   'CODE': 'A_HAd_kd',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c1844ea90>},
#  7: {'id': 7,
#   'CODE': 'A_FOp_bs',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c18489198>},
#  8: {'id': 8,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c13ee9278>},
#  9: {'id': 9,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c18506390>},
#  10: {'id': 10,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c1849ae10>},
#  11: {'id': 11,
#   'CODE': 'A_HAd_kd',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c18375d68>},
#  12: {'id': 12,
#   'CODE': 'A_HAd_kd',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c

#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19afd780>},
#  94: {'id': 94,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19aefba8>},
#  95: {'id': 95,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19aefef0>},
#  96: {'id': 96,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b06860>},
#  97: {'id': 97,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b06ba8>},
#  98: {'id': 98,
#   'CODE': 'P__TK_s',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b06cc0>},
#  99: {'id': 99,
#   'CODE': 'P__TK_s',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b06f98>},
#  100: {'id': 100,
#   'CODE': 'P__TK_s',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b06e10>},
#  101: {'id': 101,
#   'CODE': 'P__TK_s',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b06c50>},
#  102: {'id': 102,
#   'CODE': 'P__TK_s',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b16630>},
#  103: {'id': 103,
#   'CODE': 'P__TK_s',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b169b0>},
#  104: {'id': 104,
#   'CODE': 'P__TK_s',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b16b70>},
#  105: {'id': 105,
#   'CODE': 'P__HAj_xci_od',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b16908>},
#  106: {'id': 106,
#   'CODE': 'P__HAj_xci_od',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b065f8>},
#  107: {'id': 107,
#   'CODE': 'P__HAo_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b16c88>},
#  108: {'id': 108,
#   'CODE': 'A_HAd_kd',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b1cba8>},
#  109: {'id': 109,
#   'CODE': 'A_HAd_kd',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b2bc18>},
#  110: {'id': 110,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b1cc18>},
#  111: {'id': 111,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b2b128>},
#  112: {'id': 112,
#   'CODE': 'A_HAd_kd',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b1c7f0>},
#  113: {'id': 113,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b39160>},
#  114: {'id': 114,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b39240>},
#  115: {'id': 115,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b2be10>},
#  116: {'id': 116,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b39470>},
#  117: {'id': 117,
#   'CODE': 'A_FOu_bbo',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b44cc0>},
#  118: {'id': 118,
#   'CODE': 'P__HAj_xci_od',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b510f0>},
#  119: {'id': 119,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b51240>},
#  120: {'id': 120,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b44f60>},
#  121: {'id': 121,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b51320>},
#  122: {'id': 122,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b6e748>},
#  123: {'id': 123,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b51048>},
#  124: {'id': 124,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b6e8d0>},
#  125: {'id': 125,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b6eb38>},
#  126: {'id': 126,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b6ed68>},
#  127: {'id': 127,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b6ec18>},
#  128: {'id': 128,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b6e9e8>},
#  129: {'id': 129,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b7b898>},
#  130: {'id': 130,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b84978>},
#  131: {'id': 131,
#   'CODE': 'P__HAj_xci_od',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b7bf98>},
#  132: {'id': 132,
#   'CODE': 'P__HAo_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b95780>},
#  133: {'id': 133,
#   'CODE': 'P__HAw_fr',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b844e0>},
#  134: {'id': 134,
#   'CODE': 'P__HAw_fr',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b95860>},
#  135: {'id': 135,
#   'CODE': 'A_FOo_bbo',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19b95978>},
#  136: {'id': 136,
#   'CODE': 'P__WYm_sp',
#   'GROUP_': 'Wyloo_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bb12b0>},
#  137: {'id': 137,
#   'CODE': 'P__WYm_sp',
#   'GROUP_': 'Wyloo_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19ba2128>},
#  138: {'id': 138,
#   'CODE': 'P__WYd_kd',
#   'GROUP_': 'Wyloo_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bb1358>},
#  139: {'id': 139,
#   'CODE': 'P__WYd_kd',
#   'GROUP_': 'Wyloo_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bb1898>},
#  140: {'id': 140,
#   'CODE': 'P__SKq_stq',
#   'GROUP_': 'Shingle_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bb1a58>},
#  141: {'id': 141,
#   'CODE': 'P__SKq_stq',
#   'GROUP_': 'Shingle_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bb1208>},
#  142: {'id': 142,
#   'CODE': 'P__TK_s',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bb1c18>},
#  143: {'id': 143,
#   'CODE': 'P__TK_s',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bb1ac8>},
#  144: {'id': 144,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bb19b0>},
#  145: {'id': 145,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bb18d0>},
#  146: {'id': 146,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bbb0b8>},
#  147: {'id': 147,
#   'CODE': 'P__WYa_st',
#   'GROUP_': 'Wyloo_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bbb4e0>},
#  148: {'id': 148,
#   'CODE': 'P__HAw_fr',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bbb6d8>},
#  149: {'id': 149,
#   'CODE': 'P__SKq_stq',
#   'GROUP_': 'Shingle_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bb1d30>},
#  150: {'id': 150,
#   'CODE': 'P__SKq_stq',
#   'GROUP_': 'Shingle_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bbb358>},
#  151: {'id': 151,
#   'CODE': 'P__HAj_xci_od',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bbb978>},
#  152: {'id': 152,
#   'CODE': 'P__HAw_fr',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bbb828>},
#  153: {'id': 153,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bbba20>},
#  154: {'id': 154,
#   'CODE': 'P__HAo_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bbb048>},
#  155: {'id': 155,
#   'CODE': 'P__HAo_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bbbc88>},
#  156: {'id': 156,
#   'CODE': 'P__HAo_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bcb160>},
#  157: {'id': 157,
#   'CODE': 'P__HAo_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bcb2e8>},
#  158: {'id': 158,
#   'CODE': 'P__HAo_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bcb278>},
#  159: {'id': 159,
#   'CODE': 'P__HAo_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bcb2b0>},
#  160: {'id': 160,
#   'CODE': 'P__TKo_stq',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bbbb00>},
#  161: {'id': 161,
#   'CODE': 'P__TKo_stq',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bcbc50>},
#  162: {'id': 162,
#   'CODE': 'P__TKo_stq',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bcb320>},
#  163: {'id': 163,
#   'CODE': 'P__HAj_xci_od',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bcbd68>},
#  164: {'id': 164,
#   'CODE': 'P__WYm_sp',
#   'GROUP_': 'Wyloo_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bd70f0>},
#  165: {'id': 165,
#   'CODE': 'P__WYm_sp',
#   'GROUP_': 'Wyloo_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bd7278>},
#  166: {'id': 166,
#   'CODE': 'P__WYm_sp',
#   'GROUP_': 'Wyloo_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bd71d0>},
#  167: {'id': 167,
#   'CODE': 'P__WYm_sp',
#   'GROUP_': 'Wyloo_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bd7400>},
#  168: {'id': 168,
#   'CODE': 'P__WYm_sp',
#   'GROUP_': 'Wyloo_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bd7208>},
#  169: {'id': 169,
#   'CODE': 'P__SKq_stq',
#   'GROUP_': 'Shingle_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bd7198>},
#  170: {'id': 170,
#   'CODE': 'P__HAw_fr',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bcba58>},
#  171: {'id': 171,
#   'CODE': 'P__HAw_fr',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bdf0f0>},
#  172: {'id': 172,
#   'CODE': 'P__TKa_xs_k',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bdf748>},
#  173: {'id': 173,
#   'CODE': 'P__TKa_xs_k',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bdf4a8>},
#  174: {'id': 174,
#   'CODE': 'P__TKa_xs_k',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bdfb00>},
#  175: {'id': 175,
#   'CODE': 'P__TKa_xs_k',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bdf9b0>},
#  176: {'id': 176,
#   'CODE': 'A_FOr_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bdfa90>},
#  177: {'id': 177,
#   'CODE': 'A_FOr_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bdf390>},
#  178: {'id': 178,
#   'CODE': 'P__TKo_stq',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bdfd30>},
#  179: {'id': 179,
#   'CODE': 'P__TKk_sf',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bef080>},
#  180: {'id': 180,
#   'CODE': 'P__SKb_bb',
#   'GROUP_': 'Shingle_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bef518>},
#  181: {'id': 181,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bef208>},
#  182: {'id': 182,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19befac8>},
#  183: {'id': 183,
#   'CODE': 'A_FOr_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bef8d0>},
#  184: {'id': 184,
#   'CODE': 'A_FOr_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bef2e8>},
#  185: {'id': 185,
#   'CODE': 'A_FOh_xs_f',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19beffd0>},
#  186: {'id': 186,
#   'CODE': 'A_FOh_xs_f',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bfc7b8>},
#  187: {'id': 187,
#   'CODE': 'A_FOh_xs_f',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bfc0f0>},
#  188: {'id': 188,
#   'CODE': 'A_FOh_xs_f',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bfc320>},
#  189: {'id': 189,
#   'CODE': 'A_FOh_xs_f',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bfc940>},
#  190: {'id': 190,
#   'CODE': 'A_FOh_xs_f',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bfca58>},
#  191: {'id': 191,
#   'CODE': 'A_FOh_xs_f',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bfcba8>},
#  192: {'id': 192,
#   'CODE': 'A_FOo_bbo',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19c01198>},
#  193: {'id': 193,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19c01b70>},
#  194: {'id': 194,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19bfc470>},
#  195: {'id': 195,
#   'CODE': 'A_FOp_bs',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19c13208>},
#  196: {'id': 196,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19c13a90>},
#  197: {'id': 197,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19c01b00>},
#  198: {'id': 198,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19c20550>},
#  199: {'id': 199,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19c208d0>},
#  200: {'id': 200,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19c20748>},
#  201: {'id': 201,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19c20b00>},
#  202: {'id': 202,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19c20780>},
#  203: {'id': 203,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19c2a240>},
#  204: {'id': 204,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19c20630>},
#  205: {'id': 205,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19c2a8d0>},
#  206: {'id': 206,
#   'CODE': 'A_HAd_kd',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19c2ab00>},
#  207: {'id': 207,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19c2a860>},
#  208: {'id': 208,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19c2a7f0>},
#  209: {'id': 209,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19c2aef0>},
#  210: {'id': 210,
#   'CODE': 'P__HAj_xci_od',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x22c19c2acf8>}}

# %%
m2l_geometry.save_basal_no_faults(tmp_path+'basal_contacts.shp',tmp_path+'faults_clip.shp',ls_dict,10,c_l,dst_crs)
# Out:
# basal contacts without faults saved as ../test_data3/tmp/basal_contacts.shp

# %% [markdown]
# ## Remove faults from decimated basal contacts as save as csv file

# %%
contacts=gpd.read_file(tmp_path+'basal_contacts.shp')

m2l_geometry.save_basal_contacts_csv(contacts,output_path,dtm,contact_decimate)

#m2l_geometry.save_contacts_with_faults_removed(tmp_path+'faults_clip.shp',output_path,10,ls_dict,ls_dict_decimate,c_l,dst_crs,dtm)
# Out:
# decimated contacts saved as ../test_data3/output/contacts4.csv

# %% [markdown]
# ## Save fault as contact info and and orientation info make vertical (for the moment)

# %%
m2l_geometry.save_faults(tmp_path+'faults_clip.shp',output_path,dtm,c_l,fault_decimate,min_fault_length)
# Out:
# fault orientations saved as ../test_data3/output/fault_orientations.csv
# fault positions saved as ../test_data3/output/faults.csv
# fault dimensions saved as ../test_data3/output/fault_dimensions.csv

# %% [markdown]
# ## Create basal contact points with orientation from orientations and basal points

# %% [markdown]
# contacts = gpd.read_file(tmp_path+'basal_contacts2.shp') #load orientation data as geopandas dataframe
# structures = gpd.read_file(tmp_path+'structure_clip.shp') #load orientation data as geopandas dataframe
#
# m2l_geometry.create_basal_contact_orientations(contacts,structures,output_path,dtm,2500,ccode,gcode,dcode,ddcode)

# %% [markdown]
# ## Creates fold axial trace points

# %%
m2l_geometry.save_fold_axial_traces(tmp_path+'faults_clip.shp',output_path,dtm,c_l,fold_decimate)
# Out:
# fold axial traces saved as ../test_data3/output/fold_axial_traces.csv

# %% [markdown]
# ## Process plutons
#
# For each instruve but not sill polygon, find older neighbours and store decimated contact points. Also store dipping contact orientations (user defined, just because) with four possible sub-surface configurations:
#
# <b>saucers: \\_+++_/ <br>
# batholiths: +++/__ __ _\\+++  <br>
# domes: /‾+++‾\\ <br>
# pendants: +++\\_  _/+++ <br>
# </b>
#
# Saves out orientations and contact points, as well as updated group level stratigraphic column.<br>

# %%
bbox=(minx,miny,maxx,maxy)

pluton_dip=str(pluton_dip)

dist_buffer=10
dtm = rasterio.open(dtm_reproj_file)
m2l_geometry.process_plutons(tmp_path,output_path,geol_clip,local_paths,dtm,pluton_form,pluton_dip,contact_decimate,c_l)
# Out:
# 0 Wyloo_Group
# 1 Shingle_Creek_Group
# 2 Turee_Creek_Group
# 3 Hamersley_Group
# 4 Fortescue_Group
# 5 A_s_PMI
# 6 A_mgn_PMI
# 7 A_mgn_PRK
# 8 A_s_PRK
# 9 A_b_PRK
# pluton contacts and orientations saved as:
# ../test_data3/output/ign_contacts.csv
# ../test_data3/output/ign_orientations_domes.csv

# %% [markdown]
# ## Preprocess data to ensure it meets gempy's requirements

# %% [markdown]
# if(local_paths): ###############FUDGE#############
#     use_gcode=('Hamersley_Group','Fortescue_Group','Wyloo_Group','Shingle_Creek_Group','Turee_Creek_Group','A_mgn_PRK',  'A_mgn_PMI' ) ################# MOVE UP   #########################
# else:
#     use_gcode=('Hamersley_Group','Fortescue_Group','Wyloo_Group','Shingle_Creek_Group','Turee_Creek_Group','A_mgn_PMI_7366',  'A_mgn_PRK_16193' ) ################# MOVE UP   #########################
#
#
# print('only processing',use_gcode)
#
# m2l_geometry.tidy_data(output_path,tmp_path,use_gcode,use_interpolations,pluton_form)

# %% [markdown]
# m2l_topology.parse_fault_relationships(graph_path,tmp_path,output_path)

# %% [markdown]
# ## Interpolates a regular grid of orientations from an  shapefile of arbitrarily-located points and saves out four csv files of l,m & n direction cosines and dip dip direction data
#
# Can choose between various RBF and IDW options
#
# The purpose of these interpolations and associated code is to help in three cases:
# - Providing estimated dips and contacts in fault-bounded domains where no structural data are available
# - Needed to estimate true thickness of formations
# - Possibly useful for poulating parts of maps where little structural data is available

# %%
use_gcode=('Hamersley Group','Fortescue Group','Wyloo Group','Shingle Creek Group','Turee Creek Group' ) ################# MOVE UP   #########################
structure_file=tmp_path+'structure_clip.shp'
bbox=(minx+inset,miny+inset,maxx-inset,maxy-inset)

# %%
print(c_l['g'])
print(use_gcode)
# Out:
# GROUP_
# ('Hamersley Group', 'Fortescue Group', 'Wyloo Group', 'Shingle Creek Group', 'Turee Creek Group')

# %%
m2l_interpolation.interpolate_orientations(structure_file,tmp_path,bbox,c_l,use_gcode,scheme,gridx,gridy)
# Out:
#      DIP  DIP_DIR                          FEATURE  index_righ OBJECTID_1  \
# 6     44      359  Bedding, showing strike and dip          71        312
# 19    29      343  Bedding, showing strike and dip         134        666
# 21    52      185  Bedding, showing strike and dip           3         17
# 22    52      198  Bedding, showing strike and dip         124        642
# 28    10      354  Bedding, showing strike and dip         184        959
# 30     5       14  Bedding, showing strike and dip         119        635
# 31    14       55  Bedding, showing strike and dip         119        635
# 32     8      223  Bedding, showing strike and dip         119        635
# 34    20      313  Bedding, showing strike and dip         119        635
# 36    18       27  Bedding, showing strike and dip         119        635
# 38    33      180  Bedding, showing strike and dip         124        642
# 39    24      211  Bedding, showing strike and dip          84        350
# 40    25      349  Bedding, showing strike and dip           3         17
# 41    54      201  Bedding, showing strike and dip           3         17
# 42    19       33  Bedding, showing strike and dip           3         17
# 43    32      203  Bedding, showing strike and dip           3         17
# 44     9      191  Bedding, showing strike and dip           3         17
# 45    26      317  Bedding, showing strike and dip           3         17
# 46    41      290  Bedding, showing strike and dip         124        642
# 66    50       22  Bedding, showing strike and dip          16        113
# 67    70       24  Bedding, showing strike and dip          17        114
# 69    48      168  Bedding, showing strike and dip          17        114
# 74    35       80  Bedding, showing strike and dip          84        350
# 75    33      220  Bedding, showing strike and dip          84        350
# 76    28      307  Bedding, showing strike and dip         128        653
# 77    34        5  Bedding, showing strike and dip         128        653
# 79    25      172  Bedding, showing strike and dip          84        350
# 80     5      192  Bedding, showing strike and dip         119        635
# 81    15       19  Bedding, showing strike and dip         119        635
# 82    10       10  Bedding, showing strike and dip         119        635
# 83    24       43  Bedding, showing strike and dip         184        959
# 84    20       46  Bedding, showing strike and dip         184        959
# 85    10       34  Bedding, showing strike and dip         184        959
# 86     6      135  Bedding, showing strike and dip          11         64
# 87    14      206  Bedding, showing strike and dip         184        959
# 88    32       21  Bedding, showing strike and dip         184        959
# 89     2      316  Bedding, showing strike and dip         119        635
# 91    42       88  Bedding, showing strike and dip          34        159
# 94    12       25  Bedding, showing strike and dip          21        123
# 95    84      227  Bedding, showing strike and dip          21        123
# 118   20      247  Bedding, showing strike and dip         119        635
# 119   40       22  Bedding, showing strike and dip         184        959
#
#     OBJECTID LITHSTRTNO           CODE  \
# 6        278       4111  P_-HAj-xci-od
# 19       630       4124   A-HAS-xsl-ci
# 21        12       4113     P_-HAb-cib
# 22       606       2258      A-HAm-cib
# 28       919       4113     P_-HAb-cib
# 30       599       2258      A-HAm-cib
# 31       599       2258      A-HAm-cib
# 32       599       2258      A-HAm-cib
# 34       599       2258      A-HAm-cib
# 36       599       2258      A-HAm-cib
# 38       606       2258      A-HAm-cib
# 39       316       4124   A-HAS-xsl-ci
# 40        12       4113     P_-HAb-cib
# 41        12       4113     P_-HAb-cib
# 42        12       4113     P_-HAb-cib
# 43        12       4113     P_-HAb-cib
# 44        12       4113     P_-HAb-cib
# 45        12       4113     P_-HAb-cib
# 46       606       2258      A-HAm-cib
# 66        83       4104      P_-HAo-ci
# 67        84       4111  P_-HAj-xci-od
# 69        84       4111  P_-HAj-xci-od
# 74       316       4124   A-HAS-xsl-ci
# 75       316       4124   A-HAS-xsl-ci
# 76       617       2257       A-HAd-kd
# 77       617       2257       A-HAd-kd
# 79       316       4124   A-HAS-xsl-ci
# 80       599       2258      A-HAm-cib
# 81       599       2258      A-HAm-cib
# 82       599       2258      A-HAm-cib
# 83       919       4113     P_-HAb-cib
# 84       919       4113     P_-HAb-cib
# 85       919       4113     P_-HAb-cib
# 86        51       2257       A-HAd-kd
# 87       919       4113     P_-HAb-cib
# 88       919       4113     P_-HAb-cib
# 89       599       2258      A-HAm-cib
# 91       125       4124   A-HAS-xsl-ci
# 94        92       4113     P_-HAb-cib
# 95        92       4113     P_-HAb-cib
# 118      599       2258      A-HAm-cib
# 119      919       4113     P_-HAb-cib
#
#                                          UNITNAME GSWASTATUS       RANK  \
# 6                           Weeli Wolli Formation     Formal  Formation
# 19   Mount McRae Shale and Mount Sylvia Formation   Informal   Subgroup
# 21                        Brockman Iron Formation     Formal  Formation
# 22                     Marra Mamba Iron Formation     Formal  Formation
# 28                        Brockman Iron Formation     Formal  Formation
# 30                     Marra Mamba Iron Formation     Formal  Formation
# 31                     Marra Mamba Iron Formation     Formal  Formation
# 32                     Marra Mamba Iron Formation     Formal  Formation
# 34                     Marra Mamba Iron Formation     Formal  Formation
# 36                     Marra Mamba Iron Formation     Formal  Formation
# 38                     Marra Mamba Iron Formation     Formal  Formation
# 39   Mount McRae Shale and Mount Sylvia Formation   Informal   Subgroup
# 40                        Brockman Iron Formation     Formal  Formation
# 41                        Brockman Iron Formation     Formal  Formation
# 42                        Brockman Iron Formation     Formal  Formation
# 43                        Brockman Iron Formation     Formal  Formation
# 44                        Brockman Iron Formation     Formal  Formation
# 45                        Brockman Iron Formation     Formal  Formation
# 46                     Marra Mamba Iron Formation     Formal  Formation
# 66                       Boolgeeda Iron Formation     Formal  Formation
# 67                          Weeli Wolli Formation     Formal  Formation
# 69                          Weeli Wolli Formation     Formal  Formation
# 74   Mount McRae Shale and Mount Sylvia Formation   Informal   Subgroup
#
# 21                                        None            None       None
# 22                                        None            None       None
# 28                                        None            None       None
# 30                                        None            None       None
# 31                                        None            None       None
# 32                                        None            None       None
# 34                                        None            None       None
# 36                                        None            None       None
# 38                                        None            None       None
# 39   sedimentary other chemical or biochemical  iron formation       None
# 40                                        None            None       None
# 41                                        None            None       None
# 42                                        None            None       None
# 43                                        None            None       None
# 44                                        None            None       None
# 45                                        None            None       None
# 46                                        None            None       None
# 66                                        None            None       None
# 67                     igneous mafic intrusive            None   dolerite
# 69                     igneous mafic intrusive            None   dolerite
# 74   sedimentary other chemical or biochemical  iron formation       None
# 75   sedimentary other chemical or biochemical  iron formation       None
# 76                                        None            None       None
# 77                                        None            None       None
# 79   sedimentary other chemical or biochemical  iron formation       None
# 80                                        None            None       None
# 81                                        None            None       None
# 82                                        None            None       None
# 83                                        None            None       None
# 84                                        None            None       None
# 85                                        None            None       None
# 86                                        None            None       None
# 87                                        None            None       None
# 88                                        None            None       None
# 89                                        None            None       None
# 91   sedimentary other chemical or biochemical  iron formation       None
# 94                                        None            None       None
# 95                                        None            None       None
# 118                                       None            None       None
# 119                                       None            None       None
#
#     MIXEDQUAL2 WASTRAUNIT SUPERSUITE SUITE              SUPERGROUP  \
# 6         None       None       None  None  Mount Bruce Supergroup
# 19        None       None       None  None  Mount Bruce Supergroup
# 21        None       None       None  None  Mount Bruce Supergroup
# 22        None       None       None  None  Mount Bruce Supergroup
# 28        None       None       None  None  Mount Bruce Supergroup
# 30        None       None       None  None  Mount Bruce Supergroup
# 31        None       None       None  None  Mount Bruce Supergroup
# 32        None       None       None  None  Mount Bruce Supergroup
# 34        None       None       None  None  Mount Bruce Supergroup
# 36        None       None       None  None  Mount Bruce Supergroup
# 38        None       None       None  None  Mount Bruce Supergroup
# 39        None       None       None  None  Mount Bruce Supergroup
# 40        None       None       None  None  Mount Bruce Supergroup
# 41        None       None       None  None  Mount Bruce Supergroup
# 42        None       None       None  None  Mount Bruce Supergroup
# 43        None       None       None  None  Mount Bruce Supergroup
# 44        None       None       None  None  Mount Bruce Supergroup
# 45        None       None       None  None  Mount Bruce Supergroup
# 46        None       None       None  None  Mount Bruce Supergroup
# 66        None       None       None  None  Mount Bruce Supergroup
# 67        None       None       None  None  Mount Bruce Supergroup
# 69        None       None       None  None  Mount Bruce Supergroup
# 74        None       None       None  None  Mount Bruce Supergroup
# 75        None       None       None  None  Mount Bruce Supergroup
# 76        None       None       None  None  Mount Bruce Supergroup
# 77        None       None       None  None  Mount Bruce Supergroup
# 79        None       None       None  None  Mount Bruce Supergroup
# 80        None       None       None  None  Mount Bruce Supergroup
# 81        None       None       None  None  Mount Bruce Supergroup
# 82        None       None       None  None  Mount Bruce Supergroup
# 83        None       None       None  None  Mount Bruce Supergroup
# 84        None       None       None  None  Mount Bruce Supergroup
# 85        None       None       None  None  Mount Bruce Supergroup
# 86        None       None       None  None  Mount Bruce Supergroup
# 87        None       None       None  None  Mount Bruce Supergroup
# 88        None       None       None  None  Mount Bruce Supergroup
# 89        None       None       None  None  Mount Bruce Supergroup
# 91        None       None       None  None  Mount Bruce Supergroup
# 94        None       None       None  None  Mount Bruce Supergroup
# 95        None       None       None  None  Mount Bruce Supergroup
# 118       None       None       None  None  Mount Bruce Supergroup
# 119       None       None       None  None  Mount Bruce Supergroup
#
#               GROUP_                                      SUBGROUP  \
# 6    Hamersley Group                        Hamersley Group, upper
# 19   Hamersley Group  Mount McRae Shale and Mount Sylvia Formation
#
paleoproterozoic  Paleoproterozoic       2451       None       2450
# 19         Neoarchean        Neoarchean       2541       None       2501
# 21   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 22         Neoarchean        Neoarchean       2629       None       2597
# 28   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 30         Neoarchean        Neoarchean       2629       None       2597
# 31         Neoarchean        Neoarchean       2629       None       2597
# 32         Neoarchean        Neoarchean       2629       None       2597
# 34         Neoarchean        Neoarchean       2629       None       2597
# 36         Neoarchean        Neoarchean       2629       None       2597
# 38         Neoarchean        Neoarchean       2629       None       2597
# 39         Neoarchean        Neoarchean       2541       None       2501
# 40   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 41   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 42   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 43   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 44   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 45   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 46         Neoarchean        Neoarchean       2629       None       2597
# 66   Paleoproterozoic  Paleoproterozoic       2445       None       2208
# 67   Paleoproterozoic  Paleoproterozoic       2451       None       2450
# 69   Paleoproterozoic  Paleoproterozoic       2451       None       2450
# 74         Neoarchean        Neoarchean       2541       None       2501
# 75         Neoarchean        Neoarchean       2541       None       2501
# 76         Neoarchean        Neoarchean       2597          5       2504
# 77         Neoarchean        Neoarchean       2597          5       2504
# 79         Neoarchean        Neoarchean       2541       None       2501
# 80         Neoarchean        Neoarchean       2629       None       2597
# 81         Neoarchean        Neoarchean       2629       None       2597
# 82         Neoarchean        Neoarchean       2629       None       2597
# 83   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 84   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 85   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 86         Neoarchean        Neoarchean       2597          5       2504
# 87   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 88   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 89         Neoarchean        Neoarchean       2629       None       2597
# 91         Neoarchean        Neoarchean       2541       None       2501
# 94   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 95   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 118        Neoarchean        Neoarchean       2629       None       2597
# 119  Paleoproterozoic  Paleoproterozoic       2494       None       2451
#
#     MINUNCERTY MAX_AGE_DA MIN_AGE_DA  EXTRACT_DA  SHAPE_Leng ORIG_FID  \
# 6         None   Inferred   Inferred  2014-12-04    0.110114      277
# 19        None   Inferred   Inferred  2014-12-04    0.250994      629
# 21        None   Inferred   Inferred  2014-12-04    5.308226       11
# 22           5   Inferred   Isotopic  2014-12-04    3.207429      605
# 28        None   Inferred   Inferred  2014-12-04   11.316451      918
# 30           5   Inferred   Isotopic  2014-12-04    7.640042      598
# 31           5   Inferred   Isotopic  2014-12-04    7.640042      598
# 32           5   Inferred   Isotopic  2014-12-04    7.640042      598
# 34           5   Inferred   Isotopic  2014-12-04    7.640042      598
# 36           5   Inferred   Isotopic  2014-12-04    7.640042      598
# 38           5   Inferred   Isotopic  2014-12-04    3.207429      605
# 39        None   Inferred   Inferred  2014-12-04    1.322761      315
# 40        None   Inferred   Inferred  2014-12-04    5.308226       11
# 41        None   Inferred   Inferred  2014-12-04    5.308226       11
# 42        None   Inferred   Inferred  2014-12-04    5.308226       11
# 43        None   Inferred   Inferred  2014-12-04    5.308226       11
# 44        None   Inferred   Inferred  2014-12-04    5.308226       11
# 45        None   Inferred   Inferred  2014-12-04    5.308226       11
# 46           5   Inferred   Isotopic  2014-12-04    3.207429      605
# 66        None   Inferred   Inferred  2014-12-04    0.842299       82
# 67        None   Inferred   Inferred  2014-12-04    1.129298       83
# 69        None   Inferred   Inferred  2014-12-04    1.129298       83
# 74        None   Inferred   Inferred  2014-12-04    1.322761      315
# 75        None   Inferred   Inferred  2014-12-04    1.322761      315
# ...
# 32   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 34   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 36   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 38   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 39   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 40   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 41   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 42   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 43   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 44   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 45   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 46   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 66   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 67   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 69   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 74   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 75   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 76   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 77   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 79   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 80   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 81   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 82   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 83   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 84   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 85   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 86   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 87   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 88   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 89   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 91   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 94   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 95   Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 118  Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
# 119  Capricorn Orogen     None       None       None  Ophthalmia Fold Belt
#
#     OROG_FORSU IN_OUTLIER                                             EVENTS  \
# 6         None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 19        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 21        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 22        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 28        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 30        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 31        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 32        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 34        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 36        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 38        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 39        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 40        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 41        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 42        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 43        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 44        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 45        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 46        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 66        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 67        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 69        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 74        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 75        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 76        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 77        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 79        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 80        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 81        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 82        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 83        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 84        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 85        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 86        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 87        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 88        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 89        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 91        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 94        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 95        None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 118       None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
# 119       None       None  Capricorn Orogeny; Edmundian Orogeny; Miles Or...
#
#               AGEFROM             AGETO MAX_AGE_MA MAXUNCERTY MIN_AGE_MA  \
# 6    Paleoproterozoic  Paleoproterozoic       2451       None       2450
# 19         Neoarchean        Neoarchean       2541       None       2501
# 21   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 22         Neoarchean        Neoarchean       2629       None       2597
# 28   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 30         Neoarchean        Neoarchean       2629       None       2597
# 31         Neoarchean        Neoarchean       2629       None       2597
# 32         Neoarchean        Neoarchean       2629       None       2597
# 34         Neoarchean        Neoarchean       2629       None       2597
# 36         Neoarchean        Neoarchean       2629       None       2597
# 38         Neoarchean        Neoarchean       2629       None       2597
# 39         Neoarchean        Neoarchean       2541       None       2501
# 40   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 41   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 42   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 43   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 44   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 45   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 46         Neoarchean        Neoarchean       2629       None       2597
# 66   Paleoproterozoic  Paleoproterozoic       2445       None       2208
# 67   Paleoproterozoic  Paleoproterozoic       2451       None       2450
# 69   Paleoproterozoic  Paleoproterozoic       2451       None       2450
# 74         Neoarchean        Neoarchean       2541       None       2501
# 75         Neoarchean        Neoarchean       2541       None       2501
# 76         Neoarchean        Neoarchean       2597          5       2504
# 77         Neoarchean        Neoarchean       2597          5       2504
# 79         Neoarchean        Neoarchean       2541       None       2501
# 80         Neoarchean        Neoarchean       2629       None       2597
# 81         Neoarchean        Neoarchean       2629       None       2597
# 82         Neoarchean        Neoarchean       2629       None       2597
# 83   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 84   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 85   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 86         Neoarchean        Neoarchean       2597          5       2504
# 87   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 88   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 89         Neoarchean        Neoarchean       2629       None       2597
# 91         Neoarchean        Neoarchean       2541       None       2501
# 94   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 95   Paleoproterozoic  Paleoproterozoic       2494       None       2451
# 118        Neoarchean        Neoarchean       2629       None       2597
# 119  Paleoproterozoic  Paleoproterozoic       2494       None       2451
#
#     MINUNCERTY MAX_AGE_DA MIN_AGE_DA  EXTRACT_DA  SHAPE_Leng ORIG_FID  \
# 6         None   Inferred   Inferred  2014-12-04    0.110114      277
# 19        None   Inferred   Inferred  2014-12-04    0.250994      629
# 21        None   Inferred   Inferred  2014-12-04    5.308226       11
# 22           5   Inferred   Isotopic  2014-12-04    3.207429      605
# 28        None   Inferred   Inferred  2014-12-04   11.316451      918
# 30           5   Inferred   Isotopic  2014-12-04    7.640042      598
# 31           5   Inferred   Isotopic  2014-12-04    7.640042      598
# 32           5   Inferred   Isotopic  2014-12-04    7.640042      598
# 34           5   Inferred   Isotopic  2014-12-04    7.640042      598
# 36           5   Inferred   Isotopic  2014-12-04    7.640042      598
# 38           5   Inferred   Isotopic  2014-12-04    3.207429      605
# 39        None   Inferred   Inferred  2014-12-04    1.322761      315
# 40        None   Inferred   Inferred  2014-12-04    5.308226       11
# 41        None   Inferred   Inferred  2014-12-04    5.308226       11
# 42        None   Inferred   Inferred  2014-12-04    5.308226       11
# 43        None   Inferred   Inferred  2014-12-04    5.308226       11
# 44        None   Inferred   Inferred  2014-12-04    5.308226       11
# 45        None   Inferred   Inferred  2014-12-04    5.308226       11
# 46           5   Inferred   Isotopic  2014-12-04    3.207429      605
# 66        None   Inferred   Inferred  2014-12-04    0.842299       82
# 67        None   Inferred   Inferred  2014-12-04    1.129298       83
# 69        None   Inferred   Inferred  2014-12-04    1.129298       83
# 74        None   Inferred   Inferred  2014-12-04    1.322761      315
# 75        None   Inferred   Inferred  2014-12-04    1.322761      315
# 76        None   Isotopic   Inferred  2014-12-04    2.226145      616
# 77        None   Isotopic   Inferred  2014-12-04    2.226145      616
# 79        None   Inferred   Inferred  2014-12-04    1.322761      315
# 80           5   Inferred   Isotopic  2014-12-04    7.640042      598
#
# 82     7.640042    0.045693  POINT (546295.4105379576 7532604.629010826)
# 83    11.316451    0.492442  POINT (547505.9686688377 7536844.754766093)
# 84    11.316451    0.492442  POINT (553608.0573693756 7538142.808482063)
# 85    11.316451    0.492442  POINT (552841.2690654509 7546671.423356638)
# 86     5.611076    0.249778  POINT (571120.6228392244 7560759.886930016)
# 87    11.316451    0.492442  POINT (573333.3134094238 7547958.775480569)
# 88    11.316451    0.492442  POINT (568699.0559527974 7537244.204769069)
# 89     7.640042    0.045693  POINT (570473.7697480624 7530572.664886281)
# 91     1.067986    0.002524  POINT (567997.5259216769 7495674.383570734)
# 94     1.878346    0.017609  POINT (574022.9605266358 7481717.528795866)
# 95     1.878346    0.017609  POINT (573590.2007864462 7483267.530040545)
# 118    7.640042    0.045693  POINT (503356.6984616453 7533181.013372352)
# 119   11.316451    0.492442  POINT (523580.6783817719 7543711.048984814)
# orientations interpolated as dip dip direction ../test_data3/tmp/interpolation_scipy_rbf.csv
# orientations interpolated as l,m,n dir cos ../test_data3/tmp/interpolation_l.csv etc.

# %% [markdown]
# ## Interpolates a regular grid from a shapefile of from contacts and saves out three csv files of l & m direction cosines and strike data
#
# Can choose between various RBF and IDW options
#
# <font face color='red'>Best with basal contacts only, using Notebook #1 as this avoids intrusive  and fault contacts being considered</font>

# %%
geology_file=tmp_path+'basal_contacts.shp'

dtm = rasterio.open(dtm_reproj_file)
use_gcode=('Hamersley_Group','Fortescue_Group','Wyloo_Group','Shingle_Creek_Group','Turee_Creek_Group' ) ################# MOVE UP   #########################

# %%
m2l_interpolation.interpolate_contacts(geology_file,tmp_path,dtm,bbox,c_l,use_gcode,scheme,gridx,gridy)
# Out:
# contacts interpolated as strike ../test_data3/tmp/interpolation_contacts_scipy_rbf.csv
# contacts interpolated as l,m dir cos ../test_data3/tmp/interpolation_contacts_l.csv etc.

# %% [markdown]
# ## Combines rbf of contact orientations with rbf of dip/dipdir measurements
#
# Uses normalised direction cosines **(l,m,n)**:
# - **l,m** from RBF of basal contact orientations
# - **signs of l & m** from misorientation with RBF of orientation data and
# - **n** from RBF of orientation data
#
# May be useful for adding data where no orientations are available (e.g. in fault bounded domains) and for calculating true thickness of layers. Assumes a 2D plane of data, but if 3D RBF was calulated and projected contact info was used it should apply with topography too.

# %%
geology_file=tmp_path+'geol_clip.shp'
combo_file=tmp_path+'combo.csv'

lc=np.loadtxt(tmp_path+'interpolation_contacts_l.csv',skiprows =1,delimiter =',',dtype=float)
mc=np.loadtxt(tmp_path+'interpolation_contacts_m.csv',skiprows =1,delimiter =',',dtype=float)
lo=np.loadtxt(tmp_path+'interpolation_l.csv',skiprows =1,delimiter =',',dtype=float)
mo=np.loadtxt(tmp_path+'interpolation_m.csv',skiprows =1,delimiter =',',dtype=float)
no=np.loadtxt(tmp_path+'interpolation_n.csv',skiprows =1,delimiter =',',dtype=float)
xy=np.loadtxt(tmp_path+'interpolation_'+scheme+'.csv',skiprows =1,delimiter =',',dtype=float)

# %%
m2l_interpolation.join_contacts_and_orientations(combo_file,geology_file,tmp_path,dtm_reproj_file,c_l,lo,mo,no,lc,mc,xy,dst_crs,bbox)
# Out:
# {'init': 'EPSG:28350'} None
# C:\Users\00073294\AppData\Local\Continuum\anaconda3\lib\site-packages\geopandas\tools\sjoin.py:44: UserWarning: CRS of frames being joined does not match!
#   warn('CRS of frames being joined does not match!')
# contacts and orientations interpolated as dip dip direction ../test_data3/tmp/combo_full.csv

# %% [markdown]
# ## Preprocess data to ensure it meets gempy's requirements

# %%
if(local_paths): ###############FUDGE#############
    use_gcode=('Hamersley_Group','Fortescue_Group','Wyloo_Group','Shingle_Creek_Group','Turee_Creek_Group','A_mgn_PRK',  'A_mgn_PMI' ) ################# MOVE UP   #########################
else:
    use_gcode=('Hamersley_Group','Fortescue_Group','Wyloo_Group','Shingle_Creek_Group','Turee_Creek_Group','A_mgn_PMI_7366',  'A_mgn_PRK_16193' ) ################# MOVE UP   #########################


print('only processing',use_gcode)

#inputs=('invented_orientations','interpolated_orientations','intrusive_orientations','fat_orientations','near_fault_orientations')
inputs=('invented_orientations','interpolated_orientations','intrusive_orientations','fat_orientations','near_fault_orientations')

m2l_geometry.tidy_data(output_path,tmp_path,use_gcode,use_interpolations,use_fat,pluton_form,inputs)
# Out:
# only processing ('Hamersley_Group', 'Fortescue_Group', 'Wyloo_Group', 'Shingle_Creek_Group', 'Turee_Creek_Group', 'A_mgn_PRK', 'A_mgn_PMI')

# %% [markdown]
# ## Analyse fault-fault topology

# %%
m2l_topology.parse_fault_relationships(graph_path,tmp_path,output_path)
# Out:
# cycles [['Fault_2837', 'Fault_16825', 'Fault_7966', 'Fault_313'], ['Fault_813', 'Fault_958', 'Fault_16503']]

# %% [markdown]
# # loop2gemodeller test

# %%
save_faults=True

m2l_export.loop2geomodeller(test_data_path,tmp_path,output_path,'./dtm/hammersley_sheet_dtm.ers',bbox,save_faults,compute_etc)

# %%
os.chdir(test_data_path)
# %system geomodellerbatch.exe -batch m2l.taskfile
# Out:
# ['WARNING: An illegal reflective access operation has occurred',
#  'WARNING: Illegal reflective access by com.dfa.util.Lib (file:/C:/GeoModeller/GeoModeller4.0.7_x64_27eee3dc31ba/bin/plugins/au.com.dfa.intrepid.lib_6.0.0.201905221838.jar) to field java.lang.ClassLoader.loadedLibraryNames',
#  'WARNING: Please consider reporting this to the maintainers of com.dfa.util.Lib',
#  'WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations',
#  'WARNING: All illegal access operations will be denied in a future release',
#  'COMPOSE EXTRA LENGTH FOR A_mgn_PRK 0',
#  'COMPOSE EXTRA LENGTH FOR A_mgn_PMI 0',
#  'COMPOSE EXTRA LENGTH FOR Fortescue_Group 0',
#  'COMPOSE EXTRA LENGTH FOR Hamersley_Group 0',
#  'COMPOSE EXTRA LENGTH FOR Turee_Creek_Group 0',
#  'COMPOSE EXTRA LENGTH FOR Shingle_Creek_Group 0',
#  'COMPOSE EXTRA LENGTH FOR Wyloo_Group 0']

# %%
import winsound
duration = 500  # milliseconds
freq = 600  # Hz
winsound.Beep(freq, duration)
winsound.Beep(freq, duration)
winsound.Beep(freq, duration)
