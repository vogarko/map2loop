# %% [markdown]
# ## map2loop: From geology layers to outputs to various 3D modelling programs- Hamersley example (Geomodeller fix?)
#
# This notebook reads in three layers from  local or remote sources:  geology polygons, orientation data and fault polylines; and calculates the topological relationships between the different features. Requires compiled cpp code from Vitaliy Ogarko
#
# This all gets fed into successive tolopogical and geometric transfroms that end up feeding into geomodeller to make a 3D model
# <img src='../graphics/map_sm.png'>

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import os
import sys
import stat
import functools 
import operator  
import matplotlib
import networkx as nx
import rasterio
from shapely.geometry import Polygon
from map2loop import m2l_utils
from map2loop import m2l_topology
from map2loop import m2l_geometry
from map2loop import m2l_interpolation
from map2loop import m2l_export
# %matplotlib inline

#newwd="C:\\Users\\00073294\Dropbox\\loop_minex\\map2model\\"
#os.chdir(newwd)
print("Current Working Directory " )

gdal_data = os.environ['GDAL_DATA']
print("***",gdal_data)
print('is dir: ' + str(os.path.isdir(gdal_data)))
gcs_csv = os.path.join(gdal_data, 'gcs.csv')
print('is file: ' + str(os.path.isfile(gcs_csv)))
st = os.stat(gcs_csv)
print('is readable: ' + str(bool(st.st_mode & stat.S_IRGRP)))
os.environ['PROJ_LIB']=r"C:\\Users\\00073294\\AppData\\Local\\Continuum\\anaconda3\\Lib\\site-packages\\pyproj\\proj_dir\\share\\proj"
print(os.getenv('PROJ_LIB'))
print(os.getcwd())
# Out:
# Current Working Directory
# *** C:\Program Files\PostgreSQL\11\gdal-data
# is dir: True
# is file: True
# is readable: True
# C:\\Users\\00073294\\AppData\\Local\\Continuum\\anaconda3\\Lib\\site-packages\\pyproj\\proj_dir\\share\\proj
# C:\Users\00073294\Dropbox\1_Jupyter_notebooks\map2loop\notebooks

# %% [markdown]
# ## Create bounding box based on inputs

# %%
test_data_name='test_data3'

test_data_path='../'+test_data_name+'/'

os.chdir(test_data_path)
# %run -i "m2l_config.py"
#%run -i "m2l_config_remote.py"
print(os.getcwd())

bbox2=str(minx)+","+str(miny)+","+str(maxx)+","+str(maxy)
lat_point_list = [miny, miny, maxy, maxy, maxy]
lon_point_list = [minx, maxx, maxx, minx, minx]
bbox_geom = Polygon(zip(lon_point_list, lat_point_list))
polygon = gpd.GeoDataFrame(index=[0], crs=dst_crs, geometry=[bbox_geom]) 
bbox=(minx,miny,maxx,maxy)
# Out:
# Default parameters loaded from ../test_data3/m2l_config.py:
# #ROI
#
# step_out=0.1   #padding arounf dtm to ensure reprojected dtm covers target area (in degrees)
# inset=0      #unused??
#
# minx=500057  #region of interest coordinates in metre-based system (or non-degree system)
# maxx=603028
# miny=7455348
# maxy=7567953
# model_top=1200
# model_base=-8200
#
# #PATHS
#
# local_paths=True       #flag to use local or WFS source for data inputs (True = local)
#
# test_data_path='../test_data3/'
# m2m_cpp_path='../m2m_cpp/'
#
# geology_file='hams2_geol.shp'   #input geology file (if local)
# fault_file='GEOS_GEOLOGY_LINEARSTRUCTURE_500K_GSD.shp' #input fault file (if local)
# structure_file='hams2_structure.shp' #input bedding orientation file (if local)
# mindep_file='mindeps_2018.shp' #input mineral deposit file (if local)
#
#
# #CRS
#
# src_crs = {'init': 'EPSG:4326'}  # coordinate reference system for imported dtms (geodetic lat/long WGS84)
# dst_crs = {'init': 'EPSG:28350'} # coordinate system for data
#
# #codes and labels these refer to specific fields (codes) in GIS layer or database that contain the info needed for these calcs and text substrings (labels) in the contents of these fields
# c_l= {
# #Orientations
#   "d": "DIP",                  #field that contains dip information
#   "dd": "DIP_DIR",             #field that contains dip direction information
#   "sf": 'FEATURE',             #field that contains information on type of structure
#   "bedding": 'Bed',            #text to search for in field defined by sf code to show that this is a bedding measurement
# #Stratigraphy
#   "g": 'GROUP_',               #field that contains coarser stratigraphic coding
#   "c": 'CODE',                 #field that contains finer stratigraphic coding
#   "ds": 'DESCRIPTN',           #field that contains information about lithology
#   "u": 'UNITNAME',             #field that contains alternate stratigraphic coding (not used??)
#   "r1": 'ROCKTYPE1',           #field that contains  extra lithology information
#   "r2": 'ROCKTYPE2',           #field that contains even more lithology information
#   "sill": 'sill',              #text to search for in field defined by ds code to show that this is a sill
#   "intrusive": 'intrusive',    #text to search for in field defined by ds code to show that this is an intrusion
#   "volcanic": 'volcanic',      #text to search for in field defined by ds code to show that this is an intrusion
# #Mineral Deposits
#   "msc": 'SITE_CODE',          #field that contains site code of deposit
#   "msn": 'SHORT_NAME',         #field that contains short name of deposit
#   "mst": 'SITE_TYPE_',         #field that contains site type of deposit
#   "mtc": 'TARGET_COM',         #field that contains target commodity of deposit
#   "mscm": 'SITE_COMMO',        #field that contains site commodity of deposit
#   "mcom": 'COMMODITY_',        #field that contains commodity group of deposit
#   "minf": 'Infrastructure',    #text to search for in field defined by mst code that shows site to ignore
# #Timing
#   "min": 'MIN_AGE_MA',         #field that contains minimum age of unit defined by ccode
#   "max": 'MAX_AGE_MA',         #field that contains maximum age of unit defined by ccode
# #faults and folds
#   "f": 'FEATURE',              #field that contains information on type of structure
#   "fault": 'Fault',            #text to search for in field defined by f code to show that this is a fault
#   "fold": 'Fold axial trace',  #text to search for in field defined by f code to show that this is a fold axial trace
#   "n": 'NAME',                 #field that contains information on name of fault (not used??)
#   "t": 'TYPE',                 #field that contains information on type of fold
#   "syn": 'syncline',           #text to search for in field defined by t to show that this is a syncline
# #ids
#   "o": 'OBJECTID',             #field that contains unique id of geometry object
#   "gi": 'GEOPNT_ID'            #field that contains unique id of structure point
# }
#
# #DECIMATION
#
# orientation_decimate=0  #store every nth orientation (in object order) 0 = save all
# contact_decimate=10     #store every nth contact point (in object order) 0 = save all
# fault_decimate=5        #store every nth fault point (in object order) 0 = save all
# fold_decimate=5         #store every nth fold axial trace point (in object order) 0 = save all
#
#
# #INTERPOLATION
#
# gridx=50                #x grid dimensions (no of points, not distance) for interpolations
# gridy=50                #x grid dimensions (no of points, not distance) for interpolations
# scheme='scipy_rbf'      #interpolation scheme
# dist_buffer=5           #buffer distance for clipping points by faults (in metres or same units as dst_crs)
# intrusion_mode=0        # 1 all intrusions exluded from basal contacts, 0 only sills
# use_interpolations=False    # flag to sue interpolated orientations or not.
#
# #ASSUMPTIONS
#
# pluton_dip=45           #surface dip of pluton contacts
# pluton_form='domes'     #saucers: \__+_+__/  batholith: +/       \+   domes: /  +  + \  pendant: +\_____/+
# fault_dip=90            #surface dip of faults
#
# #DERIVED PATHS
#
#
# graph_path=test_data_path+'graph/'
# tmp_path=test_data_path+'tmp/'
# data_path=test_data_path+'data/'
# dtm_path=test_data_path+'dtm/'
# output_path=test_data_path+'output/'
# vtk_path=test_data_path+'vtk/'
#
# fault_file=data_path+fault_file
# structure_file=data_path+structure_file
# geology_file=data_path+geology_file
# mindep_file=data_path+mindep_file
#
# fault_file_csv=fault_file.replace(".shp",".csv").replace("/data/","/tmp/")
# structure_file_csv=structure_file.replace(".shp",".csv").replace("/data/","/tmp/")
# geology_file_csv=geology_file.replace(".shp",".csv").replace("/data/","/tmp/")
# mindep_file_csv=mindep_file.replace(".shp",".csv").replace("/data/","/tmp/")
#
# strat_graph_file=test_data_path+'graph/graph_strat.gml'
#
# dtm_file=dtm_path+'dtm.tif'
# dtm_reproj_file=dtm_path+'dtm_rp.tif'
#
# if(not os.path.isdir(test_data_path)):
#    os.mkdir(test_data_path)
# if(not os.path.isdir(tmp_path)):
#    os.mkdir(tmp_path)
# if(not os.path.isdir(output_path)):
#    os.mkdir(output_path)
# if(not os.path.isdir(dtm_path)):
#    os.mkdir(dtm_path)
# if(not os.path.isdir(vtk_path)):
#    os.mkdir(vtk_path)
# if(not os.path.isdir(graph_path)):
#    os.mkdir(graph_path)
#
# print('Default parameters loaded from '+test_data_path+'m2l_config.py:')
# with open(test_data_path+'m2l_config.py', 'r') as myfile:
#   data = myfile.read()
#   print(data)
#   myfile.close()
#
# print('\nModify these parameters in the cell below')
#
# Modify these parameters in the cell below
# C:\Users\00073294\Dropbox\1_Jupyter_notebooks\map2loop\test_data3

# %%
fold_decimate=2         

contact_decimate=5

use_interpolations=True       #use interpolated dips/contacts as additional constraints

use_fat=True                   #use fold axial trace orientation hints

pluton_form='domes'

fault_dip=-999

min_fault_length=5000

compute_etc=False

# %% [markdown]
# ## First we test to see if we have access to the online data we need

# %%
loopwfs=m2l_utils.have_access("geo.loop-gis.org")
hawaii=m2l_utils.have_access("pae-paha.pacioos.hawaii.edu")

if(not (loopwfs & hawaii)):
    local_paths=True
    net=False
    print('using local paths')
else:
    net=True
# Out:
# available: geo.loop-gis.org
# available: pae-paha.pacioos.hawaii.edu

# %% [markdown]
# ## Optional WFS source
#
# WFS brings in field names as lower case, so need to redefine codes too

# %%
if((not local_paths) and net):
    structure_file='http://geo.loop-gis.org/geoserver/loop/wfs?service=WFS&version=1.1.0&request=GetFeature&typeName=warox_points_f5011&bbox='+bbox2+'&srs=EPSG:28350'
    fault_file='http://geo.loop-gis.org/geoserver/loop/wfs?service=WFS&version=1.1.0&request=GetFeature&typeName=linear_500k&bbox='+bbox2+'&srs=EPSG:28350'
    geology_file='http://geo.loop-gis.org/geoserver/loop/wfs?service=WFS&version=1.0.0&request=GetFeature&typeName=loop:geol_500k&bbox='+bbox2+'&srs=EPSG:28350'

    c_l= {
    #Orientations
      "d": "dip",                  #field that contains dip information
      "dd": "dip_dir",             #field that contains dip direction information
      "sf": 'feature',             #field that contains information on type of structure
      "bedding": 'Bed',            #text to search for in field defined by sfcode to show that this is a bedding measurement
    #Stratigraphy
      "g": 'group_',               #field that contains coarser stratigraphic coding
      "c": 'code',                 #field that contains finer stratigraphic coding
      "ds": 'descriptn',           #field that contains information about lithology
      "u": 'unitname',             #field that contains alternate stratigraphic coding (not used??)
      "r1": 'rocktype1',           #field that contains  extra lithology information
      "r2": 'rocktype2',           #field that contains even more lithology information
      "sill": 'sill',              #text to search for in field defined by dscode to show that this is a sill
      "intrusive": 'intrusive',    #text to search for in field defined by dscode to show that this is an intrusion
      "volcanic": 'volcanic',      #text to search for in field defined by dscode to show that this is an intrusion
    #Mineral Deposits
      "msc": 'SITE_CODE',          #field that contains site code of deposit
      "msn": 'SHORT_NAME',         #field that contains short name of deposit
      "mst": 'SITE_TYPE_',         #field that contains site type of deposit
      "mtc": 'TARGET_COM',         #field that contains target commodity of deposit
      "mscm": 'SITE_COMMO',        #field that contains site commodity of deposit
      "mcom": 'COMMODITY_',        #field that contains commodity group of deposit
      "minf": 'Infrastructure',    #text to search for in field defined by mst code that shows site to ignore
    #Timing
      "min": 'min_age_ma',         #field that contains minimum age of unit defined by ccode
      "max": 'max_age_ma',         #field that contains maximum age of unit defined by ccode
    #faults and folds
      "f": 'feature',              #field that contains information on type of structure
      "fault": 'Fault',            #text to search for in field defined by fcode to show that this is a fault
      "fold": 'Fold axial trace',  #text to search for in field defined by fcode to show that this is a fold axial trace
      "n": 'name',                 #field that contains information on name of fault (not used??)
      "t": 'type',                 #field that contains information on type of fold
      "syn": 'syncline',           #text to search for in field defined by t to show that this is a syncline
    #ids
      "o": 'objectid',             #field that contains unique id of geometry object
      "gi": 'geopnt_id'            #field that contains unique id of structure point
    }

# %% [markdown]
# ## Plot geology polygons and bounding box

# %%
print(geology_file)
geology_ll = gpd.read_file(geology_file,bbox=bbox)

base=geology_ll.plot(column=c_l['c'],figsize=(10,10),edgecolor='#000000',linewidth=0.2)
polygon.plot(ax=base, color='none',edgecolor='black')
# Out:
# ../test_data3/data/hams2_geol.shp

# %% [markdown]
# ## Save geology to file as WKT

# %%
sub_geol = geology_ll[['geometry', c_l['o'],c_l['c'],c_l['g'],c_l['u'],c_l['min'],c_l['max'],c_l['ds'],c_l['r1'],c_l['r2']]]
m2l_topology.save_geol_wkt(sub_geol,geology_file_csv, c_l)
# Out:
# 186  polygons

# %% [markdown]
# ## Save mineral deposits to file as WKT
# This is not needed by map2loop to build 3D models, but is used by map2model to calculate mineral deposit/topology analyses.

# %%
mindep = gpd.read_file(mindep_file,bbox=bbox)

sub_mindep = mindep[['geometry', c_l['msc'],c_l['msn'],c_l['mst'],c_l['mtc'],c_l['mscm'],c_l['mcom']]]
m2l_topology.save_mindep_wkt(sub_mindep,mindep_file_csv, c_l)

base=sub_mindep.plot()
polygon.plot(ax=base, color='none',edgecolor='black')
# Out:
# 410  points

# %% [markdown]
# ## Read and save WAROX point data as WKT

# %%
warox = gpd.read_file(structure_file,bbox=bbox)

sub_pts = warox[['geometry', c_l['gi'],c_l['d'],c_l['dd']]]

m2l_topology.save_structure_wkt(sub_pts,structure_file_csv,c_l)

base=sub_pts.plot()
polygon.plot(ax=base, color='none',edgecolor='black')
# Out:
# 121  points

# %% [markdown]
# ## Plot faults and bounding box

# %%
lines_ll=gpd.read_file(fault_file,bbox=bbox)

base2=lines_ll.plot(cmap='rainbow',column=c_l['f'],figsize=(10,10),linewidth=0.4)
polygon.plot(ax=base2, color='none',edgecolor='black')

# %% [markdown]
# ## Save faults to file as WKT

# %%
sub_lines = lines_ll[['geometry', c_l['o'],c_l['f']]]
m2l_topology.save_faults_wkt(sub_lines,fault_file_csv,c_l)
# Out:
# 134  polylines

# %% [markdown]
# ## Create map2model input file

# %%
m2l_topology.save_Parfile(m2m_cpp_path,c_l,graph_path,geology_file_csv,fault_file_csv,structure_file_csv,minx,maxx,miny,maxy)

# %% [markdown]
# ## Calculate topology

# %%
os.chdir(m2m_cpp_path)
print(os.getcwd())
# %system map2model.exe Parfile
# Out:
# C:\Users\00073294\Dropbox\1_Jupyter_notebooks\map2loop\m2m_cpp
# ['Reading data from the file: Parfile',
#  '--- COLUMN NAMES IN CSV DATA FILES: -------------------------------------------------------------',
#  'OBJECT COORDINATES              =WKT',
#  'FAULT: ID                       =OBJECTID',
#  'FAULT: FEATURE                  =FEATURE',
#  'POINT: ID                       =GEOPNT_ID',
#  'POINT: DIP                      =DIP',
#  'POINT: DIP DIR                  =DIP_DIR',
#  'POLYGON: ID                     =OBJECTID',
#  'POLYGON: LEVEL1 NAME            =UNITNAME',
#  'POLYGON: LEVEL2 NAME            =GROUP_',
#  'POLYGON: MIN AGE                =MIN_AGE_MA',
#  'POLYGON: MAX AGE                =MAX_AGE_MA',
#  'POLYGON: CODE                   =CODE',
#  'POLYGON: DESCRIPTION            =DESCRIPTN',
#  'POLYGON: ROCKTYPE1              =ROCKTYPE1',
#  'POLYGON: ROCKTYPE2              =ROCKTYPE2',
#  '--- SOME CONSTANTS: ----------------------------------------------------------------------------',
#  'FAULT AXIAL FEATURE NAME        =Fold axial trace',
#  'SILL UNIT DESCRIPTION CONTAINS  =sill',
#  'IGNEOUS ROCKTYPE CONTAINS                           =intrusive',
#  'VOLCANIC ROCKTYPE CONTAINS                          =volcanic',
#  'Intersect Contact With Fault: angle epsilon (deg)   =1',
#  'Intersect Contact With Fault: distance epsilon (m)  =15',
#  '------------------------------------------------------------------------------------------------',
#  'Path to the output data folder                      =../test_data3/graph/',
#  'Path to geology data file                           =../test_data3/tmp/hams2_geol.csv',
#  'Path to faults data file                            =../test_data3/tmp/GEOS_GEOLOGY_LINEARSTRUCTURE_500K_GSD.csv',
#  'Path to points data file                            =../test_data3/tmp/hams2_structure.csv',
#  '------------------------------------------------------------------------------------------------',
#  'Clipping window X1 Y1 X2 Y2 (zeros for infinite)    =500057 7.45535e+06 603028 7.56795e+06',
#  'Min length fraction for strat/fault graphs          =0',
#  'Graph edge width categories (three doubles)         =2000 20000 200000',
#  'Graph edge direction (0-min age, 1-max age, 2-avg)  =2',
#  'Partial graph polygon ID                            =32',
#  'Partial graph depth                                 =4',
#  'Map subregion size dx, dy [m] (zeros for full map)  =0 0',
#  '------------------------------------------------------------------------------------------------',
#  'Reading data from the file ../test_data3/tmp/GEOS_GEOLOGY_LINEARSTRUCTURE_500K_GSD.csv',
#  'Objects read: 104',
#  'Reading data from the file ../test_data3/tmp/hams2_structure.csv',
#  'Objects read: 121',
#  'Reading data from the file ../test_data3/tmp/hams2_geol.csv',
#  'Objects read: 186',
#  'Multipolygons left (after clipping): 186',
#  'Faults left (after clipping): 104',
#  'Window perimeter = 431152',
#  'Building lists of units and groups...',
#  'Number of units: 29',
#  'Total unit length = 11506904.249082',
#  '1 Fortescue Group',
#  '2 Hamersley Group',
#  '3 A-b-PRK',
#  '4 A-mgn-PMI',
#  '5 A-mgn-PRK',
#  '6 A-s-PMI',
#  '7 A-s-PRK',
#  '8 Shingle Creek Group',
#  '9 Turee Creek Group',
#  '10 Wyloo Group',
#  'Intersecting faults with polygons...',
#  'Wrote 26 items to unit-fault intersection list: ../test_data3/graph//unit-fault-intersection.txt',
#  'Intersecting faults with faults...',
#  'Wrote 48 items to fault-fault intersection list: ../test_data3/graph//fault-fault-intersection.txt',
#  'Finding contacts...',
#  'numCommonEdges = 15268',
#  'Total contact length = 5537876.124541',
#  'Identifying contact types...',
#  'Total number of intersections: 681',
#  'Number of all contacts: 400',
#  'Number of fault-contacts: 96',
#  'Number of mixed-contacts: 141',
#  'Splitting mixed contacts...',
#  'Number of contacts after splitting: 764',
#  'PERIMETER LENGTHS: 11506904.249082 11506904.249082 0',
#  'Finding unit-contacts...',
#  'Number of unit-contacts: 75',
#  'Number of unit-contacts = 75',
#  'Number of stratigraphic unit-contacts = 17',
#  'Number of fault unit-contacts = 21',
#  'Number of mixed unit-contacts = 37',
#  'Identifying igneous contacts...',
#  'Number of intrusive igneous unit contacts: 23',
#  'Number of igneous unit contacts: 5',
#  'Writing topology graph to a file: ../test_data3/graph//graph_all.gml',
#  'Number of units in the graph: 29',
#  'Number of groups in the graph: 10',
#  'Writing topology graph to a file: ../test_data3/graph//graph_strat.gml',
#  'Number of units in the graph: 29',
#  'Number of groups in the graph: 10',
#  'Writing topology graph to a file: ../test_data3/graph//graph_fault.gml',
#  'Number of units in the graph: 26',
#  'Number of groups in the graph: 9',
#  'Writing topology graph to a file: ../test_data3/graph//graph_ingeous.gml',
#  'Number of units in the graph: 29',
#  'Number of groups in the graph: 10',
#  'Number of filtered contacts: 8068',
#  'Number of unique filtered contacts: 60',
#  'Finding unit-contacts...',
#  'Number of unit-contacts: 14',
#  'Number of unit-contacts = 14',
#  'Number of stratigraphic unit-contacts = 10',
#  'Number of fault unit-contacts = 0',
#  'Number of mixed unit-contacts = 4',
#  'Writing topology graph to a file: ../test_data3/graph//graph_partial.gml',
#  'Number of units in the graph: 10',
#  'Number of groups in the graph: 4',
#  'End.']

# %% [markdown]
# ## Simple network graph of the geology with legend

# %%
G=nx.read_gml(strat_graph_file,label='id')
selected_nodes = [n for n,v in G.nodes(data=True) if n >=0]
nx.draw_networkx(G, pos=nx.kamada_kawai_layout(G), arrows=True, nodelist=selected_nodes)

nlist=list(G.nodes.data('LabelGraphics'))
nlist.sort()
for no in nlist:
    if(no[0]>=0):
        elem=str(no[1]).replace("{'text':","").replace(", 'fontSize': 14}","")
        #second=elem.split(":").replace("'","")
        print(no[0]," ",elem)
# Out:
# C:\Users\00073294\AppData\Local\Continuum\anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\00073294\AppData\Local\Continuum\anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# 0    'A-HAm-cib'
# 1    'A-FOp-bs'
# 2    'A-HAS-xsl-ci'
# 3    'P_-HAb-cib'
# 4    'P_-HAj-xci-od'
# 5    'A-mgn-PRK'
# 6    'A-FOh-xs-f'
# 7    'A-FOo-bbo'
# 8    'A-FO-od'
# 9    'A-HAd-kd'
# 10    'A-FOj-xs-b'
# 11    'P_-TKa-xs-k'
# 12    'P_-HAo-ci'
# 13    'P_-HAw-fr'
# 14    'A-FO-xo-a'
# 15    'A-b-PRK'
# 16    'A-FOr-b'
# 17    'A-FOu-bbo'
# 18    'P_-TK-s'
# 19    'A-mgn-PMI'
# 20    'A-s-PMI'
# 21    'A-s-PRK'
# 22    'P_-SKq-stq'
# 23    'P_-WYm-sp'
# 24    'P_-WYa-st'
# 25    'P_-WYd-kd'
# 26    'P_-TKo-stq'
# 27    'P_-TKk-sf'
# 28    'P_-SKb-bb'

# %% [markdown]
# ## Detailed Topology via dot or gml format files
# For a more detailed look we can open up the online version of <b>yEd</b> <a href="https://www.yworks.com/yed-live/" >https://www.yworks.com/yed-live/</a>  and load in the *.dot file that we will now create or dowload the <a href="https://www.yworks.com/products/yed/download">yEd program</a> and look at the *.gml files in the <b>output</b> directory

# %% [markdown]
# from networkx.drawing.nx_pydot import write_dot
#
# import filer,gfiler
#
# filepath=filer.gui_fname().decode('UTF-8')
# write_dot(G,filepath)

# %% [markdown]
# http://localhost:8888/notebooks/Dropbox/1_Jupyter_notebooks/map2loop/notebooks/2.%20map2loop_after_topology.ipynb

# %% [markdown]
# ## Process topography, stratigraphy, fold axial traces and faults
#
# ### Takes GML file produced by topology code, combines with geology polygons, structure points and dtm to create 3D model in gempy.<br><br>
#
# Limitations:  no dykes, no sills. Sills require us to assign a unique surface to each instance of a sill (sill between units A and B needs to be different from sill of same age and strat codes as one found between E and F). Dykes via cokriging are really hard without just cookie cutting them in (but that is not our problem!). We are not checking for onlap relationships, which can perhaps been seen by having lots of units from one series adjacent to the youngest surface of the older series. Could also think about interpreting these as faults to introduce conceptual uncertainty. All mistakes belong to Mark Jessell, topology code that feeds this system by Vitaliy Ogarko.<br><br>
#
# Geology layer needs to have some unique strat code or text, some group code or text to function<br>
# Structure layer needs dip/dip direction<br>
#
# <font color='red'>Currently mostly hardwired to GSWA 500K map so needs work...</font>

# %%
os.chdir('../map2loop')

print(os.getcwd())
# Out:
# C:\Users\00073294\Dropbox\1_Jupyter_notebooks\map2loop\map2loop

# %%
#from IPython.core.display import display, HTML
#display(HTML("<style>.container { width:80% !important; }</style>"))

sys.path.insert(0,"../..")
print(os.getcwd())


#print(os.getcwd())
#os.environ["PROJ_LIB"] = r"C:\Users\00073294\AppData\Local\Continuum\anaconda3\Lib\site-packages\pyproj\proj_dir\share\proj"
# Out:
# C:\Users\00073294\Dropbox\1_Jupyter_notebooks\map2loop\map2loop

# %% [markdown]
# ## Next we define an area of interest and some other basic stuff

# %%
print(os.getcwd())
#test_data_path='../test_data3/'


#%run -i "../test_data3/m2l_config.py"

bbox2=str(minx)+","+str(miny)+","+str(maxx)+","+str(maxy)
lat_point_list = [miny, miny, maxy, maxy, maxy]
lon_point_list = [minx, maxx, maxx, minx, minx]
bbox_geom = Polygon(zip(lon_point_list, lat_point_list))
polygon = gpd.GeoDataFrame(index=[0], crs=dst_crs, geometry=[bbox_geom]) 
bbox=(minx,miny,maxx,maxy)

step_out=0.045 #add (in degrees) so edge pixel from dtm reprojection are not found


#contact_decimate=5
# Out:
# C:\Users\00073294\Dropbox\1_Jupyter_notebooks\map2loop\map2loop

# %% [markdown]
# ## Download and reproject the appropriate SRTM data
# mj: Getting this from GA, but could also get from Hawaii

# %%
polygon_ll=polygon.to_crs(src_crs)

minlong=polygon_ll.total_bounds[0]-step_out
maxlong=polygon_ll.total_bounds[2]+step_out
minlat=polygon_ll.total_bounds[1]-step_out
maxlat=polygon_ll.total_bounds[3]+step_out

print(minlong,maxlong,minlat,maxlat)
if((not local_paths) and net):     
    m2l_utils.get_dtm(dtm_file, minlong,maxlong,minlat,maxlat)
    geom_rp=m2l_utils.reproject_dtm(dtm_file,dtm_reproj_file,src_crs,dst_crs)
# Out:
# 116.9555521867685 118.0503484485386 -23.055227990891293 -21.94491765252865

# %% [markdown]
# ## Load stratigraphy graph and create list of series (aka groups)
# mj: The choice of what constitutes basic unit and what a group of units is hard-wired at the moment, but could be altered to any pair. Not even sure we need two levels but it seemed like a good idea at the time. Note that this needs the arcgis plugin version of the topology code (for now) as it seperates the different sub graphs. Text outputs list alternate topologies for series and surfaces, which if confirmed by comapring max-min ages will be a nice source of uncertainty.

# %%
groups,glabels,G = m2l_topology.get_series(strat_graph_file,'id')
m2l_topology.save_units(G,tmp_path,glabels)

# %% [markdown]
# ## Load geology & structure data
# Currently loading from local files, but could load geology from WFS server at GSWA EXCEPT that the WFS online map has less fields that the zipped shapefiles. Go figure. We don't use fault layer at the moment (except for Vitaliy's topology code) but same logic applies in terms of where to get it from. Already have fault/strat relationships and once we have fault/fault relationships will start to include faults in models.

# %%
# Extract point data from structure & geology layers for modelling
##First we readin the structure and map from shapefiles, or wherever...

bbox=(minx,miny,maxx,maxy)
geology = gpd.read_file(geology_file,bbox=bbox)


structure = gpd.read_file(structure_file,bbox=bbox)
structure.crs=dst_crs
print(fault_file)
faults = gpd.read_file(fault_file,bbox=bbox)
faults.crs=dst_crs
#display(faults)
sub_pts = structure[['geometry',c_l['d'],c_l['dd'],c_l['sf']]] 

base=geology.plot(column=c_l['c'],figsize=(10,10),edgecolor='#000000',linewidth=0.2)
sub_pts.plot(ax=base,edgecolor='black')
faults.plot(ax=base, column=c_l['f'],edgecolor='black')
# Out:
# ../test_data3/data/GEOS_GEOLOGY_LINEARSTRUCTURE_500K_GSD.shp

# %% [markdown]
# ## Clip geology, faults, structures and map geology to structures

# %%
geology = m2l_utils.explode(geology)
geology.crs = dst_crs
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows',None)
structure_code = gpd.sjoin(sub_pts, geology, how="left", op="within")

y_point_list = [miny, miny, maxy, maxy, miny]
x_point_list = [minx, maxx, maxx, minx, minx]

bbox_geom = Polygon(zip(x_point_list, y_point_list))

polygo = gpd.GeoDataFrame(index=[0], crs=dst_crs, geometry=[bbox_geom]) 
#display(polygo.geometry)
is_bed=structure_code[c_l['sf']].str.contains(c_l['bedding'], regex=False) 
    
all_beds = structure_code[is_bed]
#display(sfcode)
all_folds=faults[faults[c_l['f']].str.contains(c_l['fold'])]
folds_clip=m2l_utils.clip_shp(all_folds,polygo)
folds_clip.to_file(tmp_path+'folds_clip.shp')


all_faults=faults[faults[c_l['f']].str.contains(c_l['fault'])]



#display(structure_code)
geol_clip=m2l_utils.clip_shp(geology, polygo)
faults_clip=m2l_utils.clip_shp(all_faults,polygo)
#display(faults_clip)
structure_clip = m2l_utils.clip_shp(all_beds, polygo)

base = geol_clip.plot(column=c_l['c'],figsize=(7,7),edgecolor='#000000',linewidth=0.2)
faults_clip.plot(ax=base, column=c_l['t'],edgecolor='black')
structure_clip.plot(ax=base, column=c_l['c'],edgecolor='black')


if(c_l['dd']=='strike'):
    structure_clip['azimuth2'] = structure_clip.apply(lambda row: row[c_l['dd']]+90.0, axis = 1)
    c_l['dd']='azimuth2'
    
    
geol_clip.to_file(tmp_path+'geol_clip.shp')
faults_clip.to_file(tmp_path+'faults_clip.shp')
structure_clip.to_file(tmp_path+'structure_clip.shp')

# %% [markdown]
# ## Create possible stratigraphy sets per group
# mj: <font color='red'>Uses first of each possible set of toplogies per unit and per group, which is arbitrary. </font>On the other hand we are not checking relative ages again to see if this helps reduce ambiguity, which I think it would.

# %%
m2l_topology.save_group(G,tmp_path,glabels,geol_clip,c_l)
# Out:
#                      index     min     max     ave
# group_
# Wyloo_Group              0  1799.0  2010.0  1904.5
# Shingle_Creek_Group      1  2208.0  2208.0  2208.0
# Turee_Creek_Group        2  2208.0  2449.0  2328.5
# Hamersley_Group          3  2208.0  2629.0  2418.5
# Fortescue_Group          4  2629.0  2780.0  2704.5
# A_mgn_PMI                5  2830.0  3500.0  3165.0
# A_mgn_PRK                6  2830.0  3500.0  3165.0
# A_s_PMI                  7  2930.0  3520.0  3225.0
# A_b_PRK                  8  2930.0  3520.0  3225.0
# A_s_PRK                  9  2930.0  3520.0  3225.0
# []
# group choices: 40

# %% [markdown]
# ## Export orientation data in csv  format
# mj: Orientation data needs calculated height as file does not provide it, taken from SRTM data already downloaded. To calculate polarity <font color='red'>(WHICH WE DON'T DO YET)</font> we can calculate the dot product of the dip direction of a bedding plane and the vector to that points nearest basal contact node, if  abs(acos(dot product))>90  then right way up :
#
# <img src='../graphics/polarity.png'>
#
# Added code to not save intrusion orientation data as they won't have associated surfaces if sill...

# %%
dtm = rasterio.open(dtm_reproj_file)
m2l_geometry.save_orientations(structure_clip,output_path,c_l,orientation_decimate,dtm)
# Out:
# 115 orientations saved to ../test_data3/output//orientations.csv

# %% [markdown]
# ## Find those series that don't have any orientation or contact point data  then create arbitrary point for series with no orientation data
# Not sure if gempy needs this but geomodeller does. Currently just gives a point dipping 45 degrees to North, but could use dip direction normal to basal surface)

# %%
m2l_geometry.create_orientations( tmp_path, output_path, dtm,geol_clip,structure_clip,c_l)
# Out:
# extra orientations saved as ../test_data3/output//empty_series_orientations.csv

# %% [markdown]
# ## Export contact information subset of each polygon to gempy format
# mj: Orientation data needs calculated height as file does not provide it, taken from SRTM data already downloaded. Need to reduce number of points whilst retaining useful info (Ranee's job!)'
# To calculate which are the basal units contact for a polygon find the polygons which are older than the selected polygon, in the example below the central polygon has relative age 23 so its basal contact is with the polygons whose ages are 26 & 28. If there are no older units for a polygon it has no basal content. We keep every nth node based on the decimate term (simple count along polyline). gempy seems to need at least two points per surface, so we always take the first two points.
#
#
# <img src='../graphics/base.png'>

# %%
ls_dict,ls_dict_decimate=m2l_geometry.save_basal_contacts(tmp_path,dtm,geol_clip,contact_decimate,c_l,intrusion_mode)
# Out:
# basal contacts saved allpts= 10902 deci_pts= 2603
# saved as ../test_data3/tmp/all_contacts.csv and ../test_data3/tmp/contacts.csv

# %% [markdown]
# ## Remove all basal contacts that are defined by faults and save to shapefile (no decimation)

# %%
display(ls_dict)
# Out:
# {0: {'id': 0,
#   'CODE': 'A_FOp_bs',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6525320>},
#  1: {'id': 1,
#   'CODE': 'A_FOo_bbo',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6525f28>},
#  2: {'id': 2,
#   'CODE': 'A_FOh_xs_f',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d640fa90>},
#  3: {'id': 3,
#   'CODE': 'A_FOh_xs_f',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6425828>},
#  4: {'id': 4,
#   'CODE': 'A_FOh_xs_f',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d625a978>},
#  5: {'id': 5,
#   'CODE': 'A_s_PMI',
#   'GROUP_': 'A_s_PMI',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d640f198>},
#  6: {'id': 6,
#   'CODE': 'A_HAd_kd',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d63687f0>},
#  7: {'id': 7,
#   'CODE': 'A_FOp_bs',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d632c978>},
#  8: {'id': 8,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d622da20>},
#  9: {'id': 9,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d637e320>},
#  10: {'id': 10,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d60f77b8>},
#  11: {'id': 11,
#   'CODE': 'A_HAd_kd',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6107b00>},
#  12: {'id': 12,
#   'CODE': 'A_HAd_kd',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d639f358>},
#  13: {'id': 13,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d639f2b0>},
#  14: {'id': 14,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d639f198>},
#  15: {'id': 15,
#   'CODE': 'A_FOu_bbo',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d639f4a8>},
#  16: {'id': 16,
#   'CODE': 'A_FOu_bbo',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d639f710>},
#  17: {'id': 17,
#   'CODE': 'A_FOu_bbo',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d639f400>},
#  18: {'id': 18,
#   'CODE': 'A_FOu_bbo',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d639fc18>},
#  19: {'id': 19,
#   'CODE': 'A_FOu_bbo',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77330f0>},
#  20: {'id': 20,
#   'CODE': 'A_HAd_kd',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d639f978>},
#  21: {'id': 21,
#   'CODE': 'A_HAd_kd',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d639f1d0>},
#  22: {'id': 22,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d62bce10>},
#  23: {'id': 23,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d7733ac8>},
#  24: {'id': 24,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d62bc780>},
#  25: {'id': 25,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d62bc320>},
#  26: {'id': 26,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d61c6630>},
#  27: {'id': 27,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d61c65c0>},
#  28: {'id': 28,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6181ba8>},
#  29: {'id': 29,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d61c6588>},
#  30: {'id': 30,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6181828>},
#  31: {'id': 31,
#   'CODE': 'P__HAo_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d62bc390>},
#  32: {'id': 32,
#   'CODE': 'P__TK_s',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d61815c0>},
#  33: {'id': 33,
#   'CODE': 'P__HAw_fr',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6181cf8>},
#  34: {'id': 34,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d61816d8>},
#  35: {'id': 35,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d643c208>},
#  36: {'id': 36,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d643c7b8>},
#  37: {'id': 37,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d638b6d8>},
#  38: {'id': 38,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d638b080>},
#  39: {'id': 39,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d638b8d0>},
#  40: {'id': 40,
#   'CODE': 'A_HAd_kd',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d638b390>},
#  41: {'id': 41,
#   'CODE': 'A_HAd_kd',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6197ba8>},
#  42: {'id': 42,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6197e80>},
#  43: {'id': 43,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6197a90>},
#  44: {'id': 44,
#   'CODE': 'P__HAj_xci_od',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6197c88>},
#  45: {'id': 45,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d61975c0>},
#  46: {'id': 46,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6197898>},
#  47: {'id': 47,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6197e48>},
#  48: {'id': 48,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6197588>},
#  49: {'id': 49,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6197518>},
#  50: {'id': 50,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6197780>},
#  51: {'id': 51,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6197cc0>},
#  52: {'id': 52,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6454f28>},
#  53: {'id': 53,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d64545f8>},
#  54: {'id': 54,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d61970b8>},
#  55: {'id': 55,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6454710>},
#  56: {'id': 56,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d614c9e8>},
#  57: {'id': 57,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d614ca20>},
#  58: {'id': 58,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d614c0b8>},
#  59: {'id': 59,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6197860>},
#  60: {'id': 60,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d614c240>},
#  61: {'id': 61,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d614c7f0>},
#  62: {'id': 62,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d614cf98>},
#  63: {'id': 63,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d614cc50>},
#  64: {'id': 64,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d614c4a8>},
#  65: {'id': 65,
#   'CODE': 'A_HAd_kd',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d614ca58>},
#  66: {'id': 66,
#   'CODE': 'A_HAd_kd',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d614c048>},
#  67: {'id': 67,
#   'CODE': 'A_HAd_kd',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6405ef0>},
#  68: {'id': 68,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6405b38>},
#  69: {'id': 69,
#   'CODE': 'A_HAd_kd',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6405198>},
#  70: {'id': 70,
#   'CODE': 'A_HAd_kd',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6405c50>},
#  71: {'id': 71,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6405278>},
#  72: {'id': 72,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6405390>},
#  73: {'id': 73,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6405fd0>},
#  74: {'id': 74,
#   'CODE': 'P__HAj_xci_od',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d64050f0>},
#  75: {'id': 75,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d64052b0>},
#  76: {'id': 76,
#   'CODE': 'P__HAw_fr',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6405a20>},
#  77: {'id': 77,
#   'CODE': 'P__HAw_fr',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6405e10>},
#  78: {'id': 78,
#   'CODE': 'P__HAw_fr',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6452278>},
#  79: {'id': 79,
#   'CODE': 'P__HAw_fr',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6452208>},
#  80: {'id': 80,
#   'CODE': 'P__HAw_fr',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6452518>},
#  81: {'id': 81,
#   'CODE': 'A_HAd_kd',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d64456a0>},
#  82: {'id': 82,
#   'CODE': 'A_HAd_kd',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d64522b0>},
#  83: {'id': 83,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d64527f0>},
#  84: {'id': 84,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6452400>},
#  85: {'id': 85,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d63bbf28>},
#  86: {'id': 86,
#   'CODE': 'P__HAj_xci_od',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d63bba20>},
#  87: {'id': 87,
#   'CODE': 'P__HAo_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d6452908>},
#  88: {'id': 88,
#   'CODE': 'P__HAo_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d63bba90>},
#  89: {'id': 89,
#   'CODE': 'P__HAo_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d63bbac8>},
#  90: {'id': 90,
#   'CODE': 'P__HAo_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d63bbd68>},
#  91: {'id': 91,
#   'CODE': 'P__HAo_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d63bb8d0>},
#  92: {'id': 92,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d63bb2b0>},
#  93: {'id': 93,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d606e3c8>},
#  94: {'id': 94,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d63bb668>},
#  95: {'id': 95,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d63bb128>},
#  96: {'id': 96,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d60c5080>},
#  97: {'id': 97,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d60c50b8>},
#  98: {'id': 98,
#   'CODE': 'P__TK_s',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d60c5748>},
#  99: {'id': 99,
#   'CODE': 'P__TK_s',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d60c5400>},
#  100: {'id': 100,
#   'CODE': 'P__TK_s',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d60c5b70>},
#  101: {'id': 101,
#   'CODE': 'P__TK_s',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d60c5d30>},
#  102: {'id': 102,
#   'CODE': 'P__TK_s',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4e9be48>},
#  103: {'id': 103,
#   'CODE': 'P__TK_s',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4e8bef0>},
#  104: {'id': 104,
#   'CODE': 'P__TK_s',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4f1e278>},
#  105: {'id': 105,
#   'CODE': 'P__HAj_xci_od',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4f1e2b0>},
#  106: {'id': 106,
#   'CODE': 'P__HAj_xci_od',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d60c5438>},
#  107: {'id': 107,
#   'CODE': 'P__HAo_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4f20c88>},
#  108: {'id': 108,
#   'CODE': 'A_HAd_kd',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4f1de48>},
#  109: {'id': 109,
#   'CODE': 'A_HAd_kd',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4f22b70>},
#  110: {'id': 110,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4eb9908>},
#  111: {'id': 111,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4f22400>},
#  112: {'id': 112,
#   'CODE': 'A_HAd_kd',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4f206d8>},
#  113: {'id': 113,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d60cc9e8>},
#  114: {'id': 114,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4fd8c50>},
#  115: {'id': 115,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4f22ba8>},
#  116: {'id': 116,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4fd85f8>},
#  117: {'id': 117,
#   'CODE': 'A_FOu_bbo',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4f21198>},
#  118: {'id': 118,
#   'CODE': 'P__HAj_xci_od',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4f23da0>},
#  119: {'id': 119,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4f23518>},
#  120: {'id': 120,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4ec42e8>},
#  121: {'id': 121,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4f99940>},
#  122: {'id': 122,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d60bf518>},
#  123: {'id': 123,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4f23470>},
#  124: {'id': 124,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d60bf390>},
#  125: {'id': 125,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d60bf710>},
#  126: {'id': 126,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4f9a470>},
#  127: {'id': 127,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4f9ac50>},
#  128: {'id': 128,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4f9acc0>},
#  129: {'id': 129,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4f9a588>},
#  130: {'id': 130,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4f9e978>},
#  131: {'id': 131,
#   'CODE': 'P__HAj_xci_od',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4f25eb8>},
#  132: {'id': 132,
#   'CODE': 'P__HAo_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4f9e6a0>},
#  133: {'id': 133,
#   'CODE': 'P__HAw_fr',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d4f9ef98>},
#  134: {'id': 134,
#   'CODE': 'P__HAw_fr',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d7763198>},
#  135: {'id': 135,
#   'CODE': 'A_FOo_bbo',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d7763630>},
#  136: {'id': 136,
#   'CODE': 'P__WYm_sp',
#   'GROUP_': 'Wyloo_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d776fd30>},
#  137: {'id': 137,
#   'CODE': 'P__WYm_sp',
#   'GROUP_': 'Wyloo_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d776fa20>},
#  138: {'id': 138,
#   'CODE': 'P__WYd_kd',
#   'GROUP_': 'Wyloo_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d777d208>},
#  139: {'id': 139,
#   'CODE': 'P__WYd_kd',
#   'GROUP_': 'Wyloo_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d776ffd0>},
#  140: {'id': 140,
#   'CODE': 'P__SKq_stq',
#   'GROUP_': 'Shingle_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d777d438>},
#  141: {'id': 141,
#   'CODE': 'P__SKq_stq',
#   'GROUP_': 'Shingle_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d777d080>},
#  142: {'id': 142,
#   'CODE': 'P__TK_s',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d777d320>},
#  143: {'id': 143,
#   'CODE': 'P__TK_s',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d777d048>},
#  144: {'id': 144,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d777d710>},
#  145: {'id': 145,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d777d128>},
#  146: {'id': 146,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d777dda0>},
#  147: {'id': 147,
#   'CODE': 'P__WYa_st',
#   'GROUP_': 'Wyloo_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d777d9e8>},
#  148: {'id': 148,
#   'CODE': 'P__HAw_fr',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d777d5c0>},
#  149: {'id': 149,
#   'CODE': 'P__SKq_stq',
#   'GROUP_': 'Shingle_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d777d860>},
#  150: {'id': 150,
#   'CODE': 'P__SKq_stq',
#   'GROUP_': 'Shingle_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d7787390>},
#  151: {'id': 151,
#   'CODE': 'P__HAj_xci_od',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77873c8>},
#  152: {'id': 152,
#   'CODE': 'P__HAw_fr',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77870f0>},
#  153: {'id': 153,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d7787160>},
#  154: {'id': 154,
#   'CODE': 'P__HAo_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d7787668>},
#  155: {'id': 155,
#   'CODE': 'P__HAo_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d777d9b0>},
#  156: {'id': 156,
#   'CODE': 'P__HAo_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77879e8>},
#  157: {'id': 157,
#   'CODE': 'P__HAo_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d7787710>},
#  158: {'id': 158,
#   'CODE': 'P__HAo_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d7787fd0>},
#  159: {'id': 159,
#   'CODE': 'P__HAo_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d7787940>},
#  160: {'id': 160,
#   'CODE': 'P__TKo_stq',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d7787c50>},
#  161: {'id': 161,
#   'CODE': 'P__TKo_stq',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d7787b70>},
#  162: {'id': 162,
#   'CODE': 'P__TKo_stq',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77946d8>},
#  163: {'id': 163,
#   'CODE': 'P__HAj_xci_od',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d7794898>},
#  164: {'id': 164,
#   'CODE': 'P__WYm_sp',
#   'GROUP_': 'Wyloo_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d7794438>},
#  165: {'id': 165,
#   'CODE': 'P__WYm_sp',
#   'GROUP_': 'Wyloo_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d7794da0>},
#  166: {'id': 166,
#   'CODE': 'P__WYm_sp',
#   'GROUP_': 'Wyloo_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d7794f60>},
#  167: {'id': 167,
#   'CODE': 'P__WYm_sp',
#   'GROUP_': 'Wyloo_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d7794080>},
#  168: {'id': 168,
#   'CODE': 'P__WYm_sp',
#   'GROUP_': 'Wyloo_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d7794d68>},
#  169: {'id': 169,
#   'CODE': 'P__SKq_stq',
#   'GROUP_': 'Shingle_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d7794b70>},
#  170: {'id': 170,
#   'CODE': 'P__HAw_fr',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d7794240>},
#  171: {'id': 171,
#   'CODE': 'P__HAw_fr',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77a1f28>},
#  172: {'id': 172,
#   'CODE': 'P__TKa_xs_k',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77a1ef0>},
#  173: {'id': 173,
#   'CODE': 'P__TKa_xs_k',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77a1d30>},
#  174: {'id': 174,
#   'CODE': 'P__TKa_xs_k',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77af3c8>},
#  175: {'id': 175,
#   'CODE': 'P__TKa_xs_k',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77af438>},
#  176: {'id': 176,
#   'CODE': 'A_FOr_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77afc18>},
#  177: {'id': 177,
#   'CODE': 'A_FOr_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77a1e10>},
#  178: {'id': 178,
#   'CODE': 'P__TKo_stq',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77afbe0>},
#  179: {'id': 179,
#   'CODE': 'P__TKk_sf',
#   'GROUP_': 'Turee_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77b9080>},
#  180: {'id': 180,
#   'CODE': 'P__SKb_bb',
#   'GROUP_': 'Shingle_Creek_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77b9160>},
#  181: {'id': 181,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77b95c0>},
#  182: {'id': 182,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77b9c50>},
#  183: {'id': 183,
#   'CODE': 'A_FOr_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77b90f0>},
#  184: {'id': 184,
#   'CODE': 'A_FOr_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77b93c8>},
#  185: {'id': 185,
#   'CODE': 'A_FOh_xs_f',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77b9b38>},
#  186: {'id': 186,
#   'CODE': 'A_FOh_xs_f',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77b9dd8>},
#  187: {'id': 187,
#   'CODE': 'A_FOh_xs_f',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77c6240>},
#  188: {'id': 188,
#   'CODE': 'A_FOh_xs_f',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77c62b0>},
#  189: {'id': 189,
#   'CODE': 'A_FOh_xs_f',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77c6390>},
#  190: {'id': 190,
#   'CODE': 'A_FOh_xs_f',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77c6a20>},
#  191: {'id': 191,
#   'CODE': 'A_FOh_xs_f',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77c69e8>},
#  192: {'id': 192,
#   'CODE': 'A_FOo_bbo',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77c6320>},
#  193: {'id': 193,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77d4518>},
#  194: {'id': 194,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77c6cf8>},
#  195: {'id': 195,
#   'CODE': 'A_FOp_bs',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77d4b00>},
#  196: {'id': 196,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77df4a8>},
#  197: {'id': 197,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77d4d30>},
#  198: {'id': 198,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77dfcc0>},
#  199: {'id': 199,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77ed2b0>},
#  200: {'id': 200,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77ed240>},
#  201: {'id': 201,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77ed6a0>},
#  202: {'id': 202,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77edac8>},
#  203: {'id': 203,
#   'CODE': 'P__HAb_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77eda20>},
#  204: {'id': 204,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77df3c8>},
#  205: {'id': 205,
#   'CODE': 'A_HAm_cib',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77f7390>},
#  206: {'id': 206,
#   'CODE': 'A_HAd_kd',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77f70b8>},
#  207: {'id': 207,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77f7198>},
#  208: {'id': 208,
#   'CODE': 'A_FOj_xs_b',
#   'GROUP_': 'Fortescue_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77f79e8>},
#  209: {'id': 209,
#   'CODE': 'A_HAS_xsl_ci',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77f7a90>},
#  210: {'id': 210,
#   'CODE': 'P__HAj_xci_od',
#   'GROUP_': 'Hamersley_Group',
#   'geometry': <shapely.geometry.multilinestring.MultiLineString at 0x1c9d77f7978>}}

# %%
m2l_geometry.save_basal_no_faults(tmp_path+'basal_contacts.shp',tmp_path+'faults_clip.shp',ls_dict,10,c_l,dst_crs)
# Out:
# basal contacts without faults saved as ../test_data3/tmp/basal_contacts.shp

# %% [markdown]
# ## Remove faults from decimated basal contacts as save as csv file

# %%
contacts=gpd.read_file(tmp_path+'basal_contacts.shp')

m2l_geometry.save_basal_contacts_csv(contacts,output_path,dtm,contact_decimate,c_l)

#m2l_geometry.save_contacts_with_faults_removed(tmp_path+'faults_clip.shp',output_path,10,ls_dict,ls_dict_decimate,c_l,dst_crs,dtm)
# Out:
# decimated contacts saved as ../test_data3/output/contacts4.csv

# %% [markdown]
# ## Process fault geometry
# Save Faults as decimated points and representative orientation
# Then, for each  fault string:
# - incementally advance along polyline every at each inter-node (no point in doing more?)
# - find local stratigraphy 10m to left and right of fault
#
# Once full fault has been traversed:
# - Find list of contacts left
# - Find equivalent contacts on right
# - use interpolated orientations to estimate minimum true offset assuming vertical displacement and store
# - if no equivalent found, flag as domain fault and find min strat offset for contact, use cumulative minimum thickness estimate and store with flag (not implemented)
# - estimate median & sd of minimum fault offset and store with flag (not implemented)
#
# Local Orientations
# Since much of the code is the same, we benefit by calculating local orientation data either side of fault so that geomodeller/gempy have satisfied fault compartment orientation data## Save fault as contact info and and orientation info make vertical (for the moment)

# %%
m2l_geometry.save_faults(tmp_path+'faults_clip.shp',output_path,dtm,c_l,fault_decimate,min_fault_length,fault_dip)

use_gcode=('Hamersley Group','Fortescue Group','Wyloo Group','Shingle Creek Group','Turee Creek Group' ) 
use_gcode2=('Hamersley_Group','Fortescue_Group','Wyloo_Group','Shingle_Creek_Group','Turee_Creek_Group' ) 

m2l_interpolation.process_fault_throw_and_near_orientations(tmp_path,output_path,dtm_reproj_file,c_l,use_gcode,use_gcode2,dst_crs,bbox,scheme)
# Out:
# fault orientations saved as ../test_data3/output/fault_orientations.csv
# fault positions saved as ../test_data3/output/faults.csv
# fault dimensions saved as ../test_data3/output/fault_dimensions.csv
# C:\Users\00073294\AppData\Local\Continuum\anaconda3\lib\site-packages\geopandas\tools\sjoin.py:44: UserWarning: CRS of frames being joined does not match!
#   warn('CRS of frames being joined does not match!')
# orientations interpolated as dip dip direction ../test_data3/tmp/f_interpolation_scipy_rbf.csv
# orientations interpolated as l,m,n dir cos ../test_data3/tmp/f_interpolation_l.csv etc.
# orientations interpolated as dip dip direction ../test_data3/tmp/ex_f_interpolation_scipy_rbf.csv
# orientations interpolated as l,m,n dir cos ../test_data3/tmp/ex_f_interpolation_l.csv etc.
# contacts interpolated as strike ../test_data3/tmp/f_interpolation_contacts_scipy_rbf.csv
# contacts interpolated as l,m dir cos ../test_data3/tmp/f_interpolation_contacts_l.csv etc.
# contacts interpolated as strike ../test_data3/tmp/ex_f_interpolation_contacts_scipy_rbf.csv
# contacts interpolated as l,m dir cos ../test_data3/tmp/ex_f_interpolation_contacts_l.csv etc.
# {'init': 'EPSG:28350'} None
# contacts and orientations interpolated as dip dip direction ../test_data3/tmp/f_combo_full.csv
# {'init': 'EPSG:28350'} None
# contacts and orientations interpolated as dip dip direction ../test_data3/tmp/ex_f_combo_full.csv

# %% [markdown]
# ## Process plutons
#
# For each instruve but not sill polygon, find older neighbours and store decimated contact points. Also store dipping contact orientations (user defined, just because) with four possible sub-surface configurations:
#
# <b>saucers: \\_+++_/ <br>
# batholiths: +++/__ __ _\\+++  <br>
# domes: /‾+++‾\\ <br>
# pendants: +++\\_  _/+++ <br>
# </b>
#
# Saves out orientations and contact points, as well as updated group level stratigraphic column.<br>

# %%
bbox=(minx,miny,maxx,maxy)

pluton_dip=str(pluton_dip)

dist_buffer=10
dtm = rasterio.open(dtm_reproj_file)
m2l_geometry.process_plutons(tmp_path,output_path,geol_clip,local_paths,dtm,pluton_form,pluton_dip,contact_decimate,c_l)
# Out:
# 0 Wyloo_Group
# 1 Shingle_Creek_Group
# 2 Turee_Creek_Group
# 3 Hamersley_Group
# 4 Fortescue_Group
# 5 A_s_PMI
# 6 A_mgn_PMI
# 7 A_mgn_PRK
# 8 A_s_PRK
# 9 A_b_PRK
# pluton contacts and orientations saved as:
# ../test_data3/output/ign_contacts.csv
# ../test_data3/output/ign_orientations_domes.csv

# %% [markdown]
# ## Interpolates a regular grid of orientations from an  shapefile of arbitrarily-located points and saves out four csv files of l,m & n direction cosines and dip dip direction data
#
# Can choose between various RBF and IDW options
#
# The purpose of these interpolations and associated code is to help in three cases:
# - Providing estimated dips and contacts in fault-bounded domains where no structural data are available
# - Needed to estimate true thickness of formations
# - Possibly useful for poulating parts of maps where little structural data is available

# %%
use_gcode=('Hamersley Group','Fortescue Group','Wyloo Group','Shingle Creek Group','Turee Creek Group' ) ################# MOVE UP   #########################
structure_file=tmp_path+'structure_clip.shp'
bbox=(minx+inset,miny+inset,maxx-inset,maxy-inset)

# %%
print(c_l['g'])
print(use_gcode)
# Out:
# GROUP_
# ('Hamersley Group', 'Fortescue Group', 'Wyloo Group', 'Shingle Creek Group', 'Turee Creek Group')

# %%
m2l_interpolation.interpolate_orientations(structure_file,tmp_path,bbox,c_l,use_gcode,scheme,gridx,gridy,False)
# Out:
# orientations interpolated as dip dip direction ../test_data3/tmp/interpolation_scipy_rbf.csv
# orientations interpolated as l,m,n dir cos ../test_data3/tmp/interpolation_l.csv etc.

# %% [markdown]
# ## Interpolates a regular grid from a shapefile of from contacts and saves out three csv files of l & m direction cosines and strike data
#
# Can choose between various RBF and IDW options
#
# <font face color='red'>Best with basal contacts only, using Notebook #1 as this avoids intrusive  and fault contacts being considered</font>

# %%
geology_file=tmp_path+'basal_contacts.shp'

dtm = rasterio.open(dtm_reproj_file)
use_gcode=('Hamersley_Group','Fortescue_Group','Wyloo_Group','Shingle_Creek_Group','Turee_Creek_Group' ) ################# MOVE UP   #########################

# %%
contact_decimate=2
null_scheme='null'

m2l_interpolation.save_contact_vectors(geology_file,tmp_path,dtm,bbox,c_l,null_scheme,contact_decimate)

m2l_interpolation.interpolate_contacts(geology_file,tmp_path,dtm,bbox,c_l,use_gcode,scheme,gridx,gridy,False)
# Out:
# 176
# 5170 points saved to ../test_data3/tmp/raw_contacts.csv
# contacts interpolated as strike ../test_data3/tmp/interpolation_contacts_scipy_rbf.csv
# contacts interpolated as l,m dir cos ../test_data3/tmp/interpolation_contacts_l.csv etc.

# %% [markdown]
# ## Combines rbf of contact orientations with rbf of dip/dipdir measurements
#
# Uses normalised direction cosines **(l,m,n)**:
# - **l,m** from RBF of basal contact orientations
# - **signs of l & m** from misorientation with RBF of orientation data and
# - **n** from RBF of orientation data
#
# May be useful for adding data where no orientations are available (e.g. in fault bounded domains) and for calculating true thickness of layers. Assumes a 2D plane of data, but if 3D RBF was calulated and projected contact info was used it should apply with topography too.

# %%
geology_file=tmp_path+'geol_clip.shp'
combo_file=tmp_path+'combo.csv'

lc=np.loadtxt(tmp_path+'interpolation_contacts_l.csv',skiprows =1,delimiter =',',dtype=float)
mc=np.loadtxt(tmp_path+'interpolation_contacts_m.csv',skiprows =1,delimiter =',',dtype=float)
lo=np.loadtxt(tmp_path+'interpolation_l.csv',skiprows =1,delimiter =',',dtype=float)
mo=np.loadtxt(tmp_path+'interpolation_m.csv',skiprows =1,delimiter =',',dtype=float)
no=np.loadtxt(tmp_path+'interpolation_n.csv',skiprows =1,delimiter =',',dtype=float)
xy=np.loadtxt(tmp_path+'interpolation_'+scheme+'.csv',skiprows =1,delimiter =',',dtype=float)

# %%
m2l_interpolation.join_contacts_and_orientations(combo_file,geology_file,tmp_path,dtm_reproj_file,c_l,lo,mo,no,lc,mc,xy,dst_crs,bbox,False)
# Out:
# {'init': 'EPSG:28350'} None
# contacts and orientations interpolated as dip dip direction ../test_data3/tmp/combo_full.csv

# %% [markdown]
# ## Estimate formation thickness and normalised formation thickness

# %%
buffer =5000
max_thickness_allowed=10000

m2l_geometry.calc_thickness(tmp_path,output_path,buffer,max_thickness_allowed,c_l)

m2l_geometry.normalise_thickness(output_path)
# Out:
# 5222 thickness estimates saved as ../test_data3/output/formation_thicknesses.csv
# A_FOp_bs 893.5 474.8151508754447
# A_FOo_bbo 487.0 380.3901885591517
# A_FOh_xs_f 1342.5 516.9203605093961
# A_HAd_kd 334.0 312.8479278674922
# A_HAS_xsl_ci 182.0 173.50807625951074
# A_HAm_cib 248.0 237.3035109424519
# A_FOj_xs_b 598.0 530.348447967369
# P__HAo_ci 280.0 189.40783995028215
# P__HAw_fr 365.5 236.9973062513433
# P__HAj_xci_od 442.0 371.8378067417949
# P__HAb_cib 823.5 429.6822437951524
# P__TK_s 1353.5 64.58792456798717
# P__WYa_st 478.0 247.1000153428113
# P__TKo_stq 187.5 570.1081610129869
# P__TKa_xs_k 2434.5 246.68113696294927
# A_FOr_b 0.0 0.0
# P__TKk_sf 2223.0 136.8320137979413
# P__SKb_bb 2563.0 nan

# %% [markdown]
# ## Creates fold axial trace points

# %%
m2l_geometry.save_fold_axial_traces(tmp_path+'folds_clip.shp',output_path,dtm,c_l,fold_decimate)

#Save fold axial trace near-hinge orientations
fat_step=750         # how much to step out normal to fold axial trace
close_dip=20.0       #dip to assign to all new orientations
   
m2l_geometry.save_fold_axial_traces_orientations(tmp_path+'folds_clip.shp',output_path,tmp_path,dtm,c_l,dst_crs,fold_decimate,fat_step,close_dip)
# Out:
# fold axial traces saved as ../test_data3/output/fold_axial_traces.csv
# fold axial traces saved as ../test_data3/output/fold_axial_traces.csv
# fold axial trace orientations saved as ../test_data3/output/fold_axial_trace_orientations.csv

# %% [markdown]
# ## Preprocess data to ensure it meets modelling requirements

# %%
if(local_paths): ###############FUDGE#############
    use_gcode=('Hamersley_Group','Fortescue_Group','Turee_Creek_Group','A_mgn_PRK',  'A_mgn_PMI' ) ################# MOVE UP   #########################
    #use_gcode=('Hamersley_Group','Fortescue_Group','Wyloo_Group','Shingle_Creek_Group','Turee_Creek_Group','A_mgn_PRK',  'A_mgn_PMI' ) ################# MOVE UP   #########################
else:
    use_gcode=('Hamersley_Group','Fortescue_Group','Wyloo_Group','Shingle_Creek_Group','Turee_Creek_Group','A_mgn_PMI',  'A_mgn_PRK' ) ################# MOVE UP   #########################


print('only processing',use_gcode)

#inputs=('invented_orientations','interpolated_orientations','intrusive_orientations','fat_orientations','near_fault_orientations')
#inputs=('invented_orientations','interpolated_orientations','intrusive_orientations','fat_orientations','near_fault_orientations')
inputs=('invented_orientations','intrusive_orientations','fat_orientations','near_fault_orientations')

m2l_geometry.tidy_data(output_path,tmp_path,use_gcode,use_interpolations,use_fat,pluton_form,inputs)
# Out:
# only processing ('Hamersley_Group', 'Fortescue_Group', 'Turee_Creek_Group', 'A_mgn_PRK', 'A_mgn_PMI')

# %% [markdown]
# ## Analyse fault-fault topology

# %%
m2l_topology.parse_fault_relationships(graph_path,tmp_path,output_path)
# Out:
# cycles [['Fault_16825', 'Fault_7966', 'Fault_313', 'Fault_2837']]

# %% [markdown]
# # loop2gemodeller test

# %%
save_faults=True
compute_etc=True

m2l_export.loop2geomodeller(test_data_path,tmp_path,output_path,'./dtm/dtm_rp.tif',bbox,save_faults,compute_etc)

# %%
os.chdir(test_data_path)
# %system geomodellerbatch.exe -batch m2l.taskfile
# Out:
# ['WARNING: An illegal reflective access operation has occurred',
#  'WARNING: Illegal reflective access by com.dfa.util.Lib (file:/C:/GeoModeller/GeoModeller4.0.8_x64_88b64e610d9/bin/plugins/au.com.dfa.intrepid.lib_6.0.0.201911202221.jar) to field java.lang.ClassLoader.loadedLibraryNames',
#  'WARNING: Please consider reporting this to the maintainers of com.dfa.util.Lib',
#  'WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations',
#  'WARNING: All illegal access operations will be denied in a future release',
#  'COMPOSE EXTRA LENGTH FOR A_mgn_PRK 0',
#  'COMPOSE EXTRA LENGTH FOR A_mgn_PMI 0',
#  'COMPOSE EXTRA LENGTH FOR Fortescue_Group 0',
#  'COMPOSE EXTRA LENGTH FOR Hamersley_Group 0',
#  'COMPOSE EXTRA LENGTH FOR Turee_Creek_Group 0']

# %%
#%system geomodellerbatch.exe -batch m2l_compute.taskfile

# %%
import winsound
duration = 500  # milliseconds
freq = 1100  # Hz
winsound.Beep(freq, duration)
winsound.Beep(freq, duration)
duration=999
winsound.Beep(freq, duration)
